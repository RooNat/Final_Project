# %% [markdown]
# # CNN-LSTM Model for price movement

# %%
import pandas as pd
import numpy as np
from datetime import datetime
import datetime
import sklearn
from sklearn.model_selection import train_test_split
from tensorflow.keras.utils import to_categorical
from sklearn.preprocessing import MinMaxScaler
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.utils import shuffle
import tensorflow as tf

import keras.utils
from keras.models import Sequential
from keras.layers import Dropout
from keras.layers import Activation
from keras.layers import Convolution1D, Conv1D, ZeroPadding1D, MaxPooling1D, BatchNormalization, Activation, Dropout, Flatten, Dense
from keras.layers import Dense
from keras.layers import LSTM
from keras.optimizers import Adam

from tensorflow.keras.optimizers import RMSprop
from sklearn.metrics import classification_report

# %%
def rename_datetime(data):
    data.rename(columns={'Unnamed: 0': 'datetime'},inplace=True)
    data['datetime']=pd.to_datetime(data['datetime'])
    data.set_index('datetime', inplace=True)
    return data
# feature selection
# create features
def create_features(data, g_lag, tv_lag, tw_lag):
    data['Change'] =data['Close'].diff().dropna()
    data['Label'] = np.where(data['Change']>0, 1 ,0)
    data['google_trends_lag']=data['google_trends'].shift(g_lag)
    data['tweet_volume_lag']=data['tweet_volume'].shift(tv_lag)
    data['tw_polarity_lag'] = data['tw_polarity'].shift(tw_lag)

    data.drop(columns=['Open','High','Low','Change'],inplace=True)
    # Add features like RSI? Moving average?

    data.dropna(inplace=True)
    return data
# keep the wanted features
def keep_features(feature_conditions):
    features=['Label','Close']
    for feature, condition in feature_conditions.items():
        if condition:
            features.append(feature)
    return features

# create the lagged features based on the timesteps
def reshape_features(data, to_keep=1, to_remove=1):
    variables = 1 if type(data) is list else data.shape[1]
    df = pd.DataFrame(data)
    columns, names = list(), list()

    for i in range(to_keep, 0, -1):
        columns.append(df.shift(i))
        names += [('var%d(t-%d)' % (j+1, i)) for j in range(variables)]

    for i in range(0, to_remove):
        columns.append(df.shift(-i))
        if i == 0:
            names += [('var%d(t)' % (j+1)) for j in range(variables)]
        else:
            names += [('var%d(t+%d)' % (j+1, i)) for j in range(variables)]

    #put it all together
    final = pd.concat(columns, axis=1)
    final.columns = names

    #drop rows with NaN values
    final.dropna(inplace=True)

    new_data = final.reset_index()

    new_data = new_data.drop(columns=['datetime'])

    return new_data

# shuffle the data
def shuffle_data(times, data):
    np.random.seed(1)
    for i in range(times+1):
        data=shuffle(data)
    return data

# split labels from data
def split_label(train, test):
    train_y = train['var1(t)'].values
    test_y = test['var1(t)'].values
    train_y = train_y.reshape(len(train_y), 1)
    test_y = test_y.reshape(len(test_y), 1)
    return train_y, test_y

# normalize data using Minmaxscaler
def normalize_reshape_data(train, test, train_y, test_y, all_features, n_features, timestep):
    feature_scaler=MinMaxScaler()
    scale_train_data=feature_scaler.fit_transform(train)
    scale_test_data= feature_scaler.transform(test)
    train = scale_train_data[:, :all_features]
    test = scale_test_data[:, :all_features]
    #keep only prices array
    train_X, train_y = train[:, :all_features], train_y[:, -1]
    test_X, test_y = test[:, :all_features], test_y[:, -1]
    # reshape the data
    train_X = train_X.reshape((train_X.shape[0], timestep, n_features))
    test_X = test_X.reshape((test_X.shape[0], timestep, n_features))
    #set labels for training data to categorical
    train_y = to_categorical(train_y, 2)

    return train_X, test_X, train_y, test_y

# %%
filepath='./../data/processed_data.csv'

# %%
def get_data(filepath, g_lag, tv_lag, tw_lag, timestep, shuffle_times, split_ratio, feature_conditions, month, flag):
    # import data
    # import the original data. processed_data
    # processed_data: weighted reddit score+ fill the nan data
    data=pd.read_csv(filepath)
    # show the data
    data=rename_datetime(data)

    # get the subdata set
    if flag==0:
        data=data[data.index.month==month]
    else:
        data=data[(data.index.month>=1) & (data.index.month <=month)]

    # create features
    data_created = create_features(data,g_lag,tv_lag,tw_lag)

    # keep the wanted features
    features = keep_features(feature_conditions)
    data=data_created[features]

    # reshape the data
    # create the lagged features based on the timesteps
    df_copy = data.copy()
    new_data=reshape_features(df_copy, timestep, 1)

    # shuffle the data
    shuffled_data=shuffle_data(shuffle_times, new_data)

    # split the data
    train, test= train_test_split(shuffled_data, test_size=split_ratio)
    train_y, test_y=split_label(train, test)

    # normalized the data using MinMaxscaler
    n_features=len(features)
    all_features = timestep * n_features
    if (all_features==0):
        all_features=n_features
    train_X, test_X, train_y, test_y =normalize_reshape_data(train, test, train_y, test_y, all_features, n_features,timestep)

    print("train_X Shape:", train_X.shape)
    print("train_y Shape:", train_y.shape)
    print("test_X Shape:", test_X.shape)
    print("test_y Shape:", test_y.shape)

    return data, train_X, test_X, train_y, test_y, n_features

# %%
# # get correlation matrix
# sns.heatmap(data.corr(), annot=True)
# plt.show()

# %% [markdown]
# ## Model Building

# %%
def create_model(neurons, epochs, dropout, batch_size, verbose,
                 activ_func, activ_dense,my_optimizer,
                 train_X, train_y, test_X, test_y, n_features, timestep ):
    #set seed to reproduce results
    np.random.seed(1)
    tf.random.set_seed(1)

    # design network
    model = Sequential()

    #return sequences flag if there are more than 1 layer
    # return_seq = layers > 1

    model.add(Conv1D(neurons, kernel_size=64,padding='same', input_shape=(timestep, n_features)))
    # model.add(MaxPooling1D(pool_size=2, padding='same'))
    model.add(BatchNormalization())
    # Add ReLU activation layer
    model.add(Activation(activ_func))
    model.add(Dropout(dropout))

    model.add(Conv1D(neurons, kernel_size=32, padding='same'))
    # model.add(MaxPooling1D(pool_size=2, padding='same'))
    model.add(BatchNormalization())
    model.add(Activation(activ_func))
    model.add(Dropout(dropout))

    model.add(Conv1D(neurons, kernel_size=32, padding='same'))
    # model.add(MaxPooling1D(pool_size=2, padding='same'))
    model.add(BatchNormalization())
    model.add(Activation(activ_func))
    model.add(Dropout(dropout))

    model.add(Conv1D(neurons, kernel_size=8, padding='same'))
    model.add(MaxPooling1D(pool_size=2, padding='same'))
    model.add(BatchNormalization())
    model.add(Activation(activ_func))
    model.add(Dropout(dropout))

    model.add(Conv1D(neurons, kernel_size=1, padding='same'))
    # model.add(MaxPooling1D(pool_size=2, padding='same'))
    model.add(BatchNormalization())
    model.add(Activation(activ_func))
    model.add(Dropout(dropout))

    model.add(LSTM(32, return_sequences=False))
    model.add(BatchNormalization())
    model.add(Activation(activ_func))
    model.add(Dropout(dropout))

    model.add(Dense(200))
    model.add(Dense(100))
    model.add(Dense(100))
    model.add(Dense(100))
    model.add(Dense(100))
    model.add(Dense(100))
    model.add(Dense(100))

    #add a dense layer to output the prediction
    model.add(Dense(2, activation=activ_dense))
    model.compile(loss='categorical_crossentropy', optimizer=my_optimizer, metrics=['accuracy'])

    callback = keras.callbacks.EarlyStopping(monitor='val_loss', patience =50)

    # fit network
    history = model.fit(train_X, train_y, epochs=epochs, batch_size=batch_size, verbose=verbose, shuffle=False,validation_split=0.2, callbacks=[callback])

    #reshape
    test_X = test_X.reshape((test_X.shape[0], timestep, n_features))

    #make prediction
    pred = model.predict(test_X)

    #reshape again
    test_X = test_X.reshape((test_X.shape[0], timestep* n_features,))

    #get prediction
    y_pred = np.argmax(pred, axis=1)

    # calculate the metrics
    report=classification_report(
          test_y,
          y_pred,target_names = ["Down", "Up"],
          digits = 5, output_dict=True)

    # precision = report['Down']['precision']
    down_f1_score = report['Down']['f1-score']
    up_f1_score = report['Up']['f1-score']
    accuracy=report['accuracy']

    return down_f1_score, up_f1_score, accuracy

# %%
# model parameters

feature_conditions = {
        'google_trends': 0, 'google_trends_lag': 0,
        'tweet_volume_lag': 0, 'tw_polarity_lag': 0, 'tw_compound': 0,
        'tw_polarity': 0, 'tweet_volume': 0,'re_compound': 0,'re_polarity': 0,
        're_subjectivity': 0
    }
def test_model(filepath_out, feature_conditions):
    columns = ["timestep","features","google_trends_lag","tweet_volume_lag","tweet_polarity_score_lag", "batch_size", "neurons", "layers", "mean_down_f1_score","mean_up_f1_score", "mean_acc","min_acc", "max_acc", "diff_acc","optimizer","month","consecutive"]

    try:
        results = pd.read_csv(filepath_out)
    except:
        results = pd.DataFrame(columns=columns)

    #lagged_features
    timestep = [10,15]
    #train_ratio
    split_ratio =0.2
    shuffle_times = 3
    activ_func = "relu"
    activ_dense = 'softmax'
    my_optimizer = 'adam'
    # my_optimizer=RMSprop(lr=0.01, rho=0.9, epsilon=None, decay=0.0)
    epochs = 10000
    months =[6]
     #for each lag feature
    for month in months:
        for step in timestep:
            neurons = [32]
            batch_sizes = [80]
            dropout = 0.25
            verbose=2
            # Lags
            g_lag = [2]
            tv_lag = [28] # tweets volume
            tw_lag = 15 # tweets score

            # set flag: 1 - consecutive months, flag: 0 - single month
            flag=1

            #for each epoch, neuron, layers and batch_size value
            for n in neurons:
                for b in  batch_sizes:
                    print("Testing model: lag:", timestep, ", neurons:", n,  ", batch_size:", b)
                    for g in g_lag:
                        for tv in tv_lag:
                            #run for 5 times
                            accuracies = []
                            down_f1_score =[]
                            up_f1_score = []
                            for i in range (0,5):
                                data, train_X, test_X, train_y, test_y, n_features = get_data(filepath, g, tv, tw_lag, step, shuffle_times, split_ratio, feature_conditions,month,flag)
                                down_score, up_score, accuracy = create_model(n, epochs, dropout, b, verbose, activ_func,activ_dense,my_optimizer, train_X, train_y, test_X, test_y, n_features, step)
                                accuracies.append(accuracy)
                                down_f1_score.append(down_score)
                                up_f1_score.append(up_score)

                                #calculate mean values
                            accuracies = np.array(accuracies)
                            mean_acc =accuracies.mean()
                            min_acc =accuracies.min()
                            max_acc =accuracies.max()
                            diff_acc = max_acc - min_acc
                            mean_down_f1_score= np.array(down_f1_score).mean()
                            mean_up_f1_score=np.array(up_f1_score).mean()

                            results = results.append({"timestep": step,"features": data.columns.values,"google_trends_lag":g,"tweet_volume_lag": tv,"tweet_polarity_score_lag": tw_lag, "batch_size":b, "neurons":n,  "mean_down_f1_score":mean_down_f1_score,"mean_up_f1_score":mean_up_f1_score, "mean_acc": mean_acc,"min_acc":min_acc, "max_acc":max_acc, "diff_acc": diff_acc,"optimizer":my_optimizer,"month":month,"consecutive": flag}, ignore_index=True)
    return pd.DataFrame(results)

# %%
filepath_out='./../data/cnnlstm_results_1.csv'
results=test_model(filepath_out, feature_conditions)
# Out:
# Testing model: lag: [10, 15] , neurons: 32 , batch_size: 80
# train_X Shape: (3444, 10, 2)
# train_y Shape: (3444, 2)
# test_X Shape: (862, 10, 2)
# test_y Shape: (862,)
# Epoch 1/10000
# 2023-08-28 21:52:43.995867: W tensorflow/core/platform/profile_utils/cpu_utils.cc:128] Failed to get CPU frequency: 0 Hz
# 35/35 - 2s - loss: 0.7320 - accuracy: 0.5136 - val_loss: 0.6931 - val_accuracy: 0.5109 - 2s/epoch - 52ms/step
# Epoch 2/10000
# 35/35 - 0s - loss: 0.7000 - accuracy: 0.4966 - val_loss: 0.6929 - val_accuracy: 0.5109 - 383ms/epoch - 11ms/step
# Epoch 3/10000
# 35/35 - 0s - loss: 0.7049 - accuracy: 0.4998 - val_loss: 0.6930 - val_accuracy: 0.5109 - 420ms/epoch - 12ms/step
# Epoch 4/10000
# 35/35 - 0s - loss: 0.7006 - accuracy: 0.4940 - val_loss: 0.6930 - val_accuracy: 0.5109 - 423ms/epoch - 12ms/step
# Epoch 5/10000
# 35/35 - 1s - loss: 0.7010 - accuracy: 0.4940 - val_loss: 0.6929 - val_accuracy: 0.5109 - 504ms/epoch - 14ms/step
# Epoch 6/10000
# 35/35 - 0s - loss: 0.6968 - accuracy: 0.5016 - val_loss: 0.6934 - val_accuracy: 0.4891 - 395ms/epoch - 11ms/step
# Epoch 7/10000
# 35/35 - 0s - loss: 0.6968 - accuracy: 0.5056 - val_loss: 0.6939 - val_accuracy: 0.4891 - 411ms/epoch - 12ms/step
# Epoch 8/10000
# 35/35 - 0s - loss: 0.6957 - accuracy: 0.5201 - val_loss: 0.6942 - val_accuracy: 0.4891 - 379ms/epoch - 11ms/step
# Epoch 9/10000
# 35/35 - 0s - loss: 0.6972 - accuracy: 0.5031 - val_loss: 0.6934 - val_accuracy: 0.5109 - 398ms/epoch - 11ms/step
# Epoch 10/10000
# 35/35 - 0s - loss: 0.6964 - accuracy: 0.5009 - val_loss: 0.6929 - val_accuracy: 0.5080 - 472ms/epoch - 13ms/step
# Epoch 11/10000
# 35/35 - 0s - loss: 0.6953 - accuracy: 0.5118 - val_loss: 0.6942 - val_accuracy: 0.4935 - 491ms/epoch - 14ms/step
# Epoch 12/10000
# 35/35 - 1s - loss: 0.6969 - accuracy: 0.5038 - val_loss: 0.6966 - val_accuracy: 0.4993 - 612ms/epoch - 17ms/step
# Epoch 13/10000
# 35/35 - 0s - loss: 0.6950 - accuracy: 0.5227 - val_loss: 0.7097 - val_accuracy: 0.4935 - 459ms/epoch - 13ms/step
# Epoch 14/10000
# 35/35 - 1s - loss: 0.6976 - accuracy: 0.5042 - val_loss: 0.6972 - val_accuracy: 0.4819 - 503ms/epoch - 14ms/step
# Epoch 15/10000
# 35/35 - 0s - loss: 0.6956 - accuracy: 0.5201 - val_loss: 0.6931 - val_accuracy: 0.5167 - 477ms/epoch - 14ms/step
# Epoch 16/10000
# 35/35 - 0s - loss: 0.6958 - accuracy: 0.5132 - val_loss: 0.6930 - val_accuracy: 0.5167 - 487ms/epoch - 14ms/step
# Epoch 17/10000
# 35/35 - 1s - loss: 0.6924 - accuracy: 0.5223 - val_loss: 0.6932 - val_accuracy: 0.5065 - 516ms/epoch - 15ms/step
# Epoch 18/10000
# 35/35 - 1s - loss: 0.6953 - accuracy: 0.5111 - val_loss: 0.6980 - val_accuracy: 0.5167 - 519ms/epoch - 15ms/step
# Epoch 19/10000
# 35/35 - 1s - loss: 0.6941 - accuracy: 0.5223 - val_loss: 0.6938 - val_accuracy: 0.5022 - 546ms/epoch - 16ms/step
# Epoch 20/10000
# 35/35 - 1s - loss: 0.6957 - accuracy: 0.5024 - val_loss: 0.6926 - val_accuracy: 0.5123 - 537ms/epoch - 15ms/step
# Epoch 21/10000
# 35/35 - 1s - loss: 0.6944 - accuracy: 0.5118 - val_loss: 0.6972 - val_accuracy: 0.5065 - 538ms/epoch - 15ms/step
# Epoch 22/10000
# 35/35 - 1s - loss: 0.6934 - accuracy: 0.5187 - val_loss: 0.6975 - val_accuracy: 0.5065 - 546ms/epoch - 16ms/step
# Epoch 23/10000
# 35/35 - 0s - loss: 0.6934 - accuracy: 0.5227 - val_loss: 0.7031 - val_accuracy: 0.5065 - 489ms/epoch - 14ms/step
# Epoch 24/10000
# 35/35 - 1s - loss: 0.6936 - accuracy: 0.5183 - val_loss: 0.6963 - val_accuracy: 0.5254 - 529ms/epoch - 15ms/step
# Epoch 25/10000
# 35/35 - 1s - loss: 0.6917 - accuracy: 0.5379 - val_loss: 0.6954 - val_accuracy: 0.5254 - 544ms/epoch - 16ms/step
# Epoch 26/10000
# 35/35 - 0s - loss: 0.6917 - accuracy: 0.5314 - val_loss: 0.6931 - val_accuracy: 0.5225 - 408ms/epoch - 12ms/step
# Epoch 27/10000
# 35/35 - 0s - loss: 0.6886 - accuracy: 0.5521 - val_loss: 0.6940 - val_accuracy: 0.5298 - 457ms/epoch - 13ms/step
# Epoch 28/10000
# 35/35 - 1s - loss: 0.6911 - accuracy: 0.5354 - val_loss: 0.6968 - val_accuracy: 0.5167 - 529ms/epoch - 15ms/step
# Epoch 29/10000
# 35/35 - 0s - loss: 0.6923 - accuracy: 0.5227 - val_loss: 0.6946 - val_accuracy: 0.5080 - 491ms/epoch - 14ms/step
# Epoch 30/10000
# 35/35 - 0s - loss: 0.6915 - accuracy: 0.5336 - val_loss: 0.6988 - val_accuracy: 0.4862 - 404ms/epoch - 12ms/step
# Epoch 31/10000
# 35/35 - 0s - loss: 0.6890 - accuracy: 0.5466 - val_loss: 0.6987 - val_accuracy: 0.5051 - 407ms/epoch - 12ms/step
# Epoch 32/10000
# 35/35 - 0s - loss: 0.6906 - accuracy: 0.5303 - val_loss: 0.6937 - val_accuracy: 0.5051 - 404ms/epoch - 12ms/step
# Epoch 33/10000
# 35/35 - 0s - loss: 0.6901 - accuracy: 0.5285 - val_loss: 0.6934 - val_accuracy: 0.5167 - 412ms/epoch - 12ms/step
# Epoch 34/10000
# 35/35 - 0s - loss: 0.6895 - accuracy: 0.5292 - val_loss: 0.6963 - val_accuracy: 0.4848 - 412ms/epoch - 12ms/step
# Epoch 35/10000
# 35/35 - 0s - loss: 0.6870 - accuracy: 0.5477 - val_loss: 0.7012 - val_accuracy: 0.4862 - 476ms/epoch - 14ms/step
# Epoch 36/10000
# 35/35 - 0s - loss: 0.6879 - accuracy: 0.5376 - val_loss: 0.6959 - val_accuracy: 0.5269 - 457ms/epoch - 13ms/step
# Epoch 37/10000
# 35/35 - 0s - loss: 0.6864 - accuracy: 0.5499 - val_loss: 0.6984 - val_accuracy: 0.4964 - 426ms/epoch - 12ms/step
# Epoch 38/10000
# 35/35 - 0s - loss: 0.6859 - accuracy: 0.5503 - val_loss: 0.6937 - val_accuracy: 0.4949 - 429ms/epoch - 12ms/step
# Epoch 39/10000
# 35/35 - 0s - loss: 0.6877 - accuracy: 0.5387 - val_loss: 0.7031 - val_accuracy: 0.5196 - 400ms/epoch - 11ms/step
# Epoch 40/10000
# 35/35 - 0s - loss: 0.6875 - accuracy: 0.5463 - val_loss: 0.6961 - val_accuracy: 0.5138 - 396ms/epoch - 11ms/step
# Epoch 41/10000
# 35/35 - 0s - loss: 0.6863 - accuracy: 0.5430 - val_loss: 0.7179 - val_accuracy: 0.4978 - 395ms/epoch - 11ms/step
# Epoch 42/10000
# 35/35 - 0s - loss: 0.6860 - accuracy: 0.5590 - val_loss: 0.7028 - val_accuracy: 0.5022 - 406ms/epoch - 12ms/step
# Epoch 43/10000
# 35/35 - 0s - loss: 0.6836 - accuracy: 0.5586 - val_loss: 0.7183 - val_accuracy: 0.5283 - 409ms/epoch - 12ms/step
# Epoch 44/10000
# 35/35 - 0s - loss: 0.6853 - accuracy: 0.5535 - val_loss: 0.7048 - val_accuracy: 0.4993 - 417ms/epoch - 12ms/step
# Epoch 45/10000
# 35/35 - 0s - loss: 0.6843 - accuracy: 0.5583 - val_loss: 0.6987 - val_accuracy: 0.5094 - 399ms/epoch - 11ms/step
# Epoch 46/10000
# 35/35 - 0s - loss: 0.6821 - accuracy: 0.5641 - val_loss: 0.7159 - val_accuracy: 0.5269 - 398ms/epoch - 11ms/step
# Epoch 47/10000
# 35/35 - 0s - loss: 0.6853 - accuracy: 0.5684 - val_loss: 0.7158 - val_accuracy: 0.5007 - 411ms/epoch - 12ms/step
# Epoch 48/10000
# 35/35 - 0s - loss: 0.6864 - accuracy: 0.5557 - val_loss: 0.6960 - val_accuracy: 0.5283 - 405ms/epoch - 12ms/step
# Epoch 49/10000
# 35/35 - 0s - loss: 0.6829 - accuracy: 0.5742 - val_loss: 0.7082 - val_accuracy: 0.4993 - 397ms/epoch - 11ms/step
# Epoch 50/10000
# 35/35 - 0s - loss: 0.6823 - accuracy: 0.5633 - val_loss: 0.7046 - val_accuracy: 0.5022 - 424ms/epoch - 12ms/step
# Epoch 51/10000
# 35/35 - 0s - loss: 0.6826 - accuracy: 0.5662 - val_loss: 0.7148 - val_accuracy: 0.5080 - 429ms/epoch - 12ms/step
# Epoch 52/10000
# 35/35 - 0s - loss: 0.6859 - accuracy: 0.5583 - val_loss: 0.7144 - val_accuracy: 0.5239 - 428ms/epoch - 12ms/step
# Epoch 53/10000
# 35/35 - 0s - loss: 0.6825 - accuracy: 0.5728 - val_loss: 0.7058 - val_accuracy: 0.4978 - 429ms/epoch - 12ms/step
# Epoch 54/10000
# 35/35 - 0s - loss: 0.6803 - accuracy: 0.5786 - val_loss: 0.7240 - val_accuracy: 0.5152 - 426ms/epoch - 12ms/step
# Epoch 55/10000
# 35/35 - 0s - loss: 0.6815 - accuracy: 0.5684 - val_loss: 0.7128 - val_accuracy: 0.5051 - 460ms/epoch - 13ms/step
# Epoch 56/10000
# 35/35 - 0s - loss: 0.6792 - accuracy: 0.5779 - val_loss: 0.7127 - val_accuracy: 0.5225 - 414ms/epoch - 12ms/step
# Epoch 57/10000
# 35/35 - 0s - loss: 0.6804 - accuracy: 0.5760 - val_loss: 0.7197 - val_accuracy: 0.5123 - 417ms/epoch - 12ms/step
# Epoch 58/10000
# 35/35 - 0s - loss: 0.6785 - accuracy: 0.5739 - val_loss: 0.7292 - val_accuracy: 0.5138 - 431ms/epoch - 12ms/step
# Epoch 59/10000
# 35/35 - 0s - loss: 0.6786 - accuracy: 0.5819 - val_loss: 0.7036 - val_accuracy: 0.5167 - 421ms/epoch - 12ms/step
# Epoch 60/10000
# 35/35 - 0s - loss: 0.6773 - accuracy: 0.5822 - val_loss: 0.7324 - val_accuracy: 0.5007 - 442ms/epoch - 13ms/step
# Epoch 61/10000
# 35/35 - 0s - loss: 0.6796 - accuracy: 0.5630 - val_loss: 0.7136 - val_accuracy: 0.5210 - 442ms/epoch - 13ms/step
# Epoch 62/10000
# 35/35 - 0s - loss: 0.6791 - accuracy: 0.5681 - val_loss: 0.7283 - val_accuracy: 0.5094 - 405ms/epoch - 12ms/step
# Epoch 63/10000
# 35/35 - 0s - loss: 0.6782 - accuracy: 0.5695 - val_loss: 0.7309 - val_accuracy: 0.4949 - 408ms/epoch - 12ms/step
# Epoch 64/10000
# 35/35 - 0s - loss: 0.6783 - accuracy: 0.5768 - val_loss: 0.7172 - val_accuracy: 0.4978 - 409ms/epoch - 12ms/step
# Epoch 65/10000
# 35/35 - 0s - loss: 0.6766 - accuracy: 0.5768 - val_loss: 0.6969 - val_accuracy: 0.5036 - 424ms/epoch - 12ms/step
# Epoch 66/10000
# 35/35 - 0s - loss: 0.6738 - accuracy: 0.5833 - val_loss: 0.7391 - val_accuracy: 0.4978 - 440ms/epoch - 13ms/step
# Epoch 67/10000
# 35/35 - 0s - loss: 0.6749 - accuracy: 0.5869 - val_loss: 0.7350 - val_accuracy: 0.5181 - 411ms/epoch - 12ms/step
# Epoch 68/10000
# 35/35 - 0s - loss: 0.6736 - accuracy: 0.5819 - val_loss: 0.7014 - val_accuracy: 0.5210 - 442ms/epoch - 13ms/step
# Epoch 69/10000
# 35/35 - 0s - loss: 0.6731 - accuracy: 0.5975 - val_loss: 0.7164 - val_accuracy: 0.5167 - 451ms/epoch - 13ms/step
# Epoch 70/10000
# 35/35 - 0s - loss: 0.6726 - accuracy: 0.5862 - val_loss: 0.7183 - val_accuracy: 0.5123 - 420ms/epoch - 12ms/step
# 27/27 [==============================] - 0s 2ms/step
# train_X Shape: (3444, 10, 2)
# train_y Shape: (3444, 2)
# test_X Shape: (862, 10, 2)
# test_y Shape: (862,)
# Epoch 1/10000
# 35/35 - 2s - loss: 0.7285 - accuracy: 0.5136 - val_loss: 0.6929 - val_accuracy: 0.5109 - 2s/epoch - 49ms/step
# Epoch 2/10000
# 35/35 - 0s - loss: 0.7039 - accuracy: 0.5034 - val_loss: 0.6930 - val_accuracy: 0.5109 - 375ms/epoch - 11ms/step
# Epoch 3/10000
# 35/35 - 0s - loss: 0.7065 - accuracy: 0.4940 - val_loss: 0.6930 - val_accuracy: 0.5109 - 411ms/epoch - 12ms/step
# Epoch 4/10000
# 35/35 - 0s - loss: 0.6997 - accuracy: 0.5107 - val_loss: 0.6929 - val_accuracy: 0.5109 - 410ms/epoch - 12ms/step
# Epoch 5/10000
# 35/35 - 0s - loss: 0.6969 - accuracy: 0.4929 - val_loss: 0.6934 - val_accuracy: 0.5109 - 410ms/epoch - 12ms/step
# Epoch 6/10000
# 35/35 - 0s - loss: 0.7004 - accuracy: 0.4991 - val_loss: 0.6938 - val_accuracy: 0.5109 - 415ms/epoch - 12ms/step
# Epoch 7/10000
# 35/35 - 0s - loss: 0.6996 - accuracy: 0.5082 - val_loss: 0.6932 - val_accuracy: 0.5007 - 431ms/epoch - 12ms/step
# Epoch 8/10000
# 35/35 - 0s - loss: 0.6953 - accuracy: 0.5136 - val_loss: 0.6929 - val_accuracy: 0.5109 - 422ms/epoch - 12ms/step
# Epoch 9/10000
# 35/35 - 0s - loss: 0.6969 - accuracy: 0.4991 - val_loss: 0.6931 - val_accuracy: 0.5109 - 438ms/epoch - 13ms/step
# Epoch 10/10000
# 35/35 - 0s - loss: 0.6948 - accuracy: 0.5089 - val_loss: 0.6953 - val_accuracy: 0.5109 - 463ms/epoch - 13ms/step
# Epoch 11/10000
# 35/35 - 0s - loss: 0.6970 - accuracy: 0.5082 - val_loss: 0.6930 - val_accuracy: 0.5109 - 423ms/epoch - 12ms/step
# Epoch 12/10000
# 35/35 - 0s - loss: 0.6937 - accuracy: 0.5107 - val_loss: 0.6930 - val_accuracy: 0.5167 - 405ms/epoch - 12ms/step
# Epoch 13/10000
# 35/35 - 0s - loss: 0.6958 - accuracy: 0.4998 - val_loss: 0.6937 - val_accuracy: 0.5123 - 433ms/epoch - 12ms/step
# Epoch 14/10000
# 35/35 - 0s - loss: 0.6964 - accuracy: 0.5176 - val_loss: 0.6919 - val_accuracy: 0.5239 - 427ms/epoch - 12ms/step
# Epoch 15/10000
# 35/35 - 0s - loss: 0.6960 - accuracy: 0.5140 - val_loss: 0.6935 - val_accuracy: 0.5196 - 387ms/epoch - 11ms/step
# Epoch 16/10000
# 35/35 - 0s - loss: 0.6945 - accuracy: 0.5100 - val_loss: 0.6927 - val_accuracy: 0.5007 - 409ms/epoch - 12ms/step
# Epoch 17/10000
# 35/35 - 0s - loss: 0.6893 - accuracy: 0.5292 - val_loss: 0.7018 - val_accuracy: 0.4935 - 404ms/epoch - 12ms/step
# Epoch 18/10000
# 35/35 - 0s - loss: 0.6941 - accuracy: 0.5143 - val_loss: 0.6978 - val_accuracy: 0.4906 - 388ms/epoch - 11ms/step
# Epoch 19/10000
# 35/35 - 0s - loss: 0.6911 - accuracy: 0.5347 - val_loss: 0.7145 - val_accuracy: 0.5298 - 381ms/epoch - 11ms/step
# Epoch 20/10000
# 35/35 - 0s - loss: 0.6952 - accuracy: 0.5205 - val_loss: 0.7004 - val_accuracy: 0.5312 - 381ms/epoch - 11ms/step
# Epoch 21/10000
# 35/35 - 0s - loss: 0.6941 - accuracy: 0.5191 - val_loss: 0.6942 - val_accuracy: 0.5225 - 378ms/epoch - 11ms/step
# Epoch 22/10000
# 35/35 - 0s - loss: 0.6921 - accuracy: 0.5267 - val_loss: 0.6977 - val_accuracy: 0.5210 - 381ms/epoch - 11ms/step
# Epoch 23/10000
# 35/35 - 0s - loss: 0.6927 - accuracy: 0.5209 - val_loss: 0.6992 - val_accuracy: 0.5036 - 397ms/epoch - 11ms/step
# Epoch 24/10000
# 35/35 - 0s - loss: 0.6924 - accuracy: 0.5292 - val_loss: 0.7032 - val_accuracy: 0.5094 - 384ms/epoch - 11ms/step
# Epoch 25/10000
# 35/35 - 0s - loss: 0.6939 - accuracy: 0.5165 - val_loss: 0.6999 - val_accuracy: 0.5269 - 400ms/epoch - 11ms/step
# Epoch 26/10000
# 35/35 - 0s - loss: 0.6918 - accuracy: 0.5339 - val_loss: 0.6951 - val_accuracy: 0.5007 - 378ms/epoch - 11ms/step
# Epoch 27/10000
# 35/35 - 0s - loss: 0.6922 - accuracy: 0.5267 - val_loss: 0.6921 - val_accuracy: 0.5312 - 391ms/epoch - 11ms/step
# Epoch 28/10000
# 35/35 - 0s - loss: 0.6934 - accuracy: 0.5169 - val_loss: 0.6927 - val_accuracy: 0.5385 - 422ms/epoch - 12ms/step
# Epoch 29/10000
# 35/35 - 0s - loss: 0.6925 - accuracy: 0.5249 - val_loss: 0.6913 - val_accuracy: 0.5385 - 424ms/epoch - 12ms/step
# Epoch 30/10000
# 35/35 - 0s - loss: 0.6939 - accuracy: 0.5252 - val_loss: 0.6921 - val_accuracy: 0.5327 - 408ms/epoch - 12ms/step
# Epoch 31/10000
# 35/35 - 0s - loss: 0.6910 - accuracy: 0.5314 - val_loss: 0.6926 - val_accuracy: 0.5254 - 398ms/epoch - 11ms/step
# Epoch 32/10000
# 35/35 - 0s - loss: 0.6914 - accuracy: 0.5289 - val_loss: 0.6926 - val_accuracy: 0.5283 - 451ms/epoch - 13ms/step
# Epoch 33/10000
# 35/35 - 0s - loss: 0.6921 - accuracy: 0.5278 - val_loss: 0.6927 - val_accuracy: 0.5269 - 462ms/epoch - 13ms/step
# Epoch 34/10000
# 35/35 - 0s - loss: 0.6895 - accuracy: 0.5499 - val_loss: 0.6965 - val_accuracy: 0.5428 - 379ms/epoch - 11ms/step
# Epoch 35/10000
# 35/35 - 0s - loss: 0.6917 - accuracy: 0.5260 - val_loss: 0.6966 - val_accuracy: 0.5327 - 362ms/epoch - 10ms/step
# Epoch 36/10000
# 35/35 - 0s - loss: 0.6899 - accuracy: 0.5379 - val_loss: 0.6939 - val_accuracy: 0.5138 - 358ms/epoch - 10ms/step
# Epoch 37/10000
# 35/35 - 0s - loss: 0.6891 - accuracy: 0.5481 - val_loss: 0.6925 - val_accuracy: 0.5254 - 356ms/epoch - 10ms/step
# Epoch 38/10000
# 35/35 - 0s - loss: 0.6889 - accuracy: 0.5405 - val_loss: 0.6939 - val_accuracy: 0.5094 - 348ms/epoch - 10ms/step
# Epoch 39/10000
# 35/35 - 0s - loss: 0.6894 - accuracy: 0.5412 - val_loss: 0.6949 - val_accuracy: 0.5385 - 352ms/epoch - 10ms/step
# Epoch 40/10000
# 35/35 - 0s - loss: 0.6885 - accuracy: 0.5401 - val_loss: 0.6949 - val_accuracy: 0.5210 - 358ms/epoch - 10ms/step
# Epoch 41/10000
# 35/35 - 0s - loss: 0.6869 - accuracy: 0.5448 - val_loss: 0.6958 - val_accuracy: 0.5370 - 350ms/epoch - 10ms/step
# Epoch 42/10000
# 35/35 - 0s - loss: 0.6846 - accuracy: 0.5550 - val_loss: 0.7021 - val_accuracy: 0.5327 - 358ms/epoch - 10ms/step
# Epoch 43/10000
# 35/35 - 0s - loss: 0.6882 - accuracy: 0.5495 - val_loss: 0.6991 - val_accuracy: 0.5239 - 372ms/epoch - 11ms/step
# Epoch 44/10000
# 35/35 - 0s - loss: 0.6883 - accuracy: 0.5514 - val_loss: 0.7085 - val_accuracy: 0.4993 - 374ms/epoch - 11ms/step
# Epoch 45/10000
# 35/35 - 0s - loss: 0.6874 - accuracy: 0.5437 - val_loss: 0.6928 - val_accuracy: 0.5210 - 371ms/epoch - 11ms/step
# Epoch 46/10000
# 35/35 - 0s - loss: 0.6908 - accuracy: 0.5194 - val_loss: 0.6932 - val_accuracy: 0.5109 - 379ms/epoch - 11ms/step
# Epoch 47/10000
# 35/35 - 0s - loss: 0.6909 - accuracy: 0.5292 - val_loss: 0.6938 - val_accuracy: 0.5152 - 368ms/epoch - 11ms/step
# Epoch 48/10000
# 35/35 - 0s - loss: 0.6920 - accuracy: 0.5408 - val_loss: 0.6933 - val_accuracy: 0.4964 - 356ms/epoch - 10ms/step
# Epoch 49/10000
# 35/35 - 0s - loss: 0.6890 - accuracy: 0.5343 - val_loss: 0.6940 - val_accuracy: 0.4978 - 388ms/epoch - 11ms/step
# Epoch 50/10000
# 35/35 - 0s - loss: 0.6910 - accuracy: 0.5241 - val_loss: 0.6934 - val_accuracy: 0.5094 - 363ms/epoch - 10ms/step
# Epoch 51/10000
# 35/35 - 0s - loss: 0.6894 - accuracy: 0.5405 - val_loss: 0.6930 - val_accuracy: 0.5181 - 367ms/epoch - 10ms/step
# Epoch 52/10000
# 35/35 - 0s - loss: 0.6888 - accuracy: 0.5452 - val_loss: 0.6962 - val_accuracy: 0.4775 - 366ms/epoch - 10ms/step
# Epoch 53/10000
# 35/35 - 0s - loss: 0.6871 - accuracy: 0.5466 - val_loss: 0.6940 - val_accuracy: 0.4978 - 368ms/epoch - 11ms/step
# Epoch 54/10000
# 35/35 - 0s - loss: 0.6867 - accuracy: 0.5514 - val_loss: 0.6970 - val_accuracy: 0.4964 - 369ms/epoch - 11ms/step
# Epoch 55/10000
# 35/35 - 0s - loss: 0.6853 - accuracy: 0.5445 - val_loss: 0.6981 - val_accuracy: 0.4935 - 361ms/epoch - 10ms/step
# Epoch 56/10000
# 35/35 - 0s - loss: 0.6864 - accuracy: 0.5586 - val_loss: 0.7046 - val_accuracy: 0.5123 - 378ms/epoch - 11ms/step
# Epoch 57/10000
# 35/35 - 0s - loss: 0.6837 - accuracy: 0.5561 - val_loss: 0.7050 - val_accuracy: 0.5196 - 373ms/epoch - 11ms/step
# Epoch 58/10000
# 35/35 - 0s - loss: 0.6834 - accuracy: 0.5525 - val_loss: 0.7170 - val_accuracy: 0.4920 - 366ms/epoch - 10ms/step
# Epoch 59/10000
# 35/35 - 0s - loss: 0.6820 - accuracy: 0.5539 - val_loss: 0.6948 - val_accuracy: 0.5225 - 371ms/epoch - 11ms/step
# Epoch 60/10000
# 35/35 - 0s - loss: 0.6832 - accuracy: 0.5525 - val_loss: 0.7107 - val_accuracy: 0.5022 - 378ms/epoch - 11ms/step
# Epoch 61/10000
# 35/35 - 0s - loss: 0.6803 - accuracy: 0.5492 - val_loss: 0.7040 - val_accuracy: 0.4964 - 362ms/epoch - 10ms/step
# Epoch 62/10000
# 35/35 - 0s - loss: 0.6836 - accuracy: 0.5637 - val_loss: 0.7070 - val_accuracy: 0.5138 - 372ms/epoch - 11ms/step
# Epoch 63/10000
# 35/35 - 0s - loss: 0.6785 - accuracy: 0.5695 - val_loss: 0.7037 - val_accuracy: 0.5022 - 369ms/epoch - 11ms/step
# Epoch 64/10000
# 35/35 - 0s - loss: 0.6799 - accuracy: 0.5670 - val_loss: 0.6965 - val_accuracy: 0.5138 - 367ms/epoch - 10ms/step
# Epoch 65/10000
# 35/35 - 0s - loss: 0.6824 - accuracy: 0.5561 - val_loss: 0.7115 - val_accuracy: 0.5051 - 367ms/epoch - 10ms/step
# Epoch 66/10000
# 35/35 - 0s - loss: 0.6810 - accuracy: 0.5543 - val_loss: 0.6991 - val_accuracy: 0.5123 - 369ms/epoch - 11ms/step
# Epoch 67/10000
# 35/35 - 0s - loss: 0.6779 - accuracy: 0.5702 - val_loss: 0.6974 - val_accuracy: 0.4978 - 363ms/epoch - 10ms/step
# Epoch 68/10000
# 35/35 - 0s - loss: 0.6797 - accuracy: 0.5626 - val_loss: 0.6959 - val_accuracy: 0.5138 - 366ms/epoch - 10ms/step
# Epoch 69/10000
# 35/35 - 0s - loss: 0.6799 - accuracy: 0.5583 - val_loss: 0.6931 - val_accuracy: 0.5065 - 365ms/epoch - 10ms/step
# Epoch 70/10000
# 35/35 - 0s - loss: 0.6745 - accuracy: 0.5750 - val_loss: 0.7162 - val_accuracy: 0.5036 - 368ms/epoch - 11ms/step
# Epoch 71/10000
# 35/35 - 0s - loss: 0.6813 - accuracy: 0.5662 - val_loss: 0.6967 - val_accuracy: 0.4978 - 372ms/epoch - 11ms/step
# Epoch 72/10000
# 35/35 - 0s - loss: 0.6746 - accuracy: 0.5673 - val_loss: 0.7002 - val_accuracy: 0.4993 - 384ms/epoch - 11ms/step
# Epoch 73/10000
# 35/35 - 0s - loss: 0.6769 - accuracy: 0.5750 - val_loss: 0.7029 - val_accuracy: 0.5036 - 363ms/epoch - 10ms/step
# Epoch 74/10000
# 35/35 - 0s - loss: 0.6758 - accuracy: 0.5633 - val_loss: 0.7001 - val_accuracy: 0.4964 - 387ms/epoch - 11ms/step
# Epoch 75/10000
# 35/35 - 0s - loss: 0.6696 - accuracy: 0.5931 - val_loss: 0.6991 - val_accuracy: 0.4964 - 371ms/epoch - 11ms/step
# Epoch 76/10000
# 35/35 - 0s - loss: 0.6683 - accuracy: 0.5855 - val_loss: 0.7077 - val_accuracy: 0.4949 - 375ms/epoch - 11ms/step
# Epoch 77/10000
# 35/35 - 0s - loss: 0.6769 - accuracy: 0.5684 - val_loss: 0.6998 - val_accuracy: 0.5007 - 376ms/epoch - 11ms/step
# Epoch 78/10000
# 35/35 - 0s - loss: 0.6716 - accuracy: 0.5917 - val_loss: 0.7015 - val_accuracy: 0.5138 - 366ms/epoch - 10ms/step
# Epoch 79/10000
# 35/35 - 0s - loss: 0.6696 - accuracy: 0.5851 - val_loss: 0.7056 - val_accuracy: 0.5080 - 372ms/epoch - 11ms/step
# 27/27 [==============================] - 0s 2ms/step
# train_X Shape: (3444, 10, 2)
# train_y Shape: (3444, 2)
# test_X Shape: (862, 10, 2)
# test_y Shape: (862,)
# Epoch 1/10000
# 35/35 - 2s - loss: 0.7236 - accuracy: 0.4831 - val_loss: 0.6932 - val_accuracy: 0.4891 - 2s/epoch - 47ms/step
# Epoch 2/10000
# 35/35 - 0s - loss: 0.7014 - accuracy: 0.4907 - val_loss: 0.6930 - val_accuracy: 0.5109 - 364ms/epoch - 10ms/step
# Epoch 3/10000
# 35/35 - 0s - loss: 0.7028 - accuracy: 0.5024 - val_loss: 0.6929 - val_accuracy: 0.5109 - 352ms/epoch - 10ms/step
# Epoch 4/10000
# 35/35 - 0s - loss: 0.7021 - accuracy: 0.5009 - val_loss: 0.6932 - val_accuracy: 0.5109 - 375ms/epoch - 11ms/step
# Epoch 5/10000
# 35/35 - 0s - loss: 0.7010 - accuracy: 0.4893 - val_loss: 0.6938 - val_accuracy: 0.5109 - 377ms/epoch - 11ms/step
# Epoch 6/10000
# 35/35 - 0s - loss: 0.6973 - accuracy: 0.5114 - val_loss: 0.6935 - val_accuracy: 0.5109 - 413ms/epoch - 12ms/step
# Epoch 7/10000
# 35/35 - 0s - loss: 0.6983 - accuracy: 0.4984 - val_loss: 0.6934 - val_accuracy: 0.5109 - 388ms/epoch - 11ms/step
# Epoch 8/10000
# 35/35 - 0s - loss: 0.6937 - accuracy: 0.5241 - val_loss: 0.6962 - val_accuracy: 0.5109 - 401ms/epoch - 11ms/step
# Epoch 9/10000
# 35/35 - 0s - loss: 0.7001 - accuracy: 0.5060 - val_loss: 0.6960 - val_accuracy: 0.5109 - 394ms/epoch - 11ms/step
# Epoch 10/10000
# 35/35 - 0s - loss: 0.6978 - accuracy: 0.5078 - val_loss: 0.6924 - val_accuracy: 0.5167 - 384ms/epoch - 11ms/step
# Epoch 11/10000
# 35/35 - 0s - loss: 0.6964 - accuracy: 0.4991 - val_loss: 0.6949 - val_accuracy: 0.5109 - 431ms/epoch - 12ms/step
# Epoch 12/10000
# 35/35 - 0s - loss: 0.6954 - accuracy: 0.5064 - val_loss: 0.6942 - val_accuracy: 0.5109 - 405ms/epoch - 12ms/step
# Epoch 13/10000
# 35/35 - 0s - loss: 0.6951 - accuracy: 0.5234 - val_loss: 0.6955 - val_accuracy: 0.5138 - 421ms/epoch - 12ms/step
# Epoch 14/10000
# 35/35 - 0s - loss: 0.6918 - accuracy: 0.5299 - val_loss: 0.7154 - val_accuracy: 0.5152 - 417ms/epoch - 12ms/step
# Epoch 15/10000
# 35/35 - 0s - loss: 0.6957 - accuracy: 0.5249 - val_loss: 0.6930 - val_accuracy: 0.5094 - 415ms/epoch - 12ms/step
# Epoch 16/10000
# 35/35 - 0s - loss: 0.6900 - accuracy: 0.5318 - val_loss: 0.7092 - val_accuracy: 0.5007 - 445ms/epoch - 13ms/step
# Epoch 17/10000
# 35/35 - 0s - loss: 0.6936 - accuracy: 0.5158 - val_loss: 0.6969 - val_accuracy: 0.5094 - 424ms/epoch - 12ms/step
# Epoch 18/10000
# 35/35 - 0s - loss: 0.6937 - accuracy: 0.5140 - val_loss: 0.6964 - val_accuracy: 0.5312 - 449ms/epoch - 13ms/step
# Epoch 19/10000
# 35/35 - 0s - loss: 0.6918 - accuracy: 0.5249 - val_loss: 0.7105 - val_accuracy: 0.5181 - 429ms/epoch - 12ms/step
# Epoch 20/10000
# 35/35 - 0s - loss: 0.6909 - accuracy: 0.5303 - val_loss: 0.7232 - val_accuracy: 0.5312 - 396ms/epoch - 11ms/step
# Epoch 21/10000
# 35/35 - 0s - loss: 0.6919 - accuracy: 0.5285 - val_loss: 0.7009 - val_accuracy: 0.5167 - 420ms/epoch - 12ms/step
# Epoch 22/10000
# 35/35 - 0s - loss: 0.6931 - accuracy: 0.5281 - val_loss: 0.7033 - val_accuracy: 0.4993 - 444ms/epoch - 13ms/step
# Epoch 23/10000
# 35/35 - 0s - loss: 0.6910 - accuracy: 0.5343 - val_loss: 0.7212 - val_accuracy: 0.5356 - 420ms/epoch - 12ms/step
# Epoch 24/10000
# 35/35 - 1s - loss: 0.6933 - accuracy: 0.5230 - val_loss: 0.6994 - val_accuracy: 0.5138 - 501ms/epoch - 14ms/step
# Epoch 25/10000
# 35/35 - 0s - loss: 0.6908 - accuracy: 0.5263 - val_loss: 0.7033 - val_accuracy: 0.5254 - 402ms/epoch - 11ms/step
# Epoch 26/10000
# 35/35 - 1s - loss: 0.6907 - accuracy: 0.5281 - val_loss: 0.7119 - val_accuracy: 0.5254 - 514ms/epoch - 15ms/step
# Epoch 27/10000
# 35/35 - 0s - loss: 0.6905 - accuracy: 0.5372 - val_loss: 0.7041 - val_accuracy: 0.5196 - 388ms/epoch - 11ms/step
# Epoch 28/10000
# 35/35 - 0s - loss: 0.6899 - accuracy: 0.5307 - val_loss: 0.7056 - val_accuracy: 0.5210 - 425ms/epoch - 12ms/step
# Epoch 29/10000
# 35/35 - 0s - loss: 0.6876 - accuracy: 0.5405 - val_loss: 0.7010 - val_accuracy: 0.5312 - 391ms/epoch - 11ms/step
# Epoch 30/10000
# 35/35 - 0s - loss: 0.6925 - accuracy: 0.5165 - val_loss: 0.6952 - val_accuracy: 0.4877 - 382ms/epoch - 11ms/step
# Epoch 31/10000
# 35/35 - 0s - loss: 0.6898 - accuracy: 0.5368 - val_loss: 0.6911 - val_accuracy: 0.5370 - 389ms/epoch - 11ms/step
# Epoch 32/10000
# 35/35 - 0s - loss: 0.6914 - accuracy: 0.5372 - val_loss: 0.6942 - val_accuracy: 0.5080 - 376ms/epoch - 11ms/step
# Epoch 33/10000
# 35/35 - 0s - loss: 0.6904 - accuracy: 0.5347 - val_loss: 0.6933 - val_accuracy: 0.5167 - 363ms/epoch - 10ms/step
# Epoch 34/10000
# 35/35 - 0s - loss: 0.6918 - accuracy: 0.5310 - val_loss: 0.6950 - val_accuracy: 0.5036 - 362ms/epoch - 10ms/step
# Epoch 35/10000
# 35/35 - 0s - loss: 0.6893 - accuracy: 0.5350 - val_loss: 0.6947 - val_accuracy: 0.4978 - 377ms/epoch - 11ms/step
# Epoch 36/10000
# 35/35 - 0s - loss: 0.6905 - accuracy: 0.5397 - val_loss: 0.6954 - val_accuracy: 0.4702 - 382ms/epoch - 11ms/step
# Epoch 37/10000
# 35/35 - 0s - loss: 0.6899 - accuracy: 0.5397 - val_loss: 0.6944 - val_accuracy: 0.5080 - 371ms/epoch - 11ms/step
# Epoch 38/10000
# 35/35 - 0s - loss: 0.6895 - accuracy: 0.5445 - val_loss: 0.6937 - val_accuracy: 0.5181 - 371ms/epoch - 11ms/step
# Epoch 39/10000
# 35/35 - 0s - loss: 0.6896 - accuracy: 0.5390 - val_loss: 0.6959 - val_accuracy: 0.4993 - 370ms/epoch - 11ms/step
# Epoch 40/10000
# 35/35 - 0s - loss: 0.6858 - accuracy: 0.5633 - val_loss: 0.6947 - val_accuracy: 0.5254 - 371ms/epoch - 11ms/step
# Epoch 41/10000
# 35/35 - 0s - loss: 0.6880 - accuracy: 0.5506 - val_loss: 0.6974 - val_accuracy: 0.5123 - 370ms/epoch - 11ms/step
# Epoch 42/10000
# 35/35 - 0s - loss: 0.6850 - accuracy: 0.5499 - val_loss: 0.6935 - val_accuracy: 0.5080 - 373ms/epoch - 11ms/step
# Epoch 43/10000
# 35/35 - 0s - loss: 0.6896 - accuracy: 0.5401 - val_loss: 0.6980 - val_accuracy: 0.4848 - 372ms/epoch - 11ms/step
# Epoch 44/10000
# 35/35 - 0s - loss: 0.6841 - accuracy: 0.5593 - val_loss: 0.6964 - val_accuracy: 0.5225 - 369ms/epoch - 11ms/step
# Epoch 45/10000
# 35/35 - 0s - loss: 0.6848 - accuracy: 0.5517 - val_loss: 0.7008 - val_accuracy: 0.5036 - 368ms/epoch - 11ms/step
# Epoch 46/10000
# 35/35 - 0s - loss: 0.6884 - accuracy: 0.5466 - val_loss: 0.6942 - val_accuracy: 0.5196 - 374ms/epoch - 11ms/step
# Epoch 47/10000
# 35/35 - 0s - loss: 0.6859 - accuracy: 0.5597 - val_loss: 0.6940 - val_accuracy: 0.4993 - 408ms/epoch - 12ms/step
# Epoch 48/10000
# 35/35 - 0s - loss: 0.6840 - accuracy: 0.5546 - val_loss: 0.6989 - val_accuracy: 0.5167 - 409ms/epoch - 12ms/step
# Epoch 49/10000
# 35/35 - 0s - loss: 0.6825 - accuracy: 0.5615 - val_loss: 0.6941 - val_accuracy: 0.5051 - 389ms/epoch - 11ms/step
# Epoch 50/10000
# 35/35 - 0s - loss: 0.6825 - accuracy: 0.5691 - val_loss: 0.6930 - val_accuracy: 0.5123 - 375ms/epoch - 11ms/step
# Epoch 51/10000
# 35/35 - 0s - loss: 0.6828 - accuracy: 0.5532 - val_loss: 0.6956 - val_accuracy: 0.4775 - 374ms/epoch - 11ms/step
# Epoch 52/10000
# 35/35 - 0s - loss: 0.6842 - accuracy: 0.5441 - val_loss: 0.6933 - val_accuracy: 0.4964 - 368ms/epoch - 11ms/step
# Epoch 53/10000
# 35/35 - 0s - loss: 0.6832 - accuracy: 0.5546 - val_loss: 0.7015 - val_accuracy: 0.5239 - 377ms/epoch - 11ms/step
# Epoch 54/10000
# 35/35 - 0s - loss: 0.6845 - accuracy: 0.5575 - val_loss: 0.6943 - val_accuracy: 0.5138 - 379ms/epoch - 11ms/step
# Epoch 55/10000
# 35/35 - 0s - loss: 0.6851 - accuracy: 0.5597 - val_loss: 0.6927 - val_accuracy: 0.5239 - 381ms/epoch - 11ms/step
# Epoch 56/10000
# 35/35 - 0s - loss: 0.6816 - accuracy: 0.5525 - val_loss: 0.6954 - val_accuracy: 0.4775 - 373ms/epoch - 11ms/step
# Epoch 57/10000
# 35/35 - 0s - loss: 0.6794 - accuracy: 0.5742 - val_loss: 0.6941 - val_accuracy: 0.5239 - 365ms/epoch - 10ms/step
# Epoch 58/10000
# 35/35 - 0s - loss: 0.6789 - accuracy: 0.5742 - val_loss: 0.6946 - val_accuracy: 0.4920 - 366ms/epoch - 10ms/step
# Epoch 59/10000
# 35/35 - 0s - loss: 0.6804 - accuracy: 0.5655 - val_loss: 0.7056 - val_accuracy: 0.5065 - 392ms/epoch - 11ms/step
# Epoch 60/10000
# 35/35 - 0s - loss: 0.6812 - accuracy: 0.5612 - val_loss: 0.6944 - val_accuracy: 0.4775 - 378ms/epoch - 11ms/step
# Epoch 61/10000
# 35/35 - 0s - loss: 0.6836 - accuracy: 0.5557 - val_loss: 0.6997 - val_accuracy: 0.4819 - 380ms/epoch - 11ms/step
# Epoch 62/10000
# 35/35 - 0s - loss: 0.6800 - accuracy: 0.5721 - val_loss: 0.6936 - val_accuracy: 0.5123 - 373ms/epoch - 11ms/step
# Epoch 63/10000
# 35/35 - 0s - loss: 0.6790 - accuracy: 0.5728 - val_loss: 0.6945 - val_accuracy: 0.5065 - 386ms/epoch - 11ms/step
# Epoch 64/10000
# 35/35 - 0s - loss: 0.6764 - accuracy: 0.5844 - val_loss: 0.6931 - val_accuracy: 0.5181 - 370ms/epoch - 11ms/step
# Epoch 65/10000
# 35/35 - 0s - loss: 0.6763 - accuracy: 0.5746 - val_loss: 0.6946 - val_accuracy: 0.5181 - 382ms/epoch - 11ms/step
# Epoch 66/10000
# 35/35 - 0s - loss: 0.6740 - accuracy: 0.5710 - val_loss: 0.6941 - val_accuracy: 0.4746 - 378ms/epoch - 11ms/step
# Epoch 67/10000
# 35/35 - 0s - loss: 0.6791 - accuracy: 0.5728 - val_loss: 0.6967 - val_accuracy: 0.4775 - 381ms/epoch - 11ms/step
# Epoch 68/10000
# 35/35 - 0s - loss: 0.6765 - accuracy: 0.5713 - val_loss: 0.6946 - val_accuracy: 0.5181 - 386ms/epoch - 11ms/step
# Epoch 69/10000
# 35/35 - 0s - loss: 0.6747 - accuracy: 0.5815 - val_loss: 0.6976 - val_accuracy: 0.4949 - 386ms/epoch - 11ms/step
# Epoch 70/10000
# 35/35 - 0s - loss: 0.6700 - accuracy: 0.5858 - val_loss: 0.6973 - val_accuracy: 0.4891 - 377ms/epoch - 11ms/step
# Epoch 71/10000
# 35/35 - 0s - loss: 0.6777 - accuracy: 0.5753 - val_loss: 0.6933 - val_accuracy: 0.5109 - 370ms/epoch - 11ms/step
# Epoch 72/10000
# 35/35 - 0s - loss: 0.6745 - accuracy: 0.5742 - val_loss: 0.6945 - val_accuracy: 0.5254 - 377ms/epoch - 11ms/step
# Epoch 73/10000
# 35/35 - 0s - loss: 0.6779 - accuracy: 0.5804 - val_loss: 0.6939 - val_accuracy: 0.4935 - 374ms/epoch - 11ms/step
# Epoch 74/10000
# 35/35 - 0s - loss: 0.6830 - accuracy: 0.5644 - val_loss: 0.6976 - val_accuracy: 0.5138 - 371ms/epoch - 11ms/step
# Epoch 75/10000
# 35/35 - 0s - loss: 0.6832 - accuracy: 0.5742 - val_loss: 0.7363 - val_accuracy: 0.5138 - 380ms/epoch - 11ms/step
# Epoch 76/10000
# 35/35 - 0s - loss: 0.6836 - accuracy: 0.5670 - val_loss: 0.7470 - val_accuracy: 0.5181 - 381ms/epoch - 11ms/step
# Epoch 77/10000
# 35/35 - 0s - loss: 0.6800 - accuracy: 0.5746 - val_loss: 0.7481 - val_accuracy: 0.5225 - 374ms/epoch - 11ms/step
# Epoch 78/10000
# 35/35 - 0s - loss: 0.6745 - accuracy: 0.5877 - val_loss: 0.7920 - val_accuracy: 0.5196 - 376ms/epoch - 11ms/step
# Epoch 79/10000
# 35/35 - 0s - loss: 0.6759 - accuracy: 0.5862 - val_loss: 0.8168 - val_accuracy: 0.5167 - 377ms/epoch - 11ms/step
# Epoch 80/10000
# 35/35 - 0s - loss: 0.6769 - accuracy: 0.5721 - val_loss: 0.8397 - val_accuracy: 0.4906 - 381ms/epoch - 11ms/step
# Epoch 81/10000
# 35/35 - 0s - loss: 0.6803 - accuracy: 0.5666 - val_loss: 0.8631 - val_accuracy: 0.5167 - 374ms/epoch - 11ms/step
# 27/27 [==============================] - 0s 2ms/step
# train_X Shape: (3444, 10, 2)
# train_y Shape: (3444, 2)
# test_X Shape: (862, 10, 2)
# test_y Shape: (862,)
# Epoch 1/10000
# 35/35 - 2s - loss: 0.7390 - accuracy: 0.4882 - val_loss: 0.6933 - val_accuracy: 0.4891 - 2s/epoch - 49ms/step
# Epoch 2/10000
# 35/35 - 0s - loss: 0.7032 - accuracy: 0.5085 - val_loss: 0.6929 - val_accuracy: 0.5109 - 352ms/epoch - 10ms/step
# Epoch 3/10000
# 35/35 - 0s - loss: 0.7012 - accuracy: 0.5002 - val_loss: 0.6929 - val_accuracy: 0.5109 - 355ms/epoch - 10ms/step
# Epoch 4/10000
# 35/35 - 0s - loss: 0.7021 - accuracy: 0.4995 - val_loss: 0.6930 - val_accuracy: 0.5109 - 376ms/epoch - 11ms/step
# Epoch 5/10000
# 35/35 - 0s - loss: 0.6975 - accuracy: 0.5013 - val_loss: 0.6938 - val_accuracy: 0.5109 - 382ms/epoch - 11ms/step
# Epoch 6/10000
# 35/35 - 0s - loss: 0.7009 - accuracy: 0.4940 - val_loss: 0.6929 - val_accuracy: 0.5109 - 372ms/epoch - 11ms/step
# Epoch 7/10000
# 35/35 - 0s - loss: 0.6955 - accuracy: 0.5005 - val_loss: 0.6930 - val_accuracy: 0.5109 - 374ms/epoch - 11ms/step
# Epoch 8/10000
# 35/35 - 0s - loss: 0.7022 - accuracy: 0.4969 - val_loss: 0.6931 - val_accuracy: 0.5109 - 368ms/epoch - 11ms/step
# Epoch 9/10000
# 35/35 - 0s - loss: 0.6982 - accuracy: 0.4973 - val_loss: 0.6933 - val_accuracy: 0.5138 - 374ms/epoch - 11ms/step
# Epoch 10/10000
# 35/35 - 0s - loss: 0.6983 - accuracy: 0.4868 - val_loss: 0.6928 - val_accuracy: 0.5080 - 374ms/epoch - 11ms/step
# Epoch 11/10000
# 35/35 - 0s - loss: 0.6962 - accuracy: 0.5064 - val_loss: 0.6938 - val_accuracy: 0.4775 - 373ms/epoch - 11ms/step
# Epoch 12/10000
# 35/35 - 0s - loss: 0.6967 - accuracy: 0.4958 - val_loss: 0.6924 - val_accuracy: 0.5022 - 382ms/epoch - 11ms/step
# Epoch 13/10000
# 35/35 - 0s - loss: 0.6942 - accuracy: 0.5100 - val_loss: 0.6928 - val_accuracy: 0.5138 - 364ms/epoch - 10ms/step
# Epoch 14/10000
# 35/35 - 0s - loss: 0.6938 - accuracy: 0.5005 - val_loss: 0.6936 - val_accuracy: 0.5109 - 369ms/epoch - 11ms/step
# Epoch 15/10000
# 35/35 - 0s - loss: 0.6938 - accuracy: 0.5082 - val_loss: 0.6930 - val_accuracy: 0.5065 - 367ms/epoch - 10ms/step
# Epoch 16/10000
# 35/35 - 0s - loss: 0.6921 - accuracy: 0.5292 - val_loss: 0.6975 - val_accuracy: 0.5385 - 370ms/epoch - 11ms/step
# Epoch 17/10000
# 35/35 - 0s - loss: 0.6937 - accuracy: 0.5289 - val_loss: 0.6942 - val_accuracy: 0.4717 - 379ms/epoch - 11ms/step
# Epoch 18/10000
# 35/35 - 0s - loss: 0.6947 - accuracy: 0.5129 - val_loss: 0.6951 - val_accuracy: 0.5269 - 373ms/epoch - 11ms/step
# Epoch 19/10000
# 35/35 - 0s - loss: 0.6951 - accuracy: 0.5216 - val_loss: 0.6948 - val_accuracy: 0.5225 - 375ms/epoch - 11ms/step
# Epoch 20/10000
# 35/35 - 0s - loss: 0.6937 - accuracy: 0.5183 - val_loss: 0.6948 - val_accuracy: 0.5298 - 492ms/epoch - 14ms/step
# Epoch 21/10000
# 35/35 - 0s - loss: 0.6947 - accuracy: 0.5241 - val_loss: 0.6954 - val_accuracy: 0.5109 - 369ms/epoch - 11ms/step
# Epoch 22/10000
# 35/35 - 0s - loss: 0.6899 - accuracy: 0.5372 - val_loss: 0.6963 - val_accuracy: 0.5152 - 374ms/epoch - 11ms/step
# Epoch 23/10000
# 35/35 - 0s - loss: 0.6937 - accuracy: 0.5209 - val_loss: 0.6940 - val_accuracy: 0.5269 - 369ms/epoch - 11ms/step
# Epoch 24/10000
# 35/35 - 0s - loss: 0.6923 - accuracy: 0.5223 - val_loss: 0.6963 - val_accuracy: 0.5181 - 372ms/epoch - 11ms/step
# Epoch 25/10000
# 35/35 - 0s - loss: 0.6921 - accuracy: 0.5216 - val_loss: 0.6984 - val_accuracy: 0.5051 - 368ms/epoch - 11ms/step
# Epoch 26/10000
# 35/35 - 0s - loss: 0.6919 - accuracy: 0.5299 - val_loss: 0.6971 - val_accuracy: 0.5152 - 365ms/epoch - 10ms/step
# Epoch 27/10000
# 35/35 - 0s - loss: 0.6916 - accuracy: 0.5328 - val_loss: 0.6955 - val_accuracy: 0.5138 - 386ms/epoch - 11ms/step
# Epoch 28/10000
# 35/35 - 0s - loss: 0.6918 - accuracy: 0.5205 - val_loss: 0.6982 - val_accuracy: 0.5239 - 383ms/epoch - 11ms/step
# Epoch 29/10000
# 35/35 - 0s - loss: 0.6890 - accuracy: 0.5448 - val_loss: 0.6995 - val_accuracy: 0.5298 - 379ms/epoch - 11ms/step
# Epoch 30/10000
# 35/35 - 0s - loss: 0.6924 - accuracy: 0.5187 - val_loss: 0.6945 - val_accuracy: 0.5152 - 376ms/epoch - 11ms/step
# Epoch 31/10000
# 35/35 - 0s - loss: 0.6890 - accuracy: 0.5423 - val_loss: 0.6988 - val_accuracy: 0.5298 - 378ms/epoch - 11ms/step
# Epoch 32/10000
# 35/35 - 0s - loss: 0.6865 - accuracy: 0.5503 - val_loss: 0.7275 - val_accuracy: 0.5152 - 380ms/epoch - 11ms/step
# Epoch 33/10000
# 35/35 - 0s - loss: 0.6900 - accuracy: 0.5492 - val_loss: 0.6988 - val_accuracy: 0.5196 - 374ms/epoch - 11ms/step
# Epoch 34/10000
# 35/35 - 0s - loss: 0.6891 - accuracy: 0.5365 - val_loss: 0.7261 - val_accuracy: 0.5065 - 377ms/epoch - 11ms/step
# Epoch 35/10000
# 35/35 - 0s - loss: 0.6896 - accuracy: 0.5328 - val_loss: 0.7025 - val_accuracy: 0.5254 - 376ms/epoch - 11ms/step
# Epoch 36/10000
# 35/35 - 0s - loss: 0.6903 - accuracy: 0.5310 - val_loss: 0.7143 - val_accuracy: 0.5181 - 404ms/epoch - 12ms/step
# Epoch 37/10000
# 35/35 - 0s - loss: 0.6917 - accuracy: 0.5260 - val_loss: 0.7014 - val_accuracy: 0.5254 - 379ms/epoch - 11ms/step
# Epoch 38/10000
# 35/35 - 0s - loss: 0.6914 - accuracy: 0.5274 - val_loss: 0.7005 - val_accuracy: 0.4688 - 384ms/epoch - 11ms/step
# Epoch 39/10000
# 35/35 - 0s - loss: 0.6924 - accuracy: 0.5270 - val_loss: 0.6924 - val_accuracy: 0.5167 - 380ms/epoch - 11ms/step
# Epoch 40/10000
# 35/35 - 0s - loss: 0.6894 - accuracy: 0.5299 - val_loss: 0.6959 - val_accuracy: 0.4978 - 377ms/epoch - 11ms/step
# Epoch 41/10000
# 35/35 - 0s - loss: 0.6912 - accuracy: 0.5234 - val_loss: 0.6937 - val_accuracy: 0.5181 - 380ms/epoch - 11ms/step
# Epoch 42/10000
# 35/35 - 0s - loss: 0.6915 - accuracy: 0.5321 - val_loss: 0.6927 - val_accuracy: 0.5239 - 385ms/epoch - 11ms/step
# Epoch 43/10000
# 35/35 - 0s - loss: 0.6905 - accuracy: 0.5397 - val_loss: 0.6927 - val_accuracy: 0.5196 - 388ms/epoch - 11ms/step
# Epoch 44/10000
# 35/35 - 0s - loss: 0.6888 - accuracy: 0.5416 - val_loss: 0.6939 - val_accuracy: 0.4920 - 382ms/epoch - 11ms/step
# Epoch 45/10000
# 35/35 - 0s - loss: 0.6843 - accuracy: 0.5539 - val_loss: 0.6936 - val_accuracy: 0.5370 - 386ms/epoch - 11ms/step
# Epoch 46/10000
# 35/35 - 0s - loss: 0.6898 - accuracy: 0.5419 - val_loss: 0.6936 - val_accuracy: 0.5298 - 382ms/epoch - 11ms/step
# Epoch 47/10000
# 35/35 - 0s - loss: 0.6875 - accuracy: 0.5514 - val_loss: 0.6955 - val_accuracy: 0.5225 - 389ms/epoch - 11ms/step
# Epoch 48/10000
# 35/35 - 0s - loss: 0.6863 - accuracy: 0.5470 - val_loss: 0.6988 - val_accuracy: 0.5109 - 372ms/epoch - 11ms/step
# Epoch 49/10000
# 35/35 - 0s - loss: 0.6831 - accuracy: 0.5655 - val_loss: 0.7015 - val_accuracy: 0.5254 - 376ms/epoch - 11ms/step
# Epoch 50/10000
# 35/35 - 0s - loss: 0.6845 - accuracy: 0.5593 - val_loss: 0.7034 - val_accuracy: 0.5094 - 370ms/epoch - 11ms/step
# Epoch 51/10000
# 35/35 - 0s - loss: 0.6867 - accuracy: 0.5564 - val_loss: 0.6978 - val_accuracy: 0.5080 - 381ms/epoch - 11ms/step
# Epoch 52/10000
# 35/35 - 0s - loss: 0.6846 - accuracy: 0.5572 - val_loss: 0.6994 - val_accuracy: 0.5123 - 376ms/epoch - 11ms/step
# Epoch 53/10000
# 35/35 - 0s - loss: 0.6847 - accuracy: 0.5528 - val_loss: 0.7137 - val_accuracy: 0.5036 - 380ms/epoch - 11ms/step
# Epoch 54/10000
# 35/35 - 0s - loss: 0.6831 - accuracy: 0.5543 - val_loss: 0.6967 - val_accuracy: 0.5210 - 380ms/epoch - 11ms/step
# Epoch 55/10000
# 35/35 - 0s - loss: 0.6816 - accuracy: 0.5713 - val_loss: 0.7007 - val_accuracy: 0.5007 - 375ms/epoch - 11ms/step
# Epoch 56/10000
# 35/35 - 0s - loss: 0.6830 - accuracy: 0.5557 - val_loss: 0.7086 - val_accuracy: 0.5196 - 377ms/epoch - 11ms/step
# Epoch 57/10000
# 35/35 - 0s - loss: 0.6824 - accuracy: 0.5655 - val_loss: 0.7018 - val_accuracy: 0.4978 - 387ms/epoch - 11ms/step
# Epoch 58/10000
# 35/35 - 0s - loss: 0.6804 - accuracy: 0.5681 - val_loss: 0.6965 - val_accuracy: 0.4920 - 379ms/epoch - 11ms/step
# Epoch 59/10000
# 35/35 - 0s - loss: 0.6820 - accuracy: 0.5731 - val_loss: 0.6986 - val_accuracy: 0.5254 - 381ms/epoch - 11ms/step
# Epoch 60/10000
# 35/35 - 0s - loss: 0.6800 - accuracy: 0.5637 - val_loss: 0.7017 - val_accuracy: 0.5094 - 377ms/epoch - 11ms/step
# Epoch 61/10000
# 35/35 - 0s - loss: 0.6785 - accuracy: 0.5644 - val_loss: 0.7154 - val_accuracy: 0.5196 - 410ms/epoch - 12ms/step
# Epoch 62/10000
# 35/35 - 0s - loss: 0.6768 - accuracy: 0.5771 - val_loss: 0.7071 - val_accuracy: 0.4906 - 414ms/epoch - 12ms/step
# Epoch 63/10000
# 35/35 - 0s - loss: 0.6780 - accuracy: 0.5811 - val_loss: 0.6988 - val_accuracy: 0.5239 - 376ms/epoch - 11ms/step
# Epoch 64/10000
# 35/35 - 0s - loss: 0.6767 - accuracy: 0.5775 - val_loss: 0.7200 - val_accuracy: 0.4993 - 379ms/epoch - 11ms/step
# Epoch 65/10000
# 35/35 - 0s - loss: 0.6778 - accuracy: 0.5757 - val_loss: 0.7012 - val_accuracy: 0.5065 - 398ms/epoch - 11ms/step
# Epoch 66/10000
# 35/35 - 0s - loss: 0.6733 - accuracy: 0.5877 - val_loss: 0.7181 - val_accuracy: 0.4819 - 382ms/epoch - 11ms/step
# Epoch 67/10000
# 35/35 - 0s - loss: 0.6717 - accuracy: 0.5793 - val_loss: 0.7046 - val_accuracy: 0.5152 - 375ms/epoch - 11ms/step
# Epoch 68/10000
# 35/35 - 0s - loss: 0.6727 - accuracy: 0.5833 - val_loss: 0.6951 - val_accuracy: 0.4949 - 378ms/epoch - 11ms/step
# Epoch 69/10000
# 35/35 - 0s - loss: 0.6738 - accuracy: 0.5902 - val_loss: 0.7208 - val_accuracy: 0.4920 - 380ms/epoch - 11ms/step
# Epoch 70/10000
# 35/35 - 0s - loss: 0.6710 - accuracy: 0.5775 - val_loss: 0.7057 - val_accuracy: 0.5007 - 372ms/epoch - 11ms/step
# Epoch 71/10000
# 35/35 - 0s - loss: 0.6713 - accuracy: 0.5935 - val_loss: 0.7029 - val_accuracy: 0.5312 - 374ms/epoch - 11ms/step
# Epoch 72/10000
# 35/35 - 0s - loss: 0.6725 - accuracy: 0.5942 - val_loss: 0.7018 - val_accuracy: 0.5123 - 386ms/epoch - 11ms/step
# Epoch 73/10000
# 35/35 - 0s - loss: 0.6688 - accuracy: 0.5938 - val_loss: 0.6991 - val_accuracy: 0.5196 - 392ms/epoch - 11ms/step
# Epoch 74/10000
# 35/35 - 0s - loss: 0.6725 - accuracy: 0.5924 - val_loss: 0.7162 - val_accuracy: 0.4891 - 382ms/epoch - 11ms/step
# Epoch 75/10000
# 35/35 - 0s - loss: 0.6712 - accuracy: 0.5855 - val_loss: 0.7004 - val_accuracy: 0.4688 - 379ms/epoch - 11ms/step
# Epoch 76/10000
# 35/35 - 0s - loss: 0.6718 - accuracy: 0.5956 - val_loss: 0.7014 - val_accuracy: 0.4862 - 384ms/epoch - 11ms/step
# Epoch 77/10000
# 35/35 - 0s - loss: 0.6622 - accuracy: 0.6073 - val_loss: 0.7105 - val_accuracy: 0.4993 - 380ms/epoch - 11ms/step
# Epoch 78/10000
# 35/35 - 0s - loss: 0.6651 - accuracy: 0.6011 - val_loss: 0.7006 - val_accuracy: 0.4993 - 377ms/epoch - 11ms/step
# Epoch 79/10000
# 35/35 - 0s - loss: 0.6701 - accuracy: 0.5989 - val_loss: 0.7072 - val_accuracy: 0.5051 - 379ms/epoch - 11ms/step
# Epoch 80/10000
# 35/35 - 0s - loss: 0.6598 - accuracy: 0.6054 - val_loss: 0.7199 - val_accuracy: 0.4978 - 386ms/epoch - 11ms/step
# Epoch 81/10000
# 35/35 - 0s - loss: 0.6666 - accuracy: 0.5960 - val_loss: 0.7072 - val_accuracy: 0.5181 - 375ms/epoch - 11ms/step
# Epoch 82/10000
# 35/35 - 0s - loss: 0.6590 - accuracy: 0.6120 - val_loss: 0.7165 - val_accuracy: 0.5138 - 382ms/epoch - 11ms/step
# Epoch 83/10000
# 35/35 - 0s - loss: 0.6625 - accuracy: 0.5942 - val_loss: 0.6995 - val_accuracy: 0.4978 - 393ms/epoch - 11ms/step
# Epoch 84/10000
# 35/35 - 0s - loss: 0.6670 - accuracy: 0.5935 - val_loss: 0.7288 - val_accuracy: 0.4746 - 488ms/epoch - 14ms/step
# Epoch 85/10000
# 35/35 - 0s - loss: 0.6586 - accuracy: 0.6040 - val_loss: 0.7166 - val_accuracy: 0.5109 - 448ms/epoch - 13ms/step
# Epoch 86/10000
# 35/35 - 0s - loss: 0.6591 - accuracy: 0.6094 - val_loss: 0.7148 - val_accuracy: 0.4906 - 357ms/epoch - 10ms/step
# Epoch 87/10000
# 35/35 - 0s - loss: 0.6574 - accuracy: 0.6047 - val_loss: 0.7056 - val_accuracy: 0.5051 - 363ms/epoch - 10ms/step
# Epoch 88/10000
# 35/35 - 0s - loss: 0.6582 - accuracy: 0.6000 - val_loss: 0.7323 - val_accuracy: 0.4978 - 372ms/epoch - 11ms/step
# Epoch 89/10000
# 35/35 - 0s - loss: 0.6621 - accuracy: 0.5927 - val_loss: 0.7165 - val_accuracy: 0.5167 - 365ms/epoch - 10ms/step
# 27/27 [==============================] - 0s 2ms/step
# train_X Shape: (3444, 10, 2)
# train_y Shape: (3444, 2)
# test_X Shape: (862, 10, 2)
# test_y Shape: (862,)
# Epoch 1/10000
# 35/35 - 2s - loss: 0.7380 - accuracy: 0.5064 - val_loss: 0.6936 - val_accuracy: 0.4891 - 2s/epoch - 52ms/step
# Epoch 2/10000
# 35/35 - 0s - loss: 0.7019 - accuracy: 0.4973 - val_loss: 0.6933 - val_accuracy: 0.5109 - 349ms/epoch - 10ms/step
# Epoch 3/10000
# 35/35 - 0s - loss: 0.7101 - accuracy: 0.4784 - val_loss: 0.6934 - val_accuracy: 0.4891 - 342ms/epoch - 10ms/step
# Epoch 4/10000
# 35/35 - 0s - loss: 0.6986 - accuracy: 0.4915 - val_loss: 0.6929 - val_accuracy: 0.5109 - 370ms/epoch - 11ms/step
# Epoch 5/10000
# 35/35 - 0s - loss: 0.6957 - accuracy: 0.5209 - val_loss: 0.6963 - val_accuracy: 0.5109 - 365ms/epoch - 10ms/step
# Epoch 6/10000
# 35/35 - 0s - loss: 0.7025 - accuracy: 0.5042 - val_loss: 0.6945 - val_accuracy: 0.5109 - 356ms/epoch - 10ms/step
# Epoch 7/10000
# 35/35 - 0s - loss: 0.7013 - accuracy: 0.4838 - val_loss: 0.6935 - val_accuracy: 0.5109 - 360ms/epoch - 10ms/step
# Epoch 8/10000
# 35/35 - 0s - loss: 0.7003 - accuracy: 0.5013 - val_loss: 0.6942 - val_accuracy: 0.5109 - 365ms/epoch - 10ms/step
# Epoch 9/10000
# 35/35 - 0s - loss: 0.6985 - accuracy: 0.4947 - val_loss: 0.6936 - val_accuracy: 0.5109 - 361ms/epoch - 10ms/step
# Epoch 10/10000
# 35/35 - 0s - loss: 0.6961 - accuracy: 0.5165 - val_loss: 0.6937 - val_accuracy: 0.5109 - 363ms/epoch - 10ms/step
# Epoch 11/10000
# 35/35 - 0s - loss: 0.6948 - accuracy: 0.5122 - val_loss: 0.6925 - val_accuracy: 0.5327 - 354ms/epoch - 10ms/step
# Epoch 12/10000
# 35/35 - 0s - loss: 0.6950 - accuracy: 0.5107 - val_loss: 0.6942 - val_accuracy: 0.5007 - 358ms/epoch - 10ms/step
# Epoch 13/10000
# 35/35 - 0s - loss: 0.6961 - accuracy: 0.5067 - val_loss: 0.6957 - val_accuracy: 0.5181 - 368ms/epoch - 11ms/step
# Epoch 14/10000
# 35/35 - 0s - loss: 0.6958 - accuracy: 0.5107 - val_loss: 0.6941 - val_accuracy: 0.5109 - 360ms/epoch - 10ms/step
# Epoch 15/10000
# 35/35 - 0s - loss: 0.6949 - accuracy: 0.5122 - val_loss: 0.6964 - val_accuracy: 0.5167 - 361ms/epoch - 10ms/step
# Epoch 16/10000
# 35/35 - 0s - loss: 0.6966 - accuracy: 0.4995 - val_loss: 0.6926 - val_accuracy: 0.5254 - 364ms/epoch - 10ms/step
# Epoch 17/10000
# 35/35 - 0s - loss: 0.6961 - accuracy: 0.4976 - val_loss: 0.6927 - val_accuracy: 0.5152 - 371ms/epoch - 11ms/step
# Epoch 18/10000
# 35/35 - 0s - loss: 0.6946 - accuracy: 0.5064 - val_loss: 0.6916 - val_accuracy: 0.5428 - 379ms/epoch - 11ms/step
# Epoch 19/10000
# 35/35 - 0s - loss: 0.6943 - accuracy: 0.5180 - val_loss: 0.6932 - val_accuracy: 0.5239 - 370ms/epoch - 11ms/step
# Epoch 20/10000
# 35/35 - 0s - loss: 0.6952 - accuracy: 0.5045 - val_loss: 0.6944 - val_accuracy: 0.5065 - 354ms/epoch - 10ms/step
# Epoch 21/10000
# 35/35 - 0s - loss: 0.6955 - accuracy: 0.5132 - val_loss: 0.6926 - val_accuracy: 0.5254 - 357ms/epoch - 10ms/step
# Epoch 22/10000
# 35/35 - 0s - loss: 0.6916 - accuracy: 0.5303 - val_loss: 0.6954 - val_accuracy: 0.5298 - 359ms/epoch - 10ms/step
# Epoch 23/10000
# 35/35 - 0s - loss: 0.6912 - accuracy: 0.5281 - val_loss: 0.6965 - val_accuracy: 0.5443 - 349ms/epoch - 10ms/step
# Epoch 24/10000
# 35/35 - 0s - loss: 0.6935 - accuracy: 0.4976 - val_loss: 0.6966 - val_accuracy: 0.5239 - 351ms/epoch - 10ms/step
# Epoch 25/10000
# 35/35 - 0s - loss: 0.6932 - accuracy: 0.5256 - val_loss: 0.7000 - val_accuracy: 0.5210 - 349ms/epoch - 10ms/step
# Epoch 26/10000
# 35/35 - 0s - loss: 0.6905 - accuracy: 0.5220 - val_loss: 0.7032 - val_accuracy: 0.5210 - 369ms/epoch - 11ms/step
# Epoch 27/10000
# 35/35 - 0s - loss: 0.6945 - accuracy: 0.5187 - val_loss: 0.6924 - val_accuracy: 0.5269 - 355ms/epoch - 10ms/step
# Epoch 28/10000
# 35/35 - 0s - loss: 0.6925 - accuracy: 0.5143 - val_loss: 0.6974 - val_accuracy: 0.5327 - 363ms/epoch - 10ms/step
# Epoch 29/10000
# 35/35 - 0s - loss: 0.6931 - accuracy: 0.5299 - val_loss: 0.6956 - val_accuracy: 0.5225 - 366ms/epoch - 10ms/step
# Epoch 30/10000
# 35/35 - 0s - loss: 0.6926 - accuracy: 0.5292 - val_loss: 0.6942 - val_accuracy: 0.5283 - 363ms/epoch - 10ms/step
# Epoch 31/10000
# 35/35 - 0s - loss: 0.6913 - accuracy: 0.5318 - val_loss: 0.6948 - val_accuracy: 0.5254 - 373ms/epoch - 11ms/step
# Epoch 32/10000
# 35/35 - 0s - loss: 0.6901 - accuracy: 0.5325 - val_loss: 0.6974 - val_accuracy: 0.5254 - 362ms/epoch - 10ms/step
# Epoch 33/10000
# 35/35 - 0s - loss: 0.6926 - accuracy: 0.5321 - val_loss: 0.6945 - val_accuracy: 0.5254 - 360ms/epoch - 10ms/step
# Epoch 34/10000
# 35/35 - 0s - loss: 0.6909 - accuracy: 0.5234 - val_loss: 0.6931 - val_accuracy: 0.5138 - 361ms/epoch - 10ms/step
# Epoch 35/10000
# 35/35 - 0s - loss: 0.6921 - accuracy: 0.5230 - val_loss: 0.6920 - val_accuracy: 0.5210 - 364ms/epoch - 10ms/step
# Epoch 36/10000
# 35/35 - 0s - loss: 0.6912 - accuracy: 0.5343 - val_loss: 0.6944 - val_accuracy: 0.5123 - 364ms/epoch - 10ms/step
# Epoch 37/10000
# 35/35 - 0s - loss: 0.6886 - accuracy: 0.5354 - val_loss: 0.6945 - val_accuracy: 0.5196 - 365ms/epoch - 10ms/step
# Epoch 38/10000
# 35/35 - 0s - loss: 0.6913 - accuracy: 0.5354 - val_loss: 0.6932 - val_accuracy: 0.5225 - 365ms/epoch - 10ms/step
# Epoch 39/10000
# 35/35 - 0s - loss: 0.6891 - accuracy: 0.5376 - val_loss: 0.6956 - val_accuracy: 0.4906 - 359ms/epoch - 10ms/step
# Epoch 40/10000
# 35/35 - 0s - loss: 0.6874 - accuracy: 0.5441 - val_loss: 0.7005 - val_accuracy: 0.5254 - 364ms/epoch - 10ms/step
# Epoch 41/10000
# 35/35 - 0s - loss: 0.6894 - accuracy: 0.5437 - val_loss: 0.6995 - val_accuracy: 0.4949 - 363ms/epoch - 10ms/step
# Epoch 42/10000
# 35/35 - 0s - loss: 0.6886 - accuracy: 0.5510 - val_loss: 0.6924 - val_accuracy: 0.5181 - 364ms/epoch - 10ms/step
# Epoch 43/10000
# 35/35 - 0s - loss: 0.6878 - accuracy: 0.5456 - val_loss: 0.6941 - val_accuracy: 0.5225 - 364ms/epoch - 10ms/step
# Epoch 44/10000
# 35/35 - 0s - loss: 0.6882 - accuracy: 0.5485 - val_loss: 0.6929 - val_accuracy: 0.5181 - 357ms/epoch - 10ms/step
# Epoch 45/10000
# 35/35 - 0s - loss: 0.6880 - accuracy: 0.5521 - val_loss: 0.7038 - val_accuracy: 0.4746 - 361ms/epoch - 10ms/step
# Epoch 46/10000
# 35/35 - 0s - loss: 0.6891 - accuracy: 0.5459 - val_loss: 0.6959 - val_accuracy: 0.5210 - 368ms/epoch - 11ms/step
# Epoch 47/10000
# 35/35 - 0s - loss: 0.6866 - accuracy: 0.5608 - val_loss: 0.6942 - val_accuracy: 0.5138 - 360ms/epoch - 10ms/step
# Epoch 48/10000
# 35/35 - 0s - loss: 0.6853 - accuracy: 0.5532 - val_loss: 0.7017 - val_accuracy: 0.4833 - 368ms/epoch - 11ms/step
# Epoch 49/10000
# 35/35 - 0s - loss: 0.6859 - accuracy: 0.5412 - val_loss: 0.6962 - val_accuracy: 0.5152 - 366ms/epoch - 10ms/step
# Epoch 50/10000
# ...
# Epoch 62/10000
# 35/35 - 0s - loss: 0.6359 - accuracy: 0.6410 - val_loss: 0.8125 - val_accuracy: 0.4913 - 401ms/epoch - 11ms/step
# Epoch 63/10000
# 35/35 - 0s - loss: 0.6302 - accuracy: 0.6406 - val_loss: 0.9218 - val_accuracy: 0.5058 - 403ms/epoch - 12ms/step
# Epoch 64/10000
# 35/35 - 0s - loss: 0.6341 - accuracy: 0.6410 - val_loss: 0.9741 - val_accuracy: 0.5160 - 401ms/epoch - 11ms/step
# Epoch 65/10000
# 35/35 - 0s - loss: 0.6406 - accuracy: 0.6323 - val_loss: 0.7745 - val_accuracy: 0.4826 - 403ms/epoch - 12ms/step
# Epoch 66/10000
# 35/35 - 0s - loss: 0.6340 - accuracy: 0.6326 - val_loss: 0.9079 - val_accuracy: 0.4782 - 404ms/epoch - 12ms/step
# Epoch 67/10000
# 35/35 - 0s - loss: 0.6421 - accuracy: 0.6330 - val_loss: 0.8341 - val_accuracy: 0.5029 - 403ms/epoch - 12ms/step
# Epoch 68/10000
# 35/35 - 0s - loss: 0.6147 - accuracy: 0.6523 - val_loss: 1.1583 - val_accuracy: 0.5160 - 400ms/epoch - 11ms/step
# Epoch 69/10000
# 35/35 - 0s - loss: 0.6328 - accuracy: 0.6435 - val_loss: 1.3701 - val_accuracy: 0.4985 - 405ms/epoch - 12ms/step
# Epoch 70/10000
# 35/35 - 0s - loss: 0.6283 - accuracy: 0.6414 - val_loss: 1.0253 - val_accuracy: 0.4956 - 405ms/epoch - 12ms/step
# Epoch 71/10000
# 35/35 - 0s - loss: 0.6227 - accuracy: 0.6446 - val_loss: 2.0995 - val_accuracy: 0.5058 - 406ms/epoch - 12ms/step
# Epoch 72/10000
# 35/35 - 0s - loss: 0.6459 - accuracy: 0.6344 - val_loss: 1.0655 - val_accuracy: 0.4942 - 407ms/epoch - 12ms/step
# Epoch 73/10000
# 35/35 - 0s - loss: 0.6216 - accuracy: 0.6501 - val_loss: 0.9689 - val_accuracy: 0.5044 - 404ms/epoch - 12ms/step
# Epoch 74/10000
# 35/35 - 0s - loss: 0.6161 - accuracy: 0.6548 - val_loss: 1.4890 - val_accuracy: 0.4942 - 401ms/epoch - 11ms/step
# Epoch 75/10000
# 35/35 - 0s - loss: 0.6271 - accuracy: 0.6504 - val_loss: 1.5196 - val_accuracy: 0.4956 - 407ms/epoch - 12ms/step
# Epoch 76/10000
# 35/35 - 0s - loss: 0.6149 - accuracy: 0.6555 - val_loss: 1.7647 - val_accuracy: 0.5029 - 405ms/epoch - 12ms/step
# Epoch 77/10000
# 35/35 - 0s - loss: 0.6151 - accuracy: 0.6693 - val_loss: 1.5036 - val_accuracy: 0.4971 - 403ms/epoch - 12ms/step
# Epoch 78/10000
# 35/35 - 0s - loss: 0.6086 - accuracy: 0.6613 - val_loss: 1.6315 - val_accuracy: 0.5102 - 406ms/epoch - 12ms/step
# Epoch 79/10000
# 35/35 - 0s - loss: 0.6070 - accuracy: 0.6690 - val_loss: 1.4595 - val_accuracy: 0.4927 - 414ms/epoch - 12ms/step
# Epoch 80/10000
# 35/35 - 0s - loss: 0.6050 - accuracy: 0.6813 - val_loss: 1.5151 - val_accuracy: 0.5044 - 408ms/epoch - 12ms/step
# Epoch 81/10000
# 35/35 - 0s - loss: 0.6004 - accuracy: 0.6672 - val_loss: 2.3532 - val_accuracy: 0.5174 - 408ms/epoch - 12ms/step
# Epoch 82/10000
# 35/35 - 0s - loss: 0.6064 - accuracy: 0.6682 - val_loss: 1.9856 - val_accuracy: 0.5000 - 405ms/epoch - 12ms/step
# 27/27 [==============================] - 0s 2ms/step
# train_X Shape: (3440, 15, 2)
# train_y Shape: (3440, 2)
# test_X Shape: (861, 15, 2)
# test_y Shape: (861,)
# Epoch 1/10000
# 35/35 - 2s - loss: 0.7286 - accuracy: 0.5040 - val_loss: 0.6931 - val_accuracy: 0.5044 - 2s/epoch - 48ms/step
# Epoch 2/10000
# 35/35 - 0s - loss: 0.7055 - accuracy: 0.4996 - val_loss: 0.6936 - val_accuracy: 0.5044 - 376ms/epoch - 11ms/step
# Epoch 3/10000
# 35/35 - 0s - loss: 0.7024 - accuracy: 0.5015 - val_loss: 0.6931 - val_accuracy: 0.5044 - 380ms/epoch - 11ms/step
# Epoch 4/10000
# 35/35 - 0s - loss: 0.7010 - accuracy: 0.5069 - val_loss: 0.6930 - val_accuracy: 0.5044 - 389ms/epoch - 11ms/step
# Epoch 5/10000
# 35/35 - 0s - loss: 0.6981 - accuracy: 0.5080 - val_loss: 0.6934 - val_accuracy: 0.4956 - 401ms/epoch - 11ms/step
# Epoch 6/10000
# 35/35 - 0s - loss: 0.6961 - accuracy: 0.5185 - val_loss: 0.6970 - val_accuracy: 0.4956 - 393ms/epoch - 11ms/step
# Epoch 7/10000
# 35/35 - 0s - loss: 0.6960 - accuracy: 0.5193 - val_loss: 0.6935 - val_accuracy: 0.4942 - 403ms/epoch - 12ms/step
# Epoch 8/10000
# 35/35 - 0s - loss: 0.6973 - accuracy: 0.5087 - val_loss: 0.6933 - val_accuracy: 0.4971 - 402ms/epoch - 11ms/step
# Epoch 9/10000
# 35/35 - 0s - loss: 0.6966 - accuracy: 0.4967 - val_loss: 0.6941 - val_accuracy: 0.5102 - 397ms/epoch - 11ms/step
# Epoch 10/10000
# 35/35 - 0s - loss: 0.6947 - accuracy: 0.5138 - val_loss: 0.6960 - val_accuracy: 0.4956 - 403ms/epoch - 12ms/step
# Epoch 11/10000
# 35/35 - 0s - loss: 0.6942 - accuracy: 0.5145 - val_loss: 0.6939 - val_accuracy: 0.4956 - 410ms/epoch - 12ms/step
# Epoch 12/10000
# 35/35 - 0s - loss: 0.6930 - accuracy: 0.5273 - val_loss: 0.6923 - val_accuracy: 0.5189 - 406ms/epoch - 12ms/step
# Epoch 13/10000
# 35/35 - 0s - loss: 0.6906 - accuracy: 0.5182 - val_loss: 0.6922 - val_accuracy: 0.5131 - 415ms/epoch - 12ms/step
# Epoch 14/10000
# 35/35 - 0s - loss: 0.6914 - accuracy: 0.5203 - val_loss: 0.6940 - val_accuracy: 0.5044 - 392ms/epoch - 11ms/step
# Epoch 15/10000
# 35/35 - 0s - loss: 0.6911 - accuracy: 0.5302 - val_loss: 0.6917 - val_accuracy: 0.5247 - 386ms/epoch - 11ms/step
# Epoch 16/10000
# 35/35 - 0s - loss: 0.6898 - accuracy: 0.5331 - val_loss: 0.6939 - val_accuracy: 0.5131 - 402ms/epoch - 11ms/step
# Epoch 17/10000
# 35/35 - 0s - loss: 0.6854 - accuracy: 0.5520 - val_loss: 0.6927 - val_accuracy: 0.5189 - 401ms/epoch - 11ms/step
# Epoch 18/10000
# 35/35 - 0s - loss: 0.6894 - accuracy: 0.5581 - val_loss: 0.6913 - val_accuracy: 0.5305 - 400ms/epoch - 11ms/step
# Epoch 19/10000
# 35/35 - 0s - loss: 0.6886 - accuracy: 0.5320 - val_loss: 0.6911 - val_accuracy: 0.5320 - 401ms/epoch - 11ms/step
# Epoch 20/10000
# 35/35 - 0s - loss: 0.6892 - accuracy: 0.5385 - val_loss: 0.6902 - val_accuracy: 0.5363 - 400ms/epoch - 11ms/step
# Epoch 21/10000
# 35/35 - 0s - loss: 0.6864 - accuracy: 0.5461 - val_loss: 0.6913 - val_accuracy: 0.5131 - 400ms/epoch - 11ms/step
# Epoch 22/10000
# 35/35 - 0s - loss: 0.6886 - accuracy: 0.5338 - val_loss: 0.6934 - val_accuracy: 0.4971 - 401ms/epoch - 11ms/step
# Epoch 23/10000
# 35/35 - 0s - loss: 0.6854 - accuracy: 0.5516 - val_loss: 0.6919 - val_accuracy: 0.5145 - 399ms/epoch - 11ms/step
# Epoch 24/10000
# 35/35 - 0s - loss: 0.6897 - accuracy: 0.5320 - val_loss: 0.6938 - val_accuracy: 0.5160 - 400ms/epoch - 11ms/step
# Epoch 25/10000
# 35/35 - 0s - loss: 0.6851 - accuracy: 0.5570 - val_loss: 0.6906 - val_accuracy: 0.5203 - 405ms/epoch - 12ms/step
# Epoch 26/10000
# 35/35 - 0s - loss: 0.6855 - accuracy: 0.5505 - val_loss: 0.6934 - val_accuracy: 0.5073 - 407ms/epoch - 12ms/step
# Epoch 27/10000
# 35/35 - 0s - loss: 0.6829 - accuracy: 0.5563 - val_loss: 0.6930 - val_accuracy: 0.5131 - 401ms/epoch - 11ms/step
# Epoch 28/10000
# 35/35 - 0s - loss: 0.6842 - accuracy: 0.5425 - val_loss: 0.6922 - val_accuracy: 0.5189 - 448ms/epoch - 13ms/step
# Epoch 29/10000
# 35/35 - 0s - loss: 0.6857 - accuracy: 0.5592 - val_loss: 0.6925 - val_accuracy: 0.5145 - 419ms/epoch - 12ms/step
# Epoch 30/10000
# 35/35 - 0s - loss: 0.6808 - accuracy: 0.5665 - val_loss: 0.6917 - val_accuracy: 0.5116 - 397ms/epoch - 11ms/step
# Epoch 31/10000
# 35/35 - 0s - loss: 0.6828 - accuracy: 0.5465 - val_loss: 0.6943 - val_accuracy: 0.5174 - 400ms/epoch - 11ms/step
# Epoch 32/10000
# 35/35 - 0s - loss: 0.6794 - accuracy: 0.5698 - val_loss: 0.6894 - val_accuracy: 0.5233 - 411ms/epoch - 12ms/step
# Epoch 33/10000
# 35/35 - 0s - loss: 0.6830 - accuracy: 0.5549 - val_loss: 0.6920 - val_accuracy: 0.5160 - 405ms/epoch - 12ms/step
# Epoch 34/10000
# 35/35 - 0s - loss: 0.6765 - accuracy: 0.5734 - val_loss: 0.6940 - val_accuracy: 0.5203 - 402ms/epoch - 11ms/step
# Epoch 35/10000
# 35/35 - 0s - loss: 0.6769 - accuracy: 0.5701 - val_loss: 0.6913 - val_accuracy: 0.5174 - 399ms/epoch - 11ms/step
# Epoch 36/10000
# 35/35 - 0s - loss: 0.6825 - accuracy: 0.5520 - val_loss: 0.6932 - val_accuracy: 0.5218 - 392ms/epoch - 11ms/step
# Epoch 37/10000
# 35/35 - 0s - loss: 0.6805 - accuracy: 0.5723 - val_loss: 0.6919 - val_accuracy: 0.5291 - 394ms/epoch - 11ms/step
# Epoch 38/10000
# 35/35 - 0s - loss: 0.6736 - accuracy: 0.5908 - val_loss: 0.6916 - val_accuracy: 0.5131 - 390ms/epoch - 11ms/step
# Epoch 39/10000
# 35/35 - 0s - loss: 0.6722 - accuracy: 0.5803 - val_loss: 0.6910 - val_accuracy: 0.5291 - 392ms/epoch - 11ms/step
# Epoch 40/10000
# 35/35 - 0s - loss: 0.6667 - accuracy: 0.5807 - val_loss: 0.6927 - val_accuracy: 0.5145 - 393ms/epoch - 11ms/step
# Epoch 41/10000
# 35/35 - 0s - loss: 0.6787 - accuracy: 0.5614 - val_loss: 0.6903 - val_accuracy: 0.5291 - 392ms/epoch - 11ms/step
# Epoch 42/10000
# 35/35 - 0s - loss: 0.6772 - accuracy: 0.5832 - val_loss: 0.6921 - val_accuracy: 0.5276 - 392ms/epoch - 11ms/step
# Epoch 43/10000
# 35/35 - 0s - loss: 0.6698 - accuracy: 0.5930 - val_loss: 0.6917 - val_accuracy: 0.5349 - 394ms/epoch - 11ms/step
# Epoch 44/10000
# 35/35 - 0s - loss: 0.6736 - accuracy: 0.5839 - val_loss: 0.6929 - val_accuracy: 0.5247 - 402ms/epoch - 11ms/step
# Epoch 45/10000
# 35/35 - 0s - loss: 0.6682 - accuracy: 0.5934 - val_loss: 0.6926 - val_accuracy: 0.5102 - 403ms/epoch - 12ms/step
# Epoch 46/10000
# 35/35 - 0s - loss: 0.6722 - accuracy: 0.5868 - val_loss: 0.6919 - val_accuracy: 0.5160 - 404ms/epoch - 12ms/step
# Epoch 47/10000
# 35/35 - 0s - loss: 0.6661 - accuracy: 0.6065 - val_loss: 0.6891 - val_accuracy: 0.5523 - 397ms/epoch - 11ms/step
# Epoch 48/10000
# 35/35 - 0s - loss: 0.6624 - accuracy: 0.6170 - val_loss: 0.6953 - val_accuracy: 0.5233 - 397ms/epoch - 11ms/step
# Epoch 49/10000
# 35/35 - 0s - loss: 0.6693 - accuracy: 0.6065 - val_loss: 0.6916 - val_accuracy: 0.5145 - 398ms/epoch - 11ms/step
# Epoch 50/10000
# 35/35 - 0s - loss: 0.6641 - accuracy: 0.6014 - val_loss: 0.6929 - val_accuracy: 0.5145 - 399ms/epoch - 11ms/step
# Epoch 51/10000
# 35/35 - 0s - loss: 0.6729 - accuracy: 0.5799 - val_loss: 0.6928 - val_accuracy: 0.5015 - 409ms/epoch - 12ms/step
# Epoch 52/10000
# 35/35 - 0s - loss: 0.6776 - accuracy: 0.5832 - val_loss: 0.6912 - val_accuracy: 0.5305 - 400ms/epoch - 11ms/step
# Epoch 53/10000
# 35/35 - 0s - loss: 0.6802 - accuracy: 0.5661 - val_loss: 0.6926 - val_accuracy: 0.5203 - 397ms/epoch - 11ms/step
# Epoch 54/10000
# 35/35 - 0s - loss: 0.6708 - accuracy: 0.5803 - val_loss: 0.6919 - val_accuracy: 0.5233 - 396ms/epoch - 11ms/step
# Epoch 55/10000
# 35/35 - 0s - loss: 0.6803 - accuracy: 0.5796 - val_loss: 0.6993 - val_accuracy: 0.5073 - 397ms/epoch - 11ms/step
# Epoch 56/10000
# 35/35 - 0s - loss: 0.6783 - accuracy: 0.5745 - val_loss: 0.7604 - val_accuracy: 0.5087 - 402ms/epoch - 11ms/step
# Epoch 57/10000
# 35/35 - 0s - loss: 0.6784 - accuracy: 0.5825 - val_loss: 0.8100 - val_accuracy: 0.5015 - 402ms/epoch - 11ms/step
# Epoch 58/10000
# 35/35 - 0s - loss: 0.6795 - accuracy: 0.5730 - val_loss: 0.8874 - val_accuracy: 0.5203 - 402ms/epoch - 11ms/step
# Epoch 59/10000
# 35/35 - 0s - loss: 0.6765 - accuracy: 0.5912 - val_loss: 0.8451 - val_accuracy: 0.5174 - 404ms/epoch - 12ms/step
# Epoch 60/10000
# 35/35 - 0s - loss: 0.6746 - accuracy: 0.5923 - val_loss: 0.9049 - val_accuracy: 0.5102 - 408ms/epoch - 12ms/step
# Epoch 61/10000
# 35/35 - 0s - loss: 0.6748 - accuracy: 0.5988 - val_loss: 0.7579 - val_accuracy: 0.5247 - 405ms/epoch - 12ms/step
# Epoch 62/10000
# 35/35 - 0s - loss: 0.6652 - accuracy: 0.6163 - val_loss: 0.8057 - val_accuracy: 0.5015 - 404ms/epoch - 12ms/step
# Epoch 63/10000
# 35/35 - 0s - loss: 0.6646 - accuracy: 0.5898 - val_loss: 0.7908 - val_accuracy: 0.5000 - 402ms/epoch - 11ms/step
# Epoch 64/10000
# 35/35 - 0s - loss: 0.6649 - accuracy: 0.6079 - val_loss: 0.7940 - val_accuracy: 0.4971 - 404ms/epoch - 12ms/step
# Epoch 65/10000
# 35/35 - 0s - loss: 0.6532 - accuracy: 0.6170 - val_loss: 0.8568 - val_accuracy: 0.5044 - 402ms/epoch - 11ms/step
# Epoch 66/10000
# 35/35 - 0s - loss: 0.6445 - accuracy: 0.6348 - val_loss: 0.9490 - val_accuracy: 0.5029 - 405ms/epoch - 12ms/step
# Epoch 67/10000
# 35/35 - 0s - loss: 0.6487 - accuracy: 0.6272 - val_loss: 1.0879 - val_accuracy: 0.5044 - 404ms/epoch - 12ms/step
# Epoch 68/10000
# 35/35 - 0s - loss: 0.6470 - accuracy: 0.6348 - val_loss: 0.8941 - val_accuracy: 0.5174 - 404ms/epoch - 12ms/step
# Epoch 69/10000
# 35/35 - 0s - loss: 0.6497 - accuracy: 0.6370 - val_loss: 1.0197 - val_accuracy: 0.5044 - 399ms/epoch - 11ms/step
# Epoch 70/10000
# 35/35 - 0s - loss: 0.6451 - accuracy: 0.6286 - val_loss: 0.8413 - val_accuracy: 0.5189 - 393ms/epoch - 11ms/step
# Epoch 71/10000
# 35/35 - 0s - loss: 0.6366 - accuracy: 0.6403 - val_loss: 0.8003 - val_accuracy: 0.5174 - 401ms/epoch - 11ms/step
# Epoch 72/10000
# 35/35 - 0s - loss: 0.6378 - accuracy: 0.6439 - val_loss: 0.7972 - val_accuracy: 0.5174 - 404ms/epoch - 12ms/step
# Epoch 73/10000
# 35/35 - 0s - loss: 0.6372 - accuracy: 0.6410 - val_loss: 0.8753 - val_accuracy: 0.5058 - 415ms/epoch - 12ms/step
# Epoch 74/10000
# 35/35 - 0s - loss: 0.6387 - accuracy: 0.6363 - val_loss: 0.9018 - val_accuracy: 0.4971 - 405ms/epoch - 12ms/step
# Epoch 75/10000
# 35/35 - 0s - loss: 0.6292 - accuracy: 0.6421 - val_loss: 1.0148 - val_accuracy: 0.5233 - 402ms/epoch - 11ms/step
# Epoch 76/10000
# 35/35 - 0s - loss: 0.6285 - accuracy: 0.6537 - val_loss: 0.9135 - val_accuracy: 0.5058 - 405ms/epoch - 12ms/step
# Epoch 77/10000
# 35/35 - 0s - loss: 0.6196 - accuracy: 0.6508 - val_loss: 0.9170 - val_accuracy: 0.5203 - 403ms/epoch - 12ms/step
# Epoch 78/10000
# 35/35 - 0s - loss: 0.6116 - accuracy: 0.6650 - val_loss: 0.8973 - val_accuracy: 0.5073 - 404ms/epoch - 12ms/step
# Epoch 79/10000
# 35/35 - 0s - loss: 0.6115 - accuracy: 0.6519 - val_loss: 0.8329 - val_accuracy: 0.5174 - 399ms/epoch - 11ms/step
# Epoch 80/10000
# 35/35 - 0s - loss: 0.6119 - accuracy: 0.6697 - val_loss: 0.9979 - val_accuracy: 0.5276 - 401ms/epoch - 11ms/step
# Epoch 81/10000
# 35/35 - 0s - loss: 0.6156 - accuracy: 0.6533 - val_loss: 0.9477 - val_accuracy: 0.5145 - 401ms/epoch - 11ms/step
# Epoch 82/10000
# 35/35 - 0s - loss: 0.6139 - accuracy: 0.6675 - val_loss: 0.8219 - val_accuracy: 0.5174 - 393ms/epoch - 11ms/step
# Epoch 83/10000
# 35/35 - 0s - loss: 0.6114 - accuracy: 0.6708 - val_loss: 0.8167 - val_accuracy: 0.5087 - 389ms/epoch - 11ms/step
# Epoch 84/10000
# 35/35 - 0s - loss: 0.6079 - accuracy: 0.6748 - val_loss: 0.9842 - val_accuracy: 0.5015 - 389ms/epoch - 11ms/step
# Epoch 85/10000
# 35/35 - 0s - loss: 0.5960 - accuracy: 0.6853 - val_loss: 1.0521 - val_accuracy: 0.5029 - 400ms/epoch - 11ms/step
# Epoch 86/10000
# 35/35 - 0s - loss: 0.5932 - accuracy: 0.6842 - val_loss: 0.8325 - val_accuracy: 0.5233 - 397ms/epoch - 11ms/step
# Epoch 87/10000
# 35/35 - 0s - loss: 0.5928 - accuracy: 0.6737 - val_loss: 0.8752 - val_accuracy: 0.5102 - 399ms/epoch - 11ms/step
# Epoch 88/10000
# 35/35 - 0s - loss: 0.5895 - accuracy: 0.6871 - val_loss: 0.8265 - val_accuracy: 0.5203 - 400ms/epoch - 11ms/step
# Epoch 89/10000
# 35/35 - 0s - loss: 0.5806 - accuracy: 0.6933 - val_loss: 0.9514 - val_accuracy: 0.5102 - 397ms/epoch - 11ms/step
# Epoch 90/10000
# 35/35 - 0s - loss: 0.5843 - accuracy: 0.6908 - val_loss: 0.9068 - val_accuracy: 0.5145 - 396ms/epoch - 11ms/step
# Epoch 91/10000
# 35/35 - 0s - loss: 0.5721 - accuracy: 0.6999 - val_loss: 0.7898 - val_accuracy: 0.5203 - 395ms/epoch - 11ms/step
# Epoch 92/10000
# 35/35 - 0s - loss: 0.5795 - accuracy: 0.6879 - val_loss: 0.9360 - val_accuracy: 0.5233 - 398ms/epoch - 11ms/step
# Epoch 93/10000
# 35/35 - 0s - loss: 0.5805 - accuracy: 0.6973 - val_loss: 0.8747 - val_accuracy: 0.5160 - 416ms/epoch - 12ms/step
# Epoch 94/10000
# 35/35 - 0s - loss: 0.5685 - accuracy: 0.7028 - val_loss: 0.9463 - val_accuracy: 0.5189 - 402ms/epoch - 11ms/step
# Epoch 95/10000
# 35/35 - 0s - loss: 0.5594 - accuracy: 0.7195 - val_loss: 1.1681 - val_accuracy: 0.5378 - 402ms/epoch - 11ms/step
# Epoch 96/10000
# 35/35 - 0s - loss: 0.5754 - accuracy: 0.7108 - val_loss: 0.9037 - val_accuracy: 0.5189 - 420ms/epoch - 12ms/step
# Epoch 97/10000
# 35/35 - 0s - loss: 0.5720 - accuracy: 0.7035 - val_loss: 0.8392 - val_accuracy: 0.5087 - 392ms/epoch - 11ms/step
# 27/27 [==============================] - 0s 2ms/step
# /var/folders/vp/8_rd4_c56g3dpqb1167z6tqr0000gn/T/ipykernel_29292/3652587134.py:69: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append({"timestep": step,"features": data.columns.values,"google_trends_lag":g,"tweet_volume_lag": tv,"tweet_polarity_score_lag": tw_lag, "batch_size":b, "neurons":n,  "mean_down_f1_score":mean_down_f1_score,"mean_up_f1_score":mean_up_f1_score, "mean_acc": mean_acc,"min_acc":min_acc, "max_acc":max_acc, "diff_acc": diff_acc,"optimizer":my_optimizer,"month":month,"consecutive": flag}, ignore_index=True)

# %%
results.to_csv(filepath_out, index=False)
