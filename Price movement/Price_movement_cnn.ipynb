# %% [markdown]
# # CNN Model for price movement

# %%
import pandas as pd
import numpy as np
from datetime import datetime
import datetime
import sklearn
from sklearn.model_selection import train_test_split
from tensorflow.keras.utils import to_categorical
from sklearn.preprocessing import MinMaxScaler
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.utils import shuffle
import tensorflow as tf

import keras.utils
from keras.models import Sequential
from keras.layers import Convolution1D, Conv1D, ZeroPadding1D, MaxPooling1D, BatchNormalization, Activation, Dropout, Flatten, Dense
from keras.layers import Dropout
from keras.layers import Activation
from keras.layers import Bidirectional
from keras.layers import Dense
from keras.layers import LSTM
from keras.optimizers import Adam

from tensorflow.keras.optimizers import RMSprop
from sklearn.metrics import classification_report

# %%
def rename_datetime(data):
    data.rename(columns={'Unnamed: 0': 'datetime'},inplace=True)
    data['datetime']=pd.to_datetime(data['datetime'])
    data.set_index('datetime', inplace=True)
    return data
# feature selection
# create features
def create_features(data, g_lag, tv_lag, tw_lag):
    data['Change'] =data['Close'].diff().dropna()
    data['Label'] = np.where(data['Change']>0, 1 ,0)
    data['google_trends_lag']=data['google_trends'].shift(g_lag)
    data['tweet_volume_lag']=data['tweet_volume'].shift(tv_lag)
    data['tw_polarity_lag'] = data['tw_polarity'].shift(tw_lag)

    data.drop(columns=['Open','High','Low','Change'],inplace=True)
    # Add features like RSI? Moving average?

    data.dropna(inplace=True)
    return data
# keep the wanted features
def keep_features(feature_conditions):
    features=['Label','Close']
    for feature, condition in feature_conditions.items():
        if condition:
            features.append(feature)
    return features

# create the lagged features based on the timesteps
def reshape_features(data, to_keep=1, to_remove=1):
    variables = 1 if type(data) is list else data.shape[1]
    df = pd.DataFrame(data)
    columns, names = list(), list()

    for i in range(to_keep, 0, -1):
        columns.append(df.shift(i))
        names += [('var%d(t-%d)' % (j+1, i)) for j in range(variables)]

    for i in range(0, to_remove):
        columns.append(df.shift(-i))
        if i == 0:
            names += [('var%d(t)' % (j+1)) for j in range(variables)]
        else:
            names += [('var%d(t+%d)' % (j+1, i)) for j in range(variables)]

    #put it all together
    final = pd.concat(columns, axis=1)
    final.columns = names

    #drop rows with NaN values
    final.dropna(inplace=True)

    new_data = final.reset_index()

    new_data = new_data.drop(columns=['datetime'])

    return new_data

# shuffle the data
def shuffle_data(times, data):
    np.random.seed(1)
    for i in range(times+1):
        data=shuffle(data)
    return data

# split labels from data
def split_label(train, test):
    train_y = train['var1(t)'].values
    test_y = test['var1(t)'].values
    train_y = train_y.reshape(len(train_y), 1)
    test_y = test_y.reshape(len(test_y), 1)
    return train_y, test_y

# normalize data using Minmaxscaler
def normalize_reshape_data(train, test, train_y, test_y, all_features, n_features, timestep):
    feature_scaler=MinMaxScaler()
    scale_train_data=feature_scaler.fit_transform(train)
    scale_test_data= feature_scaler.transform(test)
    train = scale_train_data[:, :all_features]
    test = scale_test_data[:, :all_features]
    #keep only prices array
    train_X, train_y = train[:, :all_features], train_y[:, -1]
    test_X, test_y = test[:, :all_features], test_y[:, -1]
    # reshape the data
    train_X = train_X.reshape((train_X.shape[0], timestep, n_features))
    test_X = test_X.reshape((test_X.shape[0], timestep, n_features))
    #set labels for training data to categorical
    train_y = to_categorical(train_y, 2)

    return train_X, test_X, train_y, test_y

# %%
filepath='./../data/processed_data.csv'

# %%
def get_data(filepath, g_lag, tv_lag, tw_lag, timestep, shuffle_times, split_ratio, feature_conditions):
    # import data
    # import the original data. processed_data
    # processed_data: weighted reddit score+ fill the nan data
    data=pd.read_csv(filepath)
    # show the data
    data=rename_datetime(data)

    # create features
    data_created = create_features(data,g_lag,tv_lag,tw_lag)

    # keep the wanted features
    features = keep_features(feature_conditions)
    data=data_created[features]

    # reshape the data
    # create the lagged features based on the timesteps
    df_copy = data.copy()
    new_data=reshape_features(df_copy, timestep, 1)

    # shuffle the data
    shuffled_data=shuffle_data(shuffle_times, new_data)

    # split the data
    train, test= train_test_split(shuffled_data, test_size=split_ratio)
    train_y, test_y=split_label(train, test)

    # normalized the data using MinMaxscaler
    n_features=len(features)
    all_features = timestep * n_features
    if (all_features==0):
        all_features=n_features
    train_X, test_X, train_y, test_y =normalize_reshape_data(train, test, train_y, test_y, all_features, n_features,timestep)

    print("train_X Shape:", train_X.shape)
    print("train_y Shape:", train_y.shape)
    print("test_X Shape:", test_X.shape)
    print("test_y Shape:", test_y.shape)

    return data, train_X, test_X, train_y, test_y, n_features

# %%
# # get correlation matrix
# sns.heatmap(data.corr(), annot=True)
# plt.show()

# %% [markdown]
# ## Model Building

# %%
def create_model(neurons, epochs, dropout, batch_size, verbose, layers,
                 activ_func, activ_dense,my_optimizer,
                 train_X, train_y, test_X, test_y, n_features, timestep ):
    #set seed to reproduce results
    np.random.seed(1)
    tf.random.set_seed(1)

    # design network
    model = Sequential()

    #return sequences flag if there are more than 1 layer
    return_seq = layers > 1

    #add first layer
    model.add(Conv1D(neurons, kernel_size=2, padding='same', input_shape=(timestep, n_features), activation=activ_func))
    model.add(MaxPooling1D(pool_size=2, padding='same'))
    model.add(Dropout(dropout))

    #add the other layers
    for i in range(1, layers):
        model.add(Conv1D(neurons, kernel_size=2, padding='same', activation=activ_func))
        model.add(MaxPooling1D(pool_size=2, padding='same'))
        model.add(Dropout(dropout))

    #flatten and add a dense layer and to output the prediction
    model.add(Flatten())
    model.add(Dense(2, activation=activ_dense))
    model.compile(loss='categorical_crossentropy', optimizer=my_optimizer, metrics=['accuracy'])

    callback = keras.callbacks.EarlyStopping(monitor='val_loss', patience =50)

    # fit network
    history = model.fit(train_X, train_y, epochs=epochs, batch_size=batch_size, verbose=verbose, shuffle=False,validation_split=0.2, callbacks=[callback])

    #reshape
    test_X = test_X.reshape((test_X.shape[0], timestep, n_features))

    #make prediction
    pred = model.predict(test_X)

    #reshape again
    test_X = test_X.reshape((test_X.shape[0], timestep* n_features,))

    #get prediction
    y_pred = np.argmax(pred, axis=1)

    # calculate the metrics
    report=classification_report(
          test_y,
          y_pred,target_names = ["Down", "Up"],
          digits = 5, output_dict=True)

    # precision = report['Down']['precision']
    down_f1_score = report['Down']['f1-score']
    up_f1_score = report['Up']['f1-score']
    accuracy=report['accuracy']

    return down_f1_score, up_f1_score, accuracy

# %%
# model parameters

feature_conditions = {
        'google_trends': 0, 'google_trends_lag': 0,
        'tweet_volume_lag': 0, 'tw_polarity_lag': 0, 'tw_compound': 0,
        'tw_polarity': 0, 'tweet_volume': 0,'re_compound': 0,'re_polarity': 0,
        're_subjectivity': 0
    }
def test_model(filepath_out, feature_conditions):
    columns = ["timestep","features","google_trends_lag","tweet_volume_lag","tweet_polarity_score_lag", "batch_size", "neurons", "layers", "mean_down_f1_score","mean_up_f1_score", "mean_acc","min_acc", "max_acc", "diff_acc"]

    try:
        results = pd.read_csv(filepath_out)
    except:
        results = pd.DataFrame(columns=columns)

    #lagged_features
    timestep = [10,15]
    #train_ratio
    split_ratio =0.2
    shuffle_times = 3
    activ_func = "linear"
    activ_dense = 'softmax'
    my_optimizer = 'adam'
    # my_optimizer=RMSprop(lr=0.01, rho=0.9, epsilon=None, decay=0.0)
    epochs = 10000
     #for each lag feature
    for step in timestep:
        neurons = [32]
        layers = [1]
        batch_sizes = [200]
        dropout = 0.25
        verbose=2
        # Lags
        g_lag = [10]
        tv_lag = [28] # tweets volume
        tw_lag = 15 # tweets score

        #for each epoch, neuron, layers and batch_size value
        for n in neurons:
            for l in layers:
                for b in  batch_sizes:
                    print("Testing model: lag:", timestep, ", neurons:", n, ", layers:", l, ", batch_size:", b)
                    for g in g_lag:
                        for tv in tv_lag:
                            #run for 5 times
                            accuracies = []
                            down_f1_score =[]
                            up_f1_score = []
                            for i in range (0,10):
                                data, train_X, test_X, train_y, test_y, n_features = get_data(filepath, g, tv, tw_lag, step, shuffle_times, split_ratio, feature_conditions)
                                down_score, up_score, accuracy = create_model(n, epochs, dropout, b, verbose, l, activ_func, activ_dense,my_optimizer, train_X, train_y, test_X, test_y, n_features, step)
                                accuracies.append(accuracy)
                                down_f1_score.append(down_score)
                                up_f1_score.append(up_score)

                            #calculate mean values
                            accuracies = np.array(accuracies)
                            mean_acc =accuracies.mean()
                            min_acc =accuracies.min()
                            max_acc =accuracies.max()
                            diff_acc = max_acc - min_acc
                            mean_down_f1_score= np.array(down_f1_score).mean()
                            mean_up_f1_score=np.array(up_f1_score).mean()

                            results = results.append({"timestep": step,"features": data.columns.values,"google_trends_lag":g,"tweet_volume_lag": tv,"tweet_polarity_score_lag": tw_lag, "batch_size":b, "neurons":n, "layers":l, "mean_down_f1_score":mean_down_f1_score,"mean_up_f1_score":mean_up_f1_score, "mean_acc": mean_acc,"min_acc":min_acc, "max_acc":max_acc, "diff_acc": diff_acc,'optimizer':my_optimizer}, ignore_index=True)
    return pd.DataFrame(results)

# %%
filepath_out='./../data/cnn_results_1.csv'
results=test_model(filepath_out, feature_conditions)
# Out:
# 14/14 - 0s - loss: 0.6881 - accuracy: 0.5412 - val_loss: 0.6949 - val_accuracy: 0.5210 - 27ms/epoch - 2ms/step
# Epoch 45/10000
# 14/14 - 0s - loss: 0.6866 - accuracy: 0.5481 - val_loss: 0.6950 - val_accuracy: 0.5225 - 28ms/epoch - 2ms/step
# Epoch 46/10000
# 14/14 - 0s - loss: 0.6886 - accuracy: 0.5456 - val_loss: 0.6950 - val_accuracy: 0.5196 - 31ms/epoch - 2ms/step
# Epoch 47/10000
# 14/14 - 0s - loss: 0.6878 - accuracy: 0.5488 - val_loss: 0.6949 - val_accuracy: 0.5210 - 28ms/epoch - 2ms/step
# Epoch 48/10000
# 14/14 - 0s - loss: 0.6873 - accuracy: 0.5423 - val_loss: 0.6950 - val_accuracy: 0.5210 - 34ms/epoch - 2ms/step
# Epoch 49/10000
# 14/14 - 0s - loss: 0.6873 - accuracy: 0.5354 - val_loss: 0.6950 - val_accuracy: 0.5196 - 29ms/epoch - 2ms/step
# Epoch 50/10000
# 14/14 - 0s - loss: 0.6876 - accuracy: 0.5481 - val_loss: 0.6949 - val_accuracy: 0.5210 - 27ms/epoch - 2ms/step
# Epoch 51/10000
# 14/14 - 0s - loss: 0.6883 - accuracy: 0.5459 - val_loss: 0.6950 - val_accuracy: 0.5152 - 26ms/epoch - 2ms/step
# Epoch 52/10000
# 14/14 - 0s - loss: 0.6878 - accuracy: 0.5463 - val_loss: 0.6950 - val_accuracy: 0.5181 - 26ms/epoch - 2ms/step
# Epoch 53/10000
# 14/14 - 0s - loss: 0.6892 - accuracy: 0.5448 - val_loss: 0.6951 - val_accuracy: 0.5152 - 25ms/epoch - 2ms/step
# Epoch 54/10000
# 14/14 - 0s - loss: 0.6877 - accuracy: 0.5426 - val_loss: 0.6952 - val_accuracy: 0.5210 - 26ms/epoch - 2ms/step
# Epoch 55/10000
# 14/14 - 0s - loss: 0.6882 - accuracy: 0.5474 - val_loss: 0.6952 - val_accuracy: 0.5269 - 25ms/epoch - 2ms/step
# Epoch 56/10000
# 14/14 - 0s - loss: 0.6867 - accuracy: 0.5514 - val_loss: 0.6951 - val_accuracy: 0.5239 - 25ms/epoch - 2ms/step
# Epoch 57/10000
# 14/14 - 0s - loss: 0.6872 - accuracy: 0.5495 - val_loss: 0.6952 - val_accuracy: 0.5254 - 24ms/epoch - 2ms/step
# Epoch 58/10000
# 14/14 - 0s - loss: 0.6872 - accuracy: 0.5499 - val_loss: 0.6951 - val_accuracy: 0.5239 - 24ms/epoch - 2ms/step
# Epoch 59/10000
# 14/14 - 0s - loss: 0.6865 - accuracy: 0.5510 - val_loss: 0.6954 - val_accuracy: 0.5210 - 24ms/epoch - 2ms/step
# 27/27 [==============================] - 0s 374us/step
# train_X Shape: (3444, 10, 2)
# train_y Shape: (3444, 2)
# test_X Shape: (862, 10, 2)
# test_y Shape: (862,)
# Epoch 1/10000
# 14/14 - 0s - loss: 0.7081 - accuracy: 0.5005 - val_loss: 0.6959 - val_accuracy: 0.5181 - 220ms/epoch - 16ms/step
# Epoch 2/10000
# 14/14 - 0s - loss: 0.7006 - accuracy: 0.5024 - val_loss: 0.6954 - val_accuracy: 0.5094 - 27ms/epoch - 2ms/step
# Epoch 3/10000
# 14/14 - 0s - loss: 0.6981 - accuracy: 0.5191 - val_loss: 0.6939 - val_accuracy: 0.5196 - 25ms/epoch - 2ms/step
# Epoch 4/10000
# 14/14 - 0s - loss: 0.6951 - accuracy: 0.5289 - val_loss: 0.6937 - val_accuracy: 0.5225 - 27ms/epoch - 2ms/step
# Epoch 5/10000
# 14/14 - 0s - loss: 0.6959 - accuracy: 0.5194 - val_loss: 0.6935 - val_accuracy: 0.5196 - 27ms/epoch - 2ms/step
# Epoch 6/10000
# 14/14 - 0s - loss: 0.6961 - accuracy: 0.5042 - val_loss: 0.6933 - val_accuracy: 0.5239 - 27ms/epoch - 2ms/step
# Epoch 7/10000
# 14/14 - 0s - loss: 0.6893 - accuracy: 0.5368 - val_loss: 0.6934 - val_accuracy: 0.5123 - 25ms/epoch - 2ms/step
# Epoch 8/10000
# 14/14 - 0s - loss: 0.6949 - accuracy: 0.5252 - val_loss: 0.6932 - val_accuracy: 0.5152 - 28ms/epoch - 2ms/step
# Epoch 9/10000
# 14/14 - 0s - loss: 0.6920 - accuracy: 0.5212 - val_loss: 0.6935 - val_accuracy: 0.5094 - 26ms/epoch - 2ms/step
# Epoch 10/10000
# 14/14 - 0s - loss: 0.6918 - accuracy: 0.5376 - val_loss: 0.6936 - val_accuracy: 0.5123 - 26ms/epoch - 2ms/step
# Epoch 11/10000
# 14/14 - 0s - loss: 0.6897 - accuracy: 0.5347 - val_loss: 0.6938 - val_accuracy: 0.5080 - 25ms/epoch - 2ms/step
# Epoch 12/10000
# 14/14 - 0s - loss: 0.6924 - accuracy: 0.5198 - val_loss: 0.6940 - val_accuracy: 0.5022 - 27ms/epoch - 2ms/step
# Epoch 13/10000
# 14/14 - 0s - loss: 0.6882 - accuracy: 0.5416 - val_loss: 0.6941 - val_accuracy: 0.4993 - 29ms/epoch - 2ms/step
# Epoch 14/10000
# 14/14 - 0s - loss: 0.6880 - accuracy: 0.5408 - val_loss: 0.6943 - val_accuracy: 0.5007 - 26ms/epoch - 2ms/step
# Epoch 15/10000
# 14/14 - 0s - loss: 0.6897 - accuracy: 0.5372 - val_loss: 0.6943 - val_accuracy: 0.5123 - 27ms/epoch - 2ms/step
# Epoch 16/10000
# 14/14 - 0s - loss: 0.6916 - accuracy: 0.5201 - val_loss: 0.6944 - val_accuracy: 0.5051 - 25ms/epoch - 2ms/step
# Epoch 17/10000
# 14/14 - 0s - loss: 0.6913 - accuracy: 0.5256 - val_loss: 0.6943 - val_accuracy: 0.5109 - 28ms/epoch - 2ms/step
# Epoch 18/10000
# 14/14 - 0s - loss: 0.6888 - accuracy: 0.5434 - val_loss: 0.6944 - val_accuracy: 0.5109 - 27ms/epoch - 2ms/step
# Epoch 19/10000
# 14/14 - 0s - loss: 0.6885 - accuracy: 0.5430 - val_loss: 0.6942 - val_accuracy: 0.5138 - 26ms/epoch - 2ms/step
# Epoch 20/10000
# 14/14 - 0s - loss: 0.6886 - accuracy: 0.5416 - val_loss: 0.6941 - val_accuracy: 0.5167 - 26ms/epoch - 2ms/step
# Epoch 21/10000
# 14/14 - 0s - loss: 0.6888 - accuracy: 0.5343 - val_loss: 0.6942 - val_accuracy: 0.5152 - 28ms/epoch - 2ms/step
# Epoch 22/10000
# 14/14 - 0s - loss: 0.6868 - accuracy: 0.5376 - val_loss: 0.6943 - val_accuracy: 0.5152 - 27ms/epoch - 2ms/step
# Epoch 23/10000
# 14/14 - 0s - loss: 0.6884 - accuracy: 0.5307 - val_loss: 0.6943 - val_accuracy: 0.5167 - 27ms/epoch - 2ms/step
# Epoch 24/10000
# 14/14 - 0s - loss: 0.6869 - accuracy: 0.5485 - val_loss: 0.6943 - val_accuracy: 0.5181 - 28ms/epoch - 2ms/step
# Epoch 25/10000
# 14/14 - 0s - loss: 0.6891 - accuracy: 0.5412 - val_loss: 0.6941 - val_accuracy: 0.5196 - 26ms/epoch - 2ms/step
# Epoch 26/10000
# 14/14 - 0s - loss: 0.6891 - accuracy: 0.5466 - val_loss: 0.6944 - val_accuracy: 0.5225 - 28ms/epoch - 2ms/step
# Epoch 27/10000
# 14/14 - 0s - loss: 0.6908 - accuracy: 0.5310 - val_loss: 0.6944 - val_accuracy: 0.5239 - 26ms/epoch - 2ms/step
# Epoch 28/10000
# 14/14 - 0s - loss: 0.6877 - accuracy: 0.5354 - val_loss: 0.6944 - val_accuracy: 0.5239 - 26ms/epoch - 2ms/step
# Epoch 29/10000
# 14/14 - 0s - loss: 0.6860 - accuracy: 0.5532 - val_loss: 0.6946 - val_accuracy: 0.5167 - 28ms/epoch - 2ms/step
# Epoch 30/10000
# 14/14 - 0s - loss: 0.6881 - accuracy: 0.5412 - val_loss: 0.6948 - val_accuracy: 0.5167 - 28ms/epoch - 2ms/step
# Epoch 31/10000
# 14/14 - 0s - loss: 0.6902 - accuracy: 0.5332 - val_loss: 0.6948 - val_accuracy: 0.5181 - 28ms/epoch - 2ms/step
# Epoch 32/10000
# 14/14 - 0s - loss: 0.6912 - accuracy: 0.5241 - val_loss: 0.6946 - val_accuracy: 0.5181 - 27ms/epoch - 2ms/step
# Epoch 33/10000
# 14/14 - 0s - loss: 0.6885 - accuracy: 0.5412 - val_loss: 0.6947 - val_accuracy: 0.5138 - 28ms/epoch - 2ms/step
# Epoch 34/10000
# 14/14 - 0s - loss: 0.6887 - accuracy: 0.5296 - val_loss: 0.6947 - val_accuracy: 0.5196 - 26ms/epoch - 2ms/step
# Epoch 35/10000
# 14/14 - 0s - loss: 0.6880 - accuracy: 0.5372 - val_loss: 0.6947 - val_accuracy: 0.5196 - 29ms/epoch - 2ms/step
# Epoch 36/10000
# 14/14 - 0s - loss: 0.6875 - accuracy: 0.5568 - val_loss: 0.6947 - val_accuracy: 0.5239 - 29ms/epoch - 2ms/step
# Epoch 37/10000
# 14/14 - 0s - loss: 0.6875 - accuracy: 0.5401 - val_loss: 0.6949 - val_accuracy: 0.5210 - 28ms/epoch - 2ms/step
# Epoch 38/10000
# 14/14 - 0s - loss: 0.6874 - accuracy: 0.5441 - val_loss: 0.6950 - val_accuracy: 0.5196 - 29ms/epoch - 2ms/step
# Epoch 39/10000
# 14/14 - 0s - loss: 0.6883 - accuracy: 0.5390 - val_loss: 0.6951 - val_accuracy: 0.5196 - 26ms/epoch - 2ms/step
# Epoch 40/10000
# 14/14 - 0s - loss: 0.6878 - accuracy: 0.5470 - val_loss: 0.6951 - val_accuracy: 0.5210 - 28ms/epoch - 2ms/step
# Epoch 41/10000
# 14/14 - 0s - loss: 0.6887 - accuracy: 0.5426 - val_loss: 0.6951 - val_accuracy: 0.5196 - 26ms/epoch - 2ms/step
# Epoch 42/10000
# 14/14 - 0s - loss: 0.6888 - accuracy: 0.5394 - val_loss: 0.6950 - val_accuracy: 0.5181 - 26ms/epoch - 2ms/step
# Epoch 43/10000
# 14/14 - 0s - loss: 0.6868 - accuracy: 0.5448 - val_loss: 0.6948 - val_accuracy: 0.5181 - 27ms/epoch - 2ms/step
# Epoch 44/10000
# 14/14 - 0s - loss: 0.6882 - accuracy: 0.5394 - val_loss: 0.6948 - val_accuracy: 0.5225 - 25ms/epoch - 2ms/step
# Epoch 45/10000
# 14/14 - 0s - loss: 0.6890 - accuracy: 0.5299 - val_loss: 0.6948 - val_accuracy: 0.5196 - 27ms/epoch - 2ms/step
# Epoch 46/10000
# 14/14 - 0s - loss: 0.6891 - accuracy: 0.5372 - val_loss: 0.6948 - val_accuracy: 0.5196 - 26ms/epoch - 2ms/step
# Epoch 47/10000
# 14/14 - 0s - loss: 0.6893 - accuracy: 0.5390 - val_loss: 0.6949 - val_accuracy: 0.5196 - 27ms/epoch - 2ms/step
# Epoch 48/10000
# 14/14 - 0s - loss: 0.6862 - accuracy: 0.5492 - val_loss: 0.6949 - val_accuracy: 0.5225 - 25ms/epoch - 2ms/step
# Epoch 49/10000
# 14/14 - 0s - loss: 0.6864 - accuracy: 0.5503 - val_loss: 0.6949 - val_accuracy: 0.5269 - 28ms/epoch - 2ms/step
# Epoch 50/10000
# 14/14 - 0s - loss: 0.6888 - accuracy: 0.5459 - val_loss: 0.6949 - val_accuracy: 0.5239 - 27ms/epoch - 2ms/step
# Epoch 51/10000
# 14/14 - 0s - loss: 0.6873 - accuracy: 0.5488 - val_loss: 0.6950 - val_accuracy: 0.5167 - 31ms/epoch - 2ms/step
# Epoch 52/10000
# 14/14 - 0s - loss: 0.6871 - accuracy: 0.5401 - val_loss: 0.6948 - val_accuracy: 0.5225 - 30ms/epoch - 2ms/step
# Epoch 53/10000
# 14/14 - 0s - loss: 0.6875 - accuracy: 0.5485 - val_loss: 0.6947 - val_accuracy: 0.5239 - 26ms/epoch - 2ms/step
# Epoch 54/10000
# 14/14 - 0s - loss: 0.6861 - accuracy: 0.5514 - val_loss: 0.6948 - val_accuracy: 0.5239 - 27ms/epoch - 2ms/step
# Epoch 55/10000
# 14/14 - 0s - loss: 0.6870 - accuracy: 0.5394 - val_loss: 0.6948 - val_accuracy: 0.5225 - 26ms/epoch - 2ms/step
# Epoch 56/10000
# 14/14 - 0s - loss: 0.6878 - accuracy: 0.5441 - val_loss: 0.6948 - val_accuracy: 0.5239 - 28ms/epoch - 2ms/step
# Epoch 57/10000
# 14/14 - 0s - loss: 0.6885 - accuracy: 0.5405 - val_loss: 0.6948 - val_accuracy: 0.5254 - 27ms/epoch - 2ms/step
# Epoch 58/10000
# 14/14 - 0s - loss: 0.6893 - accuracy: 0.5336 - val_loss: 0.6948 - val_accuracy: 0.5298 - 27ms/epoch - 2ms/step
# 27/27 [==============================] - 0s 391us/step
# train_X Shape: (3444, 10, 2)
# train_y Shape: (3444, 2)
# test_X Shape: (862, 10, 2)
# test_y Shape: (862,)
# Epoch 1/10000
# 14/14 - 0s - loss: 0.7051 - accuracy: 0.4951 - val_loss: 0.6944 - val_accuracy: 0.5254 - 209ms/epoch - 15ms/step
# Epoch 2/10000
# 14/14 - 0s - loss: 0.7012 - accuracy: 0.5067 - val_loss: 0.6943 - val_accuracy: 0.5181 - 26ms/epoch - 2ms/step
# Epoch 3/10000
# 14/14 - 0s - loss: 0.7044 - accuracy: 0.5056 - val_loss: 0.6942 - val_accuracy: 0.5167 - 28ms/epoch - 2ms/step
# Epoch 4/10000
# 14/14 - 0s - loss: 0.6955 - accuracy: 0.5191 - val_loss: 0.6937 - val_accuracy: 0.5065 - 25ms/epoch - 2ms/step
# Epoch 5/10000
# 14/14 - 0s - loss: 0.7031 - accuracy: 0.4980 - val_loss: 0.6939 - val_accuracy: 0.5007 - 27ms/epoch - 2ms/step
# Epoch 6/10000
# 14/14 - 0s - loss: 0.6935 - accuracy: 0.5292 - val_loss: 0.6936 - val_accuracy: 0.5022 - 24ms/epoch - 2ms/step
# Epoch 7/10000
# 14/14 - 0s - loss: 0.6961 - accuracy: 0.5252 - val_loss: 0.6938 - val_accuracy: 0.4964 - 27ms/epoch - 2ms/step
# Epoch 8/10000
# 14/14 - 0s - loss: 0.6918 - accuracy: 0.5256 - val_loss: 0.6938 - val_accuracy: 0.4964 - 25ms/epoch - 2ms/step
# Epoch 9/10000
# 14/14 - 0s - loss: 0.6906 - accuracy: 0.5379 - val_loss: 0.6942 - val_accuracy: 0.4920 - 27ms/epoch - 2ms/step
# Epoch 10/10000
# 14/14 - 0s - loss: 0.6931 - accuracy: 0.5314 - val_loss: 0.6943 - val_accuracy: 0.4978 - 25ms/epoch - 2ms/step
# Epoch 11/10000
# 14/14 - 0s - loss: 0.6910 - accuracy: 0.5397 - val_loss: 0.6944 - val_accuracy: 0.5007 - 27ms/epoch - 2ms/step
# Epoch 12/10000
# 14/14 - 0s - loss: 0.6912 - accuracy: 0.5379 - val_loss: 0.6943 - val_accuracy: 0.5051 - 25ms/epoch - 2ms/step
# Epoch 13/10000
# 14/14 - 0s - loss: 0.6891 - accuracy: 0.5423 - val_loss: 0.6945 - val_accuracy: 0.5022 - 26ms/epoch - 2ms/step
# Epoch 14/10000
# 14/14 - 0s - loss: 0.6914 - accuracy: 0.5274 - val_loss: 0.6950 - val_accuracy: 0.5094 - 26ms/epoch - 2ms/step
# Epoch 15/10000
# 14/14 - 0s - loss: 0.6914 - accuracy: 0.5278 - val_loss: 0.6947 - val_accuracy: 0.4978 - 27ms/epoch - 2ms/step
# Epoch 16/10000
# 14/14 - 0s - loss: 0.6918 - accuracy: 0.5267 - val_loss: 0.6948 - val_accuracy: 0.5080 - 29ms/epoch - 2ms/step
# Epoch 17/10000
# 14/14 - 0s - loss: 0.6907 - accuracy: 0.5318 - val_loss: 0.6948 - val_accuracy: 0.5196 - 26ms/epoch - 2ms/step
# Epoch 18/10000
# 14/14 - 0s - loss: 0.6925 - accuracy: 0.5332 - val_loss: 0.6949 - val_accuracy: 0.5152 - 26ms/epoch - 2ms/step
# Epoch 19/10000
# 14/14 - 0s - loss: 0.6897 - accuracy: 0.5408 - val_loss: 0.6950 - val_accuracy: 0.5210 - 25ms/epoch - 2ms/step
# Epoch 20/10000
# 14/14 - 0s - loss: 0.6897 - accuracy: 0.5426 - val_loss: 0.6950 - val_accuracy: 0.5196 - 27ms/epoch - 2ms/step
# Epoch 21/10000
# 14/14 - 0s - loss: 0.6899 - accuracy: 0.5408 - val_loss: 0.6950 - val_accuracy: 0.5123 - 25ms/epoch - 2ms/step
# Epoch 22/10000
# 14/14 - 0s - loss: 0.6880 - accuracy: 0.5387 - val_loss: 0.6951 - val_accuracy: 0.5181 - 34ms/epoch - 2ms/step
# Epoch 23/10000
# 14/14 - 0s - loss: 0.6889 - accuracy: 0.5368 - val_loss: 0.6952 - val_accuracy: 0.5196 - 26ms/epoch - 2ms/step
# Epoch 24/10000
# 14/14 - 0s - loss: 0.6926 - accuracy: 0.5183 - val_loss: 0.6950 - val_accuracy: 0.5225 - 28ms/epoch - 2ms/step
# Epoch 25/10000
# 14/14 - 0s - loss: 0.6872 - accuracy: 0.5488 - val_loss: 0.6950 - val_accuracy: 0.5167 - 27ms/epoch - 2ms/step
# Epoch 26/10000
# 14/14 - 0s - loss: 0.6878 - accuracy: 0.5474 - val_loss: 0.6950 - val_accuracy: 0.5239 - 28ms/epoch - 2ms/step
# Epoch 27/10000
# 14/14 - 0s - loss: 0.6890 - accuracy: 0.5379 - val_loss: 0.6952 - val_accuracy: 0.5210 - 29ms/epoch - 2ms/step
# Epoch 28/10000
# 14/14 - 0s - loss: 0.6882 - accuracy: 0.5405 - val_loss: 0.6953 - val_accuracy: 0.5181 - 26ms/epoch - 2ms/step
# Epoch 29/10000
# 14/14 - 0s - loss: 0.6896 - accuracy: 0.5365 - val_loss: 0.6951 - val_accuracy: 0.5225 - 28ms/epoch - 2ms/step
# Epoch 30/10000
# 14/14 - 0s - loss: 0.6886 - accuracy: 0.5434 - val_loss: 0.6952 - val_accuracy: 0.5196 - 28ms/epoch - 2ms/step
# Epoch 31/10000
# 14/14 - 0s - loss: 0.6857 - accuracy: 0.5532 - val_loss: 0.6954 - val_accuracy: 0.5210 - 28ms/epoch - 2ms/step
# Epoch 32/10000
# 14/14 - 0s - loss: 0.6900 - accuracy: 0.5328 - val_loss: 0.6954 - val_accuracy: 0.5269 - 28ms/epoch - 2ms/step
# Epoch 33/10000
# 14/14 - 0s - loss: 0.6894 - accuracy: 0.5408 - val_loss: 0.6954 - val_accuracy: 0.5225 - 26ms/epoch - 2ms/step
# Epoch 34/10000
# 14/14 - 0s - loss: 0.6866 - accuracy: 0.5430 - val_loss: 0.6955 - val_accuracy: 0.5094 - 28ms/epoch - 2ms/step
# Epoch 35/10000
# 14/14 - 0s - loss: 0.6871 - accuracy: 0.5495 - val_loss: 0.6952 - val_accuracy: 0.5269 - 27ms/epoch - 2ms/step
# Epoch 36/10000
# 14/14 - 0s - loss: 0.6902 - accuracy: 0.5456 - val_loss: 0.6951 - val_accuracy: 0.5269 - 28ms/epoch - 2ms/step
# Epoch 37/10000
# 14/14 - 0s - loss: 0.6892 - accuracy: 0.5289 - val_loss: 0.6953 - val_accuracy: 0.5152 - 25ms/epoch - 2ms/step
# Epoch 38/10000
# 14/14 - 0s - loss: 0.6878 - accuracy: 0.5368 - val_loss: 0.6951 - val_accuracy: 0.5225 - 26ms/epoch - 2ms/step
# Epoch 39/10000
# 14/14 - 0s - loss: 0.6882 - accuracy: 0.5423 - val_loss: 0.6951 - val_accuracy: 0.5196 - 28ms/epoch - 2ms/step
# Epoch 40/10000
# 14/14 - 0s - loss: 0.6876 - accuracy: 0.5477 - val_loss: 0.6951 - val_accuracy: 0.5254 - 27ms/epoch - 2ms/step
# Epoch 41/10000
# 14/14 - 0s - loss: 0.6856 - accuracy: 0.5575 - val_loss: 0.6952 - val_accuracy: 0.5269 - 28ms/epoch - 2ms/step
# Epoch 42/10000
# 14/14 - 0s - loss: 0.6879 - accuracy: 0.5394 - val_loss: 0.6952 - val_accuracy: 0.5298 - 26ms/epoch - 2ms/step
# Epoch 43/10000
# 14/14 - 0s - loss: 0.6859 - accuracy: 0.5488 - val_loss: 0.6953 - val_accuracy: 0.5196 - 28ms/epoch - 2ms/step
# Epoch 44/10000
# 14/14 - 0s - loss: 0.6885 - accuracy: 0.5379 - val_loss: 0.6953 - val_accuracy: 0.5181 - 27ms/epoch - 2ms/step
# Epoch 45/10000
# 14/14 - 0s - loss: 0.6870 - accuracy: 0.5477 - val_loss: 0.6950 - val_accuracy: 0.5254 - 27ms/epoch - 2ms/step
# Epoch 46/10000
# 14/14 - 0s - loss: 0.6879 - accuracy: 0.5368 - val_loss: 0.6949 - val_accuracy: 0.5210 - 28ms/epoch - 2ms/step
# Epoch 47/10000
# 14/14 - 0s - loss: 0.6875 - accuracy: 0.5503 - val_loss: 0.6948 - val_accuracy: 0.5181 - 28ms/epoch - 2ms/step
# Epoch 48/10000
# 14/14 - 0s - loss: 0.6874 - accuracy: 0.5485 - val_loss: 0.6947 - val_accuracy: 0.5239 - 27ms/epoch - 2ms/step
# Epoch 49/10000
# 14/14 - 0s - loss: 0.6867 - accuracy: 0.5495 - val_loss: 0.6948 - val_accuracy: 0.5210 - 25ms/epoch - 2ms/step
# Epoch 50/10000
# 14/14 - 0s - loss: 0.6863 - accuracy: 0.5481 - val_loss: 0.6949 - val_accuracy: 0.5196 - 26ms/epoch - 2ms/step
# Epoch 51/10000
# 14/14 - 0s - loss: 0.6884 - accuracy: 0.5437 - val_loss: 0.6949 - val_accuracy: 0.5196 - 27ms/epoch - 2ms/step
# Epoch 52/10000
# 14/14 - 0s - loss: 0.6881 - accuracy: 0.5405 - val_loss: 0.6949 - val_accuracy: 0.5138 - 28ms/epoch - 2ms/step
# Epoch 53/10000
# 14/14 - 0s - loss: 0.6865 - accuracy: 0.5514 - val_loss: 0.6947 - val_accuracy: 0.5225 - 26ms/epoch - 2ms/step
# Epoch 54/10000
# 14/14 - 0s - loss: 0.6879 - accuracy: 0.5463 - val_loss: 0.6948 - val_accuracy: 0.5181 - 26ms/epoch - 2ms/step
# Epoch 55/10000
# 14/14 - 0s - loss: 0.6879 - accuracy: 0.5474 - val_loss: 0.6948 - val_accuracy: 0.5210 - 31ms/epoch - 2ms/step
# Epoch 56/10000
# 14/14 - 0s - loss: 0.6877 - accuracy: 0.5416 - val_loss: 0.6949 - val_accuracy: 0.5225 - 25ms/epoch - 2ms/step
# 27/27 [==============================] - 0s 373us/step
# train_X Shape: (3444, 10, 2)
# train_y Shape: (3444, 2)
# test_X Shape: (862, 10, 2)
# test_y Shape: (862,)
# Epoch 1/10000
# 14/14 - 0s - loss: 0.6983 - accuracy: 0.5263 - val_loss: 0.6945 - val_accuracy: 0.5138 - 211ms/epoch - 15ms/step
# Epoch 2/10000
# 14/14 - 0s - loss: 0.6970 - accuracy: 0.5227 - val_loss: 0.6950 - val_accuracy: 0.5080 - 28ms/epoch - 2ms/step
# Epoch 3/10000
# 14/14 - 0s - loss: 0.6987 - accuracy: 0.5038 - val_loss: 0.6942 - val_accuracy: 0.5065 - 25ms/epoch - 2ms/step
# Epoch 4/10000
# 14/14 - 0s - loss: 0.6978 - accuracy: 0.5162 - val_loss: 0.6943 - val_accuracy: 0.5094 - 27ms/epoch - 2ms/step
# Epoch 5/10000
# 14/14 - 0s - loss: 0.6992 - accuracy: 0.5118 - val_loss: 0.6946 - val_accuracy: 0.5109 - 25ms/epoch - 2ms/step
# Epoch 6/10000
# 14/14 - 0s - loss: 0.6926 - accuracy: 0.5372 - val_loss: 0.6946 - val_accuracy: 0.5239 - 27ms/epoch - 2ms/step
# Epoch 7/10000
# 14/14 - 0s - loss: 0.6908 - accuracy: 0.5336 - val_loss: 0.6950 - val_accuracy: 0.5254 - 27ms/epoch - 2ms/step
# Epoch 8/10000
# 14/14 - 0s - loss: 0.6943 - accuracy: 0.5176 - val_loss: 0.6949 - val_accuracy: 0.5254 - 28ms/epoch - 2ms/step
# Epoch 9/10000
# 14/14 - 0s - loss: 0.6900 - accuracy: 0.5532 - val_loss: 0.6953 - val_accuracy: 0.5283 - 27ms/epoch - 2ms/step
# Epoch 10/10000
# 14/14 - 0s - loss: 0.6890 - accuracy: 0.5463 - val_loss: 0.6956 - val_accuracy: 0.5298 - 27ms/epoch - 2ms/step
# Epoch 11/10000
# 14/14 - 0s - loss: 0.6900 - accuracy: 0.5336 - val_loss: 0.6955 - val_accuracy: 0.5356 - 25ms/epoch - 2ms/step
# Epoch 12/10000
# 14/14 - 0s - loss: 0.6890 - accuracy: 0.5328 - val_loss: 0.6956 - val_accuracy: 0.5298 - 26ms/epoch - 2ms/step
# Epoch 13/10000
# 14/14 - 0s - loss: 0.6917 - accuracy: 0.5260 - val_loss: 0.6957 - val_accuracy: 0.5269 - 26ms/epoch - 2ms/step
# Epoch 14/10000
# 14/14 - 0s - loss: 0.6914 - accuracy: 0.5267 - val_loss: 0.6959 - val_accuracy: 0.5269 - 26ms/epoch - 2ms/step
# Epoch 15/10000
# 14/14 - 0s - loss: 0.6897 - accuracy: 0.5328 - val_loss: 0.6957 - val_accuracy: 0.5298 - 26ms/epoch - 2ms/step
# Epoch 16/10000
# 14/14 - 0s - loss: 0.6901 - accuracy: 0.5379 - val_loss: 0.6958 - val_accuracy: 0.5239 - 31ms/epoch - 2ms/step
# Epoch 17/10000
# 14/14 - 0s - loss: 0.6915 - accuracy: 0.5289 - val_loss: 0.6957 - val_accuracy: 0.5341 - 31ms/epoch - 2ms/step
# Epoch 18/10000
# 14/14 - 0s - loss: 0.6904 - accuracy: 0.5372 - val_loss: 0.6959 - val_accuracy: 0.5312 - 29ms/epoch - 2ms/step
# Epoch 19/10000
# 14/14 - 0s - loss: 0.6875 - accuracy: 0.5416 - val_loss: 0.6960 - val_accuracy: 0.5254 - 26ms/epoch - 2ms/step
# Epoch 20/10000
# 14/14 - 0s - loss: 0.6904 - accuracy: 0.5358 - val_loss: 0.6960 - val_accuracy: 0.5283 - 28ms/epoch - 2ms/step
# Epoch 21/10000
# 14/14 - 0s - loss: 0.6880 - accuracy: 0.5394 - val_loss: 0.6960 - val_accuracy: 0.5312 - 28ms/epoch - 2ms/step
# Epoch 22/10000
# 14/14 - 0s - loss: 0.6885 - accuracy: 0.5445 - val_loss: 0.6960 - val_accuracy: 0.5269 - 28ms/epoch - 2ms/step
# Epoch 23/10000
# 14/14 - 0s - loss: 0.6889 - accuracy: 0.5365 - val_loss: 0.6959 - val_accuracy: 0.5283 - 27ms/epoch - 2ms/step
# Epoch 24/10000
# 14/14 - 0s - loss: 0.6881 - accuracy: 0.5394 - val_loss: 0.6957 - val_accuracy: 0.5269 - 27ms/epoch - 2ms/step
# Epoch 25/10000
# 14/14 - 0s - loss: 0.6908 - accuracy: 0.5361 - val_loss: 0.6959 - val_accuracy: 0.5196 - 29ms/epoch - 2ms/step
# Epoch 26/10000
# 14/14 - 0s - loss: 0.6889 - accuracy: 0.5397 - val_loss: 0.6958 - val_accuracy: 0.5225 - 27ms/epoch - 2ms/step
# Epoch 27/10000
# 14/14 - 0s - loss: 0.6875 - accuracy: 0.5383 - val_loss: 0.6959 - val_accuracy: 0.5225 - 29ms/epoch - 2ms/step
# Epoch 28/10000
# 14/14 - 0s - loss: 0.6893 - accuracy: 0.5423 - val_loss: 0.6959 - val_accuracy: 0.5269 - 28ms/epoch - 2ms/step
# Epoch 29/10000
# 14/14 - 0s - loss: 0.6867 - accuracy: 0.5528 - val_loss: 0.6959 - val_accuracy: 0.5283 - 28ms/epoch - 2ms/step
# Epoch 30/10000
# 14/14 - 0s - loss: 0.6881 - accuracy: 0.5263 - val_loss: 0.6960 - val_accuracy: 0.5210 - 26ms/epoch - 2ms/step
# Epoch 31/10000
# 14/14 - 0s - loss: 0.6887 - accuracy: 0.5328 - val_loss: 0.6960 - val_accuracy: 0.5225 - 26ms/epoch - 2ms/step
# Epoch 32/10000
# 14/14 - 0s - loss: 0.6885 - accuracy: 0.5379 - val_loss: 0.6959 - val_accuracy: 0.5225 - 26ms/epoch - 2ms/step
# Epoch 33/10000
# 14/14 - 0s - loss: 0.6869 - accuracy: 0.5463 - val_loss: 0.6959 - val_accuracy: 0.5269 - 26ms/epoch - 2ms/step
# Epoch 34/10000
# 14/14 - 0s - loss: 0.6889 - accuracy: 0.5350 - val_loss: 0.6959 - val_accuracy: 0.5167 - 26ms/epoch - 2ms/step
# Epoch 35/10000
# 14/14 - 0s - loss: 0.6863 - accuracy: 0.5394 - val_loss: 0.6956 - val_accuracy: 0.5312 - 25ms/epoch - 2ms/step
# Epoch 36/10000
# 14/14 - 0s - loss: 0.6894 - accuracy: 0.5419 - val_loss: 0.6957 - val_accuracy: 0.5210 - 26ms/epoch - 2ms/step
# Epoch 37/10000
# 14/14 - 0s - loss: 0.6872 - accuracy: 0.5383 - val_loss: 0.6955 - val_accuracy: 0.5269 - 26ms/epoch - 2ms/step
# Epoch 38/10000
# 14/14 - 0s - loss: 0.6861 - accuracy: 0.5387 - val_loss: 0.6955 - val_accuracy: 0.5210 - 26ms/epoch - 2ms/step
# Epoch 39/10000
# 14/14 - 0s - loss: 0.6868 - accuracy: 0.5499 - val_loss: 0.6955 - val_accuracy: 0.5196 - 27ms/epoch - 2ms/step
# Epoch 40/10000
# 14/14 - 0s - loss: 0.6873 - accuracy: 0.5437 - val_loss: 0.6956 - val_accuracy: 0.5210 - 26ms/epoch - 2ms/step
# Epoch 41/10000
# 14/14 - 0s - loss: 0.6880 - accuracy: 0.5347 - val_loss: 0.6954 - val_accuracy: 0.5312 - 26ms/epoch - 2ms/step
# Epoch 42/10000
# 14/14 - 0s - loss: 0.6876 - accuracy: 0.5437 - val_loss: 0.6955 - val_accuracy: 0.5239 - 26ms/epoch - 2ms/step
# Epoch 43/10000
# 14/14 - 0s - loss: 0.6879 - accuracy: 0.5397 - val_loss: 0.6956 - val_accuracy: 0.5254 - 24ms/epoch - 2ms/step
# Epoch 44/10000
# 14/14 - 0s - loss: 0.6880 - accuracy: 0.5296 - val_loss: 0.6955 - val_accuracy: 0.5196 - 27ms/epoch - 2ms/step
# Epoch 45/10000
# 14/14 - 0s - loss: 0.6880 - accuracy: 0.5405 - val_loss: 0.6954 - val_accuracy: 0.5167 - 33ms/epoch - 2ms/step
# Epoch 46/10000
# 14/14 - 0s - loss: 0.6876 - accuracy: 0.5387 - val_loss: 0.6953 - val_accuracy: 0.5196 - 29ms/epoch - 2ms/step
# Epoch 47/10000
# 14/14 - 0s - loss: 0.6884 - accuracy: 0.5419 - val_loss: 0.6953 - val_accuracy: 0.5210 - 29ms/epoch - 2ms/step
# Epoch 48/10000
# 14/14 - 0s - loss: 0.6862 - accuracy: 0.5521 - val_loss: 0.6953 - val_accuracy: 0.5210 - 28ms/epoch - 2ms/step
# Epoch 49/10000
# 14/14 - 0s - loss: 0.6869 - accuracy: 0.5441 - val_loss: 0.6955 - val_accuracy: 0.5210 - 25ms/epoch - 2ms/step
# Epoch 50/10000
# 14/14 - 0s - loss: 0.6880 - accuracy: 0.5426 - val_loss: 0.6954 - val_accuracy: 0.5254 - 25ms/epoch - 2ms/step
# Epoch 51/10000
# 14/14 - 0s - loss: 0.6876 - accuracy: 0.5470 - val_loss: 0.6954 - val_accuracy: 0.5196 - 25ms/epoch - 2ms/step
# Epoch 52/10000
# 14/14 - 0s - loss: 0.6872 - accuracy: 0.5474 - val_loss: 0.6954 - val_accuracy: 0.5210 - 25ms/epoch - 2ms/step
# Epoch 53/10000
# 14/14 - 0s - loss: 0.6877 - accuracy: 0.5387 - val_loss: 0.6953 - val_accuracy: 0.5210 - 25ms/epoch - 2ms/step
# 27/27 [==============================] - 0s 369us/step
# train_X Shape: (3444, 10, 2)
# train_y Shape: (3444, 2)
# test_X Shape: (862, 10, 2)
# test_y Shape: (862,)
# Epoch 1/10000
# 14/14 - 0s - loss: 0.7079 - accuracy: 0.5016 - val_loss: 0.6939 - val_accuracy: 0.5123 - 199ms/epoch - 14ms/step
# Epoch 2/10000
# 14/14 - 0s - loss: 0.7045 - accuracy: 0.5093 - val_loss: 0.6939 - val_accuracy: 0.5109 - 29ms/epoch - 2ms/step
# Epoch 3/10000
# 14/14 - 0s - loss: 0.7028 - accuracy: 0.5031 - val_loss: 0.6922 - val_accuracy: 0.5109 - 26ms/epoch - 2ms/step
# Epoch 4/10000
# 14/14 - 0s - loss: 0.6939 - accuracy: 0.5230 - val_loss: 0.6925 - val_accuracy: 0.4964 - 51ms/epoch - 4ms/step
# Epoch 5/10000
# 14/14 - 0s - loss: 0.6992 - accuracy: 0.5187 - val_loss: 0.6928 - val_accuracy: 0.5007 - 34ms/epoch - 2ms/step
# Epoch 6/10000
# 14/14 - 0s - loss: 0.6954 - accuracy: 0.5212 - val_loss: 0.6926 - val_accuracy: 0.5138 - 25ms/epoch - 2ms/step
# Epoch 7/10000
# 14/14 - 0s - loss: 0.6981 - accuracy: 0.5078 - val_loss: 0.6932 - val_accuracy: 0.5109 - 26ms/epoch - 2ms/step
# Epoch 8/10000
# 14/14 - 0s - loss: 0.6994 - accuracy: 0.5093 - val_loss: 0.6932 - val_accuracy: 0.5094 - 25ms/epoch - 2ms/step
# Epoch 9/10000
# 14/14 - 0s - loss: 0.6946 - accuracy: 0.5274 - val_loss: 0.6934 - val_accuracy: 0.5123 - 27ms/epoch - 2ms/step
# Epoch 10/10000
# 14/14 - 0s - loss: 0.6915 - accuracy: 0.5372 - val_loss: 0.6938 - val_accuracy: 0.5109 - 27ms/epoch - 2ms/step
# Epoch 11/10000
# 14/14 - 0s - loss: 0.6921 - accuracy: 0.5238 - val_loss: 0.6937 - val_accuracy: 0.5094 - 25ms/epoch - 2ms/step
# Epoch 12/10000
# 14/14 - 0s - loss: 0.6895 - accuracy: 0.5394 - val_loss: 0.6940 - val_accuracy: 0.5152 - 25ms/epoch - 2ms/step
# Epoch 13/10000
# 14/14 - 0s - loss: 0.6907 - accuracy: 0.5314 - val_loss: 0.6941 - val_accuracy: 0.5196 - 26ms/epoch - 2ms/step
# Epoch 14/10000
# 14/14 - 0s - loss: 0.6906 - accuracy: 0.5423 - val_loss: 0.6944 - val_accuracy: 0.5196 - 25ms/epoch - 2ms/step
# Epoch 15/10000
# 14/14 - 0s - loss: 0.6892 - accuracy: 0.5412 - val_loss: 0.6944 - val_accuracy: 0.5181 - 25ms/epoch - 2ms/step
# Epoch 16/10000
# 14/14 - 0s - loss: 0.6901 - accuracy: 0.5296 - val_loss: 0.6948 - val_accuracy: 0.5181 - 25ms/epoch - 2ms/step
# Epoch 17/10000
# 14/14 - 0s - loss: 0.6908 - accuracy: 0.5281 - val_loss: 0.6950 - val_accuracy: 0.5196 - 28ms/epoch - 2ms/step
# Epoch 18/10000
# 14/14 - 0s - loss: 0.6894 - accuracy: 0.5441 - val_loss: 0.6949 - val_accuracy: 0.5181 - 29ms/epoch - 2ms/step
# Epoch 19/10000
# 14/14 - 0s - loss: 0.6912 - accuracy: 0.5416 - val_loss: 0.6952 - val_accuracy: 0.5210 - 27ms/epoch - 2ms/step
# Epoch 20/10000
# 14/14 - 0s - loss: 0.6897 - accuracy: 0.5445 - val_loss: 0.6949 - val_accuracy: 0.5239 - 26ms/epoch - 2ms/step
# Epoch 21/10000
# 14/14 - 0s - loss: 0.6887 - accuracy: 0.5459 - val_loss: 0.6950 - val_accuracy: 0.5239 - 28ms/epoch - 2ms/step
# Epoch 22/10000
# 14/14 - 0s - loss: 0.6899 - accuracy: 0.5408 - val_loss: 0.6951 - val_accuracy: 0.5269 - 26ms/epoch - 2ms/step
# Epoch 23/10000
# 14/14 - 0s - loss: 0.6887 - accuracy: 0.5376 - val_loss: 0.6953 - val_accuracy: 0.5269 - 26ms/epoch - 2ms/step
# Epoch 24/10000
# 14/14 - 0s - loss: 0.6891 - accuracy: 0.5419 - val_loss: 0.6954 - val_accuracy: 0.5239 - 26ms/epoch - 2ms/step
# Epoch 25/10000
# 14/14 - 0s - loss: 0.6881 - accuracy: 0.5499 - val_loss: 0.6952 - val_accuracy: 0.5283 - 26ms/epoch - 2ms/step
# Epoch 26/10000
# 14/14 - 0s - loss: 0.6884 - accuracy: 0.5321 - val_loss: 0.6953 - val_accuracy: 0.5254 - 27ms/epoch - 2ms/step
# Epoch 27/10000
# 14/14 - 0s - loss: 0.6890 - accuracy: 0.5314 - val_loss: 0.6952 - val_accuracy: 0.5269 - 25ms/epoch - 2ms/step
# Epoch 28/10000
# 14/14 - 0s - loss: 0.6901 - accuracy: 0.5339 - val_loss: 0.6952 - val_accuracy: 0.5283 - 25ms/epoch - 2ms/step
# Epoch 29/10000
# 14/14 - 0s - loss: 0.6891 - accuracy: 0.5310 - val_loss: 0.6954 - val_accuracy: 0.5167 - 25ms/epoch - 2ms/step
# Epoch 30/10000
# 14/14 - 0s - loss: 0.6907 - accuracy: 0.5339 - val_loss: 0.6951 - val_accuracy: 0.5298 - 25ms/epoch - 2ms/step
# Epoch 31/10000
# 14/14 - 0s - loss: 0.6889 - accuracy: 0.5376 - val_loss: 0.6954 - val_accuracy: 0.5123 - 25ms/epoch - 2ms/step
# Epoch 32/10000
# 14/14 - 0s - loss: 0.6871 - accuracy: 0.5470 - val_loss: 0.6954 - val_accuracy: 0.5239 - 25ms/epoch - 2ms/step
# Epoch 33/10000
# 14/14 - 0s - loss: 0.6892 - accuracy: 0.5390 - val_loss: 0.6956 - val_accuracy: 0.5167 - 25ms/epoch - 2ms/step
# Epoch 34/10000
# 14/14 - 0s - loss: 0.6873 - accuracy: 0.5445 - val_loss: 0.6956 - val_accuracy: 0.5138 - 25ms/epoch - 2ms/step
# Epoch 35/10000
# 14/14 - 0s - loss: 0.6875 - accuracy: 0.5488 - val_loss: 0.6954 - val_accuracy: 0.5239 - 26ms/epoch - 2ms/step
# Epoch 36/10000
# 14/14 - 0s - loss: 0.6882 - accuracy: 0.5379 - val_loss: 0.6954 - val_accuracy: 0.5239 - 26ms/epoch - 2ms/step
# Epoch 37/10000
# 14/14 - 0s - loss: 0.6869 - accuracy: 0.5554 - val_loss: 0.6954 - val_accuracy: 0.5196 - 26ms/epoch - 2ms/step
# Epoch 38/10000
# 14/14 - 0s - loss: 0.6867 - accuracy: 0.5372 - val_loss: 0.6953 - val_accuracy: 0.5225 - 28ms/epoch - 2ms/step
# Epoch 39/10000
# 14/14 - 0s - loss: 0.6871 - accuracy: 0.5539 - val_loss: 0.6954 - val_accuracy: 0.5254 - 30ms/epoch - 2ms/step
# Epoch 40/10000
# 14/14 - 0s - loss: 0.6868 - accuracy: 0.5354 - val_loss: 0.6954 - val_accuracy: 0.5269 - 25ms/epoch - 2ms/step
# Epoch 41/10000
# 14/14 - 0s - loss: 0.6890 - accuracy: 0.5350 - val_loss: 0.6954 - val_accuracy: 0.5269 - 26ms/epoch - 2ms/step
# Epoch 42/10000
# 14/14 - 0s - loss: 0.6890 - accuracy: 0.5448 - val_loss: 0.6953 - val_accuracy: 0.5254 - 25ms/epoch - 2ms/step
# Epoch 43/10000
# 14/14 - 0s - loss: 0.6877 - accuracy: 0.5401 - val_loss: 0.6954 - val_accuracy: 0.5269 - 25ms/epoch - 2ms/step
# Epoch 44/10000
# 14/14 - 0s - loss: 0.6877 - accuracy: 0.5423 - val_loss: 0.6954 - val_accuracy: 0.5269 - 28ms/epoch - 2ms/step
# Epoch 45/10000
# 14/14 - 0s - loss: 0.6882 - accuracy: 0.5401 - val_loss: 0.6955 - val_accuracy: 0.5269 - 26ms/epoch - 2ms/step
# Epoch 46/10000
# 14/14 - 0s - loss: 0.6868 - accuracy: 0.5387 - val_loss: 0.6954 - val_accuracy: 0.5269 - 26ms/epoch - 2ms/step
# Epoch 47/10000
# 14/14 - 0s - loss: 0.6884 - accuracy: 0.5332 - val_loss: 0.6953 - val_accuracy: 0.5225 - 25ms/epoch - 2ms/step
# Epoch 48/10000
# 14/14 - 0s - loss: 0.6870 - accuracy: 0.5441 - val_loss: 0.6953 - val_accuracy: 0.5254 - 28ms/epoch - 2ms/step
# Epoch 49/10000
# 14/14 - 0s - loss: 0.6879 - accuracy: 0.5285 - val_loss: 0.6953 - val_accuracy: 0.5269 - 26ms/epoch - 2ms/step
# Epoch 50/10000
# 14/14 - 0s - loss: 0.6890 - accuracy: 0.5408 - val_loss: 0.6953 - val_accuracy: 0.5283 - 25ms/epoch - 2ms/step
# Epoch 51/10000
# 14/14 - 0s - loss: 0.6866 - accuracy: 0.5485 - val_loss: 0.6952 - val_accuracy: 0.5225 - 25ms/epoch - 2ms/step
# Epoch 52/10000
# 14/14 - 0s - loss: 0.6882 - accuracy: 0.5546 - val_loss: 0.6954 - val_accuracy: 0.5210 - 26ms/epoch - 2ms/step
# Epoch 53/10000
# 14/14 - 0s - loss: 0.6878 - accuracy: 0.5358 - val_loss: 0.6954 - val_accuracy: 0.5196 - 26ms/epoch - 2ms/step
# 27/27 [==============================] - 0s 392us/step
# Testing model: lag: [10, 15] , neurons: 32 , layers: 1 , batch_size: 200
# train_X Shape: (3440, 15, 2)
# train_y Shape: (3440, 2)
# test_X Shape: (861, 15, 2)
# test_y Shape: (861,)
# Epoch 1/10000
# /var/folders/vp/8_rd4_c56g3dpqb1167z6tqr0000gn/T/ipykernel_29133/3454146048.py:66: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append({"timestep": step,"features": data.columns.values,"google_trends_lag":g,"tweet_volume_lag": tv,"tweet_polarity_score_lag": tw_lag, "batch_size":b, "neurons":n, "layers":l, "mean_down_f1_score":mean_down_f1_score,"mean_up_f1_score":mean_up_f1_score, "mean_acc": mean_acc,"min_acc":min_acc, "max_acc":max_acc, "diff_acc": diff_acc,'optimizer':my_optimizer}, ignore_index=True)
# 14/14 - 0s - loss: 0.7081 - accuracy: 0.4956 - val_loss: 0.6918 - val_accuracy: 0.5189 - 206ms/epoch - 15ms/step
# Epoch 2/10000
# 14/14 - 0s - loss: 0.7025 - accuracy: 0.5065 - val_loss: 0.6915 - val_accuracy: 0.5116 - 29ms/epoch - 2ms/step
# Epoch 3/10000
# 14/14 - 0s - loss: 0.6989 - accuracy: 0.5087 - val_loss: 0.6913 - val_accuracy: 0.5276 - 30ms/epoch - 2ms/step
# Epoch 4/10000
# 14/14 - 0s - loss: 0.6961 - accuracy: 0.5178 - val_loss: 0.6922 - val_accuracy: 0.5145 - 30ms/epoch - 2ms/step
# Epoch 5/10000
# 14/14 - 0s - loss: 0.6915 - accuracy: 0.5309 - val_loss: 0.6929 - val_accuracy: 0.5131 - 28ms/epoch - 2ms/step
# Epoch 6/10000
# 14/14 - 0s - loss: 0.6934 - accuracy: 0.5211 - val_loss: 0.6933 - val_accuracy: 0.5073 - 28ms/epoch - 2ms/step
# Epoch 7/10000
# 14/14 - 0s - loss: 0.6927 - accuracy: 0.5338 - val_loss: 0.6937 - val_accuracy: 0.5073 - 29ms/epoch - 2ms/step
# Epoch 8/10000
# 14/14 - 0s - loss: 0.6920 - accuracy: 0.5382 - val_loss: 0.6940 - val_accuracy: 0.5058 - 29ms/epoch - 2ms/step
# Epoch 9/10000
# 14/14 - 0s - loss: 0.6932 - accuracy: 0.5258 - val_loss: 0.6940 - val_accuracy: 0.5087 - 28ms/epoch - 2ms/step
# Epoch 10/10000
# 14/14 - 0s - loss: 0.6919 - accuracy: 0.5320 - val_loss: 0.6945 - val_accuracy: 0.5073 - 29ms/epoch - 2ms/step
# Epoch 11/10000
# 14/14 - 0s - loss: 0.6892 - accuracy: 0.5440 - val_loss: 0.6950 - val_accuracy: 0.5131 - 29ms/epoch - 2ms/step
# Epoch 12/10000
# 14/14 - 0s - loss: 0.6879 - accuracy: 0.5385 - val_loss: 0.6951 - val_accuracy: 0.5116 - 27ms/epoch - 2ms/step
# Epoch 13/10000
# 14/14 - 0s - loss: 0.6901 - accuracy: 0.5378 - val_loss: 0.6954 - val_accuracy: 0.5058 - 29ms/epoch - 2ms/step
# Epoch 14/10000
# 14/14 - 0s - loss: 0.6903 - accuracy: 0.5356 - val_loss: 0.6954 - val_accuracy: 0.5102 - 29ms/epoch - 2ms/step
# Epoch 15/10000
# 14/14 - 0s - loss: 0.6878 - accuracy: 0.5476 - val_loss: 0.6956 - val_accuracy: 0.5015 - 29ms/epoch - 2ms/step
# Epoch 16/10000
# 14/14 - 0s - loss: 0.6884 - accuracy: 0.5378 - val_loss: 0.6957 - val_accuracy: 0.5015 - 29ms/epoch - 2ms/step
# Epoch 17/10000
# 14/14 - 0s - loss: 0.6876 - accuracy: 0.5472 - val_loss: 0.6960 - val_accuracy: 0.5044 - 29ms/epoch - 2ms/step
# Epoch 18/10000
# 14/14 - 0s - loss: 0.6907 - accuracy: 0.5389 - val_loss: 0.6960 - val_accuracy: 0.5029 - 31ms/epoch - 2ms/step
# Epoch 19/10000
# 14/14 - 0s - loss: 0.6888 - accuracy: 0.5411 - val_loss: 0.6960 - val_accuracy: 0.5044 - 30ms/epoch - 2ms/step
# Epoch 20/10000
# 14/14 - 0s - loss: 0.6857 - accuracy: 0.5458 - val_loss: 0.6960 - val_accuracy: 0.5102 - 31ms/epoch - 2ms/step
# Epoch 21/10000
# 14/14 - 0s - loss: 0.6860 - accuracy: 0.5567 - val_loss: 0.6961 - val_accuracy: 0.5160 - 31ms/epoch - 2ms/step
# Epoch 22/10000
# 14/14 - 0s - loss: 0.6879 - accuracy: 0.5411 - val_loss: 0.6962 - val_accuracy: 0.5073 - 31ms/epoch - 2ms/step
# Epoch 23/10000
# 14/14 - 0s - loss: 0.6854 - accuracy: 0.5567 - val_loss: 0.6964 - val_accuracy: 0.5073 - 31ms/epoch - 2ms/step
# Epoch 24/10000
# 14/14 - 0s - loss: 0.6857 - accuracy: 0.5545 - val_loss: 0.6965 - val_accuracy: 0.5087 - 34ms/epoch - 2ms/step
# Epoch 25/10000
# 14/14 - 0s - loss: 0.6877 - accuracy: 0.5469 - val_loss: 0.6965 - val_accuracy: 0.5102 - 32ms/epoch - 2ms/step
# Epoch 26/10000
# 14/14 - 0s - loss: 0.6845 - accuracy: 0.5465 - val_loss: 0.6965 - val_accuracy: 0.5116 - 31ms/epoch - 2ms/step
# Epoch 27/10000
# 14/14 - 0s - loss: 0.6851 - accuracy: 0.5552 - val_loss: 0.6965 - val_accuracy: 0.5116 - 31ms/epoch - 2ms/step
# Epoch 28/10000
# 14/14 - 0s - loss: 0.6854 - accuracy: 0.5487 - val_loss: 0.6967 - val_accuracy: 0.5102 - 31ms/epoch - 2ms/step
# Epoch 29/10000
# 14/14 - 0s - loss: 0.6859 - accuracy: 0.5494 - val_loss: 0.6965 - val_accuracy: 0.5160 - 31ms/epoch - 2ms/step
# Epoch 30/10000
# 14/14 - 0s - loss: 0.6868 - accuracy: 0.5403 - val_loss: 0.6967 - val_accuracy: 0.5044 - 30ms/epoch - 2ms/step
# Epoch 31/10000
# 14/14 - 0s - loss: 0.6865 - accuracy: 0.5469 - val_loss: 0.6967 - val_accuracy: 0.5116 - 30ms/epoch - 2ms/step
# Epoch 32/10000
# 14/14 - 0s - loss: 0.6850 - accuracy: 0.5647 - val_loss: 0.6968 - val_accuracy: 0.5102 - 31ms/epoch - 2ms/step
# Epoch 33/10000
# 14/14 - 0s - loss: 0.6848 - accuracy: 0.5527 - val_loss: 0.6966 - val_accuracy: 0.5160 - 31ms/epoch - 2ms/step
# Epoch 34/10000
# 14/14 - 0s - loss: 0.6869 - accuracy: 0.5440 - val_loss: 0.6967 - val_accuracy: 0.5044 - 30ms/epoch - 2ms/step
# Epoch 35/10000
# 14/14 - 0s - loss: 0.6859 - accuracy: 0.5545 - val_loss: 0.6968 - val_accuracy: 0.5102 - 28ms/epoch - 2ms/step
# Epoch 36/10000
# 14/14 - 0s - loss: 0.6859 - accuracy: 0.5512 - val_loss: 0.6968 - val_accuracy: 0.5029 - 29ms/epoch - 2ms/step
# Epoch 37/10000
# 14/14 - 0s - loss: 0.6868 - accuracy: 0.5483 - val_loss: 0.6968 - val_accuracy: 0.5044 - 28ms/epoch - 2ms/step
# Epoch 38/10000
# 14/14 - 0s - loss: 0.6844 - accuracy: 0.5614 - val_loss: 0.6968 - val_accuracy: 0.5131 - 29ms/epoch - 2ms/step
# Epoch 39/10000
# 14/14 - 0s - loss: 0.6863 - accuracy: 0.5531 - val_loss: 0.6970 - val_accuracy: 0.5116 - 29ms/epoch - 2ms/step
# Epoch 40/10000
# 14/14 - 0s - loss: 0.6854 - accuracy: 0.5523 - val_loss: 0.6971 - val_accuracy: 0.5087 - 31ms/epoch - 2ms/step
# Epoch 41/10000
# 14/14 - 0s - loss: 0.6839 - accuracy: 0.5491 - val_loss: 0.6970 - val_accuracy: 0.5087 - 33ms/epoch - 2ms/step
# Epoch 42/10000
# 14/14 - 0s - loss: 0.6858 - accuracy: 0.5505 - val_loss: 0.6969 - val_accuracy: 0.5131 - 32ms/epoch - 2ms/step
# Epoch 43/10000
# 14/14 - 0s - loss: 0.6856 - accuracy: 0.5465 - val_loss: 0.6969 - val_accuracy: 0.5102 - 30ms/epoch - 2ms/step
# Epoch 44/10000
# 14/14 - 0s - loss: 0.6848 - accuracy: 0.5487 - val_loss: 0.6968 - val_accuracy: 0.5116 - 30ms/epoch - 2ms/step
# Epoch 45/10000
# 14/14 - 0s - loss: 0.6855 - accuracy: 0.5570 - val_loss: 0.6969 - val_accuracy: 0.5102 - 30ms/epoch - 2ms/step
# Epoch 46/10000
# 14/14 - 0s - loss: 0.6842 - accuracy: 0.5552 - val_loss: 0.6967 - val_accuracy: 0.5087 - 28ms/epoch - 2ms/step
# Epoch 47/10000
# 14/14 - 0s - loss: 0.6873 - accuracy: 0.5422 - val_loss: 0.6968 - val_accuracy: 0.5145 - 30ms/epoch - 2ms/step
# Epoch 48/10000
# 14/14 - 0s - loss: 0.6838 - accuracy: 0.5567 - val_loss: 0.6971 - val_accuracy: 0.5116 - 31ms/epoch - 2ms/step
# Epoch 49/10000
# 14/14 - 0s - loss: 0.6848 - accuracy: 0.5621 - val_loss: 0.6970 - val_accuracy: 0.5116 - 29ms/epoch - 2ms/step
# Epoch 50/10000
# 14/14 - 0s - loss: 0.6860 - accuracy: 0.5461 - val_loss: 0.6970 - val_accuracy: 0.5131 - 30ms/epoch - 2ms/step
# Epoch 51/10000
# 14/14 - 0s - loss: 0.6870 - accuracy: 0.5527 - val_loss: 0.6969 - val_accuracy: 0.5116 - 28ms/epoch - 2ms/step
# Epoch 52/10000
# 14/14 - 0s - loss: 0.6839 - accuracy: 0.5654 - val_loss: 0.6968 - val_accuracy: 0.5116 - 29ms/epoch - 2ms/step
# Epoch 53/10000
# 14/14 - 0s - loss: 0.6847 - accuracy: 0.5589 - val_loss: 0.6967 - val_accuracy: 0.5116 - 29ms/epoch - 2ms/step
# 27/27 [==============================] - 0s 380us/step
# train_X Shape: (3440, 15, 2)
# train_y Shape: (3440, 2)
# test_X Shape: (861, 15, 2)
# test_y Shape: (861,)
# Epoch 1/10000
# 14/14 - 0s - loss: 0.7306 - accuracy: 0.5025 - val_loss: 0.7054 - val_accuracy: 0.5233 - 208ms/epoch - 15ms/step
# Epoch 2/10000
# 14/14 - 0s - loss: 0.7024 - accuracy: 0.5185 - val_loss: 0.6964 - val_accuracy: 0.4985 - 28ms/epoch - 2ms/step
# Epoch 3/10000
# 14/14 - 0s - loss: 0.7017 - accuracy: 0.5033 - val_loss: 0.6957 - val_accuracy: 0.5116 - 28ms/epoch - 2ms/step
# Epoch 4/10000
# 14/14 - 0s - loss: 0.6950 - accuracy: 0.5153 - val_loss: 0.6957 - val_accuracy: 0.4927 - 28ms/epoch - 2ms/step
# Epoch 5/10000
# 14/14 - 0s - loss: 0.6940 - accuracy: 0.5265 - val_loss: 0.6949 - val_accuracy: 0.4985 - 29ms/epoch - 2ms/step
# Epoch 6/10000
# 14/14 - 0s - loss: 0.6959 - accuracy: 0.5203 - val_loss: 0.6946 - val_accuracy: 0.5029 - 29ms/epoch - 2ms/step
# Epoch 7/10000
# 14/14 - 0s - loss: 0.6922 - accuracy: 0.5323 - val_loss: 0.6946 - val_accuracy: 0.4971 - 29ms/epoch - 2ms/step
# Epoch 8/10000
# 14/14 - 0s - loss: 0.6930 - accuracy: 0.5283 - val_loss: 0.6942 - val_accuracy: 0.5015 - 29ms/epoch - 2ms/step
# Epoch 9/10000
# 14/14 - 0s - loss: 0.6914 - accuracy: 0.5349 - val_loss: 0.6942 - val_accuracy: 0.5087 - 29ms/epoch - 2ms/step
# Epoch 10/10000
# 14/14 - 0s - loss: 0.6919 - accuracy: 0.5254 - val_loss: 0.6941 - val_accuracy: 0.5102 - 30ms/epoch - 2ms/step
# Epoch 11/10000
# 14/14 - 0s - loss: 0.6917 - accuracy: 0.5254 - val_loss: 0.6941 - val_accuracy: 0.5058 - 28ms/epoch - 2ms/step
# Epoch 12/10000
# 14/14 - 0s - loss: 0.6896 - accuracy: 0.5509 - val_loss: 0.6940 - val_accuracy: 0.5145 - 29ms/epoch - 2ms/step
# Epoch 13/10000
# 14/14 - 0s - loss: 0.6938 - accuracy: 0.5247 - val_loss: 0.6942 - val_accuracy: 0.5160 - 30ms/epoch - 2ms/step
# Epoch 14/10000
# 14/14 - 0s - loss: 0.6897 - accuracy: 0.5294 - val_loss: 0.6942 - val_accuracy: 0.5145 - 30ms/epoch - 2ms/step
# Epoch 15/10000
# 14/14 - 0s - loss: 0.6890 - accuracy: 0.5411 - val_loss: 0.6943 - val_accuracy: 0.5087 - 29ms/epoch - 2ms/step
# Epoch 16/10000
# 14/14 - 0s - loss: 0.6878 - accuracy: 0.5458 - val_loss: 0.6942 - val_accuracy: 0.5058 - 29ms/epoch - 2ms/step
# Epoch 17/10000
# 14/14 - 0s - loss: 0.6895 - accuracy: 0.5527 - val_loss: 0.6942 - val_accuracy: 0.5000 - 30ms/epoch - 2ms/step
# Epoch 18/10000
# 14/14 - 0s - loss: 0.6896 - accuracy: 0.5356 - val_loss: 0.6942 - val_accuracy: 0.4985 - 31ms/epoch - 2ms/step
# Epoch 19/10000
# 14/14 - 0s - loss: 0.6881 - accuracy: 0.5447 - val_loss: 0.6941 - val_accuracy: 0.5015 - 32ms/epoch - 2ms/step
# Epoch 20/10000
# 14/14 - 0s - loss: 0.6889 - accuracy: 0.5414 - val_loss: 0.6941 - val_accuracy: 0.5073 - 29ms/epoch - 2ms/step
# Epoch 21/10000
# 14/14 - 0s - loss: 0.6898 - accuracy: 0.5411 - val_loss: 0.6942 - val_accuracy: 0.5044 - 29ms/epoch - 2ms/step
# Epoch 22/10000
# 14/14 - 0s - loss: 0.6876 - accuracy: 0.5422 - val_loss: 0.6943 - val_accuracy: 0.5058 - 30ms/epoch - 2ms/step
# Epoch 23/10000
# 14/14 - 0s - loss: 0.6868 - accuracy: 0.5389 - val_loss: 0.6944 - val_accuracy: 0.5131 - 28ms/epoch - 2ms/step
# Epoch 24/10000
# 14/14 - 0s - loss: 0.6865 - accuracy: 0.5422 - val_loss: 0.6945 - val_accuracy: 0.5102 - 29ms/epoch - 2ms/step
# Epoch 25/10000
# 14/14 - 0s - loss: 0.6878 - accuracy: 0.5367 - val_loss: 0.6946 - val_accuracy: 0.5102 - 29ms/epoch - 2ms/step
# Epoch 26/10000
# 14/14 - 0s - loss: 0.6863 - accuracy: 0.5465 - val_loss: 0.6946 - val_accuracy: 0.5102 - 29ms/epoch - 2ms/step
# Epoch 27/10000
# 14/14 - 0s - loss: 0.6877 - accuracy: 0.5447 - val_loss: 0.6947 - val_accuracy: 0.5116 - 28ms/epoch - 2ms/step
# Epoch 28/10000
# 14/14 - 0s - loss: 0.6857 - accuracy: 0.5465 - val_loss: 0.6946 - val_accuracy: 0.5160 - 29ms/epoch - 2ms/step
# Epoch 29/10000
# 14/14 - 0s - loss: 0.6884 - accuracy: 0.5418 - val_loss: 0.6948 - val_accuracy: 0.5116 - 27ms/epoch - 2ms/step
# Epoch 30/10000
# 14/14 - 0s - loss: 0.6885 - accuracy: 0.5458 - val_loss: 0.6948 - val_accuracy: 0.5087 - 27ms/epoch - 2ms/step
# Epoch 31/10000
# 14/14 - 0s - loss: 0.6861 - accuracy: 0.5505 - val_loss: 0.6950 - val_accuracy: 0.5058 - 29ms/epoch - 2ms/step
# Epoch 32/10000
# 14/14 - 0s - loss: 0.6854 - accuracy: 0.5505 - val_loss: 0.6951 - val_accuracy: 0.5029 - 28ms/epoch - 2ms/step
# Epoch 33/10000
# 14/14 - 0s - loss: 0.6832 - accuracy: 0.5600 - val_loss: 0.6952 - val_accuracy: 0.5116 - 35ms/epoch - 2ms/step
# Epoch 34/10000
# 14/14 - 0s - loss: 0.6861 - accuracy: 0.5465 - val_loss: 0.6953 - val_accuracy: 0.5073 - 30ms/epoch - 2ms/step
# Epoch 35/10000
# 14/14 - 0s - loss: 0.6847 - accuracy: 0.5567 - val_loss: 0.6953 - val_accuracy: 0.5073 - 32ms/epoch - 2ms/step
# Epoch 36/10000
# 14/14 - 0s - loss: 0.6862 - accuracy: 0.5396 - val_loss: 0.6953 - val_accuracy: 0.5058 - 32ms/epoch - 2ms/step
# Epoch 37/10000
# 14/14 - 0s - loss: 0.6857 - accuracy: 0.5487 - val_loss: 0.6954 - val_accuracy: 0.5116 - 33ms/epoch - 2ms/step
# Epoch 38/10000
# 14/14 - 0s - loss: 0.6851 - accuracy: 0.5483 - val_loss: 0.6955 - val_accuracy: 0.5131 - 36ms/epoch - 3ms/step
# Epoch 39/10000
# 14/14 - 0s - loss: 0.6869 - accuracy: 0.5552 - val_loss: 0.6956 - val_accuracy: 0.5087 - 73ms/epoch - 5ms/step
# Epoch 40/10000
# 14/14 - 0s - loss: 0.6843 - accuracy: 0.5643 - val_loss: 0.6954 - val_accuracy: 0.5131 - 32ms/epoch - 2ms/step
# Epoch 41/10000
# 14/14 - 0s - loss: 0.6854 - accuracy: 0.5483 - val_loss: 0.6954 - val_accuracy: 0.5102 - 31ms/epoch - 2ms/step
# Epoch 42/10000
# 14/14 - 0s - loss: 0.6853 - accuracy: 0.5476 - val_loss: 0.6954 - val_accuracy: 0.5131 - 31ms/epoch - 2ms/step
# Epoch 43/10000
# 14/14 - 0s - loss: 0.6847 - accuracy: 0.5531 - val_loss: 0.6955 - val_accuracy: 0.5145 - 30ms/epoch - 2ms/step
# Epoch 44/10000
# 14/14 - 0s - loss: 0.6859 - accuracy: 0.5512 - val_loss: 0.6955 - val_accuracy: 0.5102 - 31ms/epoch - 2ms/step
# Epoch 45/10000
# 14/14 - 0s - loss: 0.6840 - accuracy: 0.5578 - val_loss: 0.6955 - val_accuracy: 0.5131 - 30ms/epoch - 2ms/step
# Epoch 46/10000
# 14/14 - 0s - loss: 0.6842 - accuracy: 0.5549 - val_loss: 0.6954 - val_accuracy: 0.5145 - 29ms/epoch - 2ms/step
# Epoch 47/10000
# 14/14 - 0s - loss: 0.6848 - accuracy: 0.5498 - val_loss: 0.6954 - val_accuracy: 0.5160 - 27ms/epoch - 2ms/step
# Epoch 48/10000
# 14/14 - 0s - loss: 0.6861 - accuracy: 0.5610 - val_loss: 0.6956 - val_accuracy: 0.5131 - 29ms/epoch - 2ms/step
# Epoch 49/10000
# 14/14 - 0s - loss: 0.6868 - accuracy: 0.5469 - val_loss: 0.6954 - val_accuracy: 0.5073 - 27ms/epoch - 2ms/step
# Epoch 50/10000
# 14/14 - 0s - loss: 0.6850 - accuracy: 0.5592 - val_loss: 0.6954 - val_accuracy: 0.5044 - 29ms/epoch - 2ms/step
# Epoch 51/10000
# 14/14 - 0s - loss: 0.6852 - accuracy: 0.5585 - val_loss: 0.6952 - val_accuracy: 0.5058 - 29ms/epoch - 2ms/step
# Epoch 52/10000
# 14/14 - 0s - loss: 0.6839 - accuracy: 0.5538 - val_loss: 0.6951 - val_accuracy: 0.5087 - 29ms/epoch - 2ms/step
# Epoch 53/10000
# 14/14 - 0s - loss: 0.6849 - accuracy: 0.5538 - val_loss: 0.6952 - val_accuracy: 0.5073 - 27ms/epoch - 2ms/step
# Epoch 54/10000
# 14/14 - 0s - loss: 0.6830 - accuracy: 0.5669 - val_loss: 0.6954 - val_accuracy: 0.5087 - 29ms/epoch - 2ms/step
# Epoch 55/10000
# 14/14 - 0s - loss: 0.6847 - accuracy: 0.5585 - val_loss: 0.6954 - val_accuracy: 0.5087 - 29ms/epoch - 2ms/step
# Epoch 56/10000
# 14/14 - 0s - loss: 0.6857 - accuracy: 0.5451 - val_loss: 0.6955 - val_accuracy: 0.5087 - 30ms/epoch - 2ms/step
# Epoch 57/10000
# 14/14 - 0s - loss: 0.6865 - accuracy: 0.5403 - val_loss: 0.6956 - val_accuracy: 0.5073 - 28ms/epoch - 2ms/step
# Epoch 58/10000
# 14/14 - 0s - loss: 0.6845 - accuracy: 0.5545 - val_loss: 0.6956 - val_accuracy: 0.5116 - 29ms/epoch - 2ms/step
# Epoch 59/10000
# 14/14 - 0s - loss: 0.6836 - accuracy: 0.5596 - val_loss: 0.6956 - val_accuracy: 0.5058 - 29ms/epoch - 2ms/step
# Epoch 60/10000
# 14/14 - 0s - loss: 0.6837 - accuracy: 0.5607 - val_loss: 0.6956 - val_accuracy: 0.5087 - 29ms/epoch - 2ms/step
# Epoch 61/10000
# 14/14 - 0s - loss: 0.6863 - accuracy: 0.5570 - val_loss: 0.6956 - val_accuracy: 0.5073 - 29ms/epoch - 2ms/step
# Epoch 62/10000
# 14/14 - 0s - loss: 0.6820 - accuracy: 0.5574 - val_loss: 0.6956 - val_accuracy: 0.5073 - 30ms/epoch - 2ms/step
# 27/27 [==============================] - 0s 419us/step
# train_X Shape: (3440, 15, 2)
# train_y Shape: (3440, 2)
# test_X Shape: (861, 15, 2)
# test_y Shape: (861,)
# Epoch 1/10000
# 14/14 - 0s - loss: 0.7047 - accuracy: 0.4989 - val_loss: 0.6894 - val_accuracy: 0.5334 - 213ms/epoch - 15ms/step
# Epoch 2/10000
# 14/14 - 0s - loss: 0.6953 - accuracy: 0.5098 - val_loss: 0.6896 - val_accuracy: 0.5305 - 29ms/epoch - 2ms/step
# Epoch 3/10000
# 14/14 - 0s - loss: 0.6929 - accuracy: 0.5265 - val_loss: 0.6905 - val_accuracy: 0.5276 - 29ms/epoch - 2ms/step
# Epoch 4/10000
# 14/14 - 0s - loss: 0.6922 - accuracy: 0.5374 - val_loss: 0.6912 - val_accuracy: 0.5174 - 29ms/epoch - 2ms/step
# Epoch 5/10000
# 14/14 - 0s - loss: 0.6917 - accuracy: 0.5312 - val_loss: 0.6919 - val_accuracy: 0.5189 - 28ms/epoch - 2ms/step
# Epoch 6/10000
# 14/14 - 0s - loss: 0.6941 - accuracy: 0.5258 - val_loss: 0.6923 - val_accuracy: 0.5233 - 29ms/epoch - 2ms/step
# Epoch 7/10000
# 14/14 - 0s - loss: 0.6894 - accuracy: 0.5360 - val_loss: 0.6923 - val_accuracy: 0.5218 - 29ms/epoch - 2ms/step
# Epoch 8/10000
# 14/14 - 0s - loss: 0.6908 - accuracy: 0.5320 - val_loss: 0.6924 - val_accuracy: 0.5203 - 28ms/epoch - 2ms/step
# Epoch 9/10000
# 14/14 - 0s - loss: 0.6880 - accuracy: 0.5516 - val_loss: 0.6927 - val_accuracy: 0.5233 - 30ms/epoch - 2ms/step
# Epoch 10/10000
# 14/14 - 0s - loss: 0.6891 - accuracy: 0.5312 - val_loss: 0.6930 - val_accuracy: 0.5262 - 29ms/epoch - 2ms/step
# Epoch 11/10000
# 14/14 - 0s - loss: 0.6892 - accuracy: 0.5432 - val_loss: 0.6933 - val_accuracy: 0.5203 - 30ms/epoch - 2ms/step
# Epoch 12/10000
# 14/14 - 0s - loss: 0.6901 - accuracy: 0.5349 - val_loss: 0.6934 - val_accuracy: 0.5305 - 30ms/epoch - 2ms/step
# Epoch 13/10000
# 14/14 - 0s - loss: 0.6890 - accuracy: 0.5469 - val_loss: 0.6934 - val_accuracy: 0.5291 - 29ms/epoch - 2ms/step
# Epoch 14/10000
# 14/14 - 0s - loss: 0.6881 - accuracy: 0.5429 - val_loss: 0.6934 - val_accuracy: 0.5276 - 29ms/epoch - 2ms/step
# Epoch 15/10000
# 14/14 - 0s - loss: 0.6879 - accuracy: 0.5585 - val_loss: 0.6934 - val_accuracy: 0.5262 - 30ms/epoch - 2ms/step
# Epoch 16/10000
# 14/14 - 0s - loss: 0.6900 - accuracy: 0.5349 - val_loss: 0.6933 - val_accuracy: 0.5291 - 29ms/epoch - 2ms/step
# Epoch 17/10000
# ...
# Epoch 52/10000
# 14/14 - 0s - loss: 0.6831 - accuracy: 0.5520 - val_loss: 0.6971 - val_accuracy: 0.5087 - 28ms/epoch - 2ms/step
# Epoch 53/10000
# 14/14 - 0s - loss: 0.6839 - accuracy: 0.5527 - val_loss: 0.6971 - val_accuracy: 0.5044 - 28ms/epoch - 2ms/step
# 27/27 [==============================] - 0s 402us/step
# train_X Shape: (3440, 15, 2)
# train_y Shape: (3440, 2)
# test_X Shape: (861, 15, 2)
# test_y Shape: (861,)
# Epoch 1/10000
# 14/14 - 0s - loss: 0.6988 - accuracy: 0.5229 - val_loss: 0.6927 - val_accuracy: 0.5174 - 198ms/epoch - 14ms/step
# Epoch 2/10000
# 14/14 - 0s - loss: 0.7001 - accuracy: 0.4978 - val_loss: 0.6930 - val_accuracy: 0.5160 - 29ms/epoch - 2ms/step
# Epoch 3/10000
# 14/14 - 0s - loss: 0.6909 - accuracy: 0.5323 - val_loss: 0.6935 - val_accuracy: 0.5218 - 29ms/epoch - 2ms/step
# Epoch 4/10000
# 14/14 - 0s - loss: 0.6923 - accuracy: 0.5345 - val_loss: 0.6938 - val_accuracy: 0.5291 - 29ms/epoch - 2ms/step
# Epoch 5/10000
# 14/14 - 0s - loss: 0.6930 - accuracy: 0.5302 - val_loss: 0.6943 - val_accuracy: 0.5189 - 29ms/epoch - 2ms/step
# Epoch 6/10000
# 14/14 - 0s - loss: 0.6914 - accuracy: 0.5429 - val_loss: 0.6940 - val_accuracy: 0.5203 - 28ms/epoch - 2ms/step
# Epoch 7/10000
# 14/14 - 0s - loss: 0.6899 - accuracy: 0.5422 - val_loss: 0.6940 - val_accuracy: 0.5189 - 29ms/epoch - 2ms/step
# Epoch 8/10000
# 14/14 - 0s - loss: 0.6927 - accuracy: 0.5352 - val_loss: 0.6940 - val_accuracy: 0.5203 - 35ms/epoch - 2ms/step
# Epoch 9/10000
# 14/14 - 0s - loss: 0.6896 - accuracy: 0.5458 - val_loss: 0.6943 - val_accuracy: 0.5174 - 29ms/epoch - 2ms/step
# Epoch 10/10000
# 14/14 - 0s - loss: 0.6913 - accuracy: 0.5392 - val_loss: 0.6942 - val_accuracy: 0.5203 - 30ms/epoch - 2ms/step
# Epoch 11/10000
# 14/14 - 0s - loss: 0.6856 - accuracy: 0.5574 - val_loss: 0.6944 - val_accuracy: 0.5203 - 29ms/epoch - 2ms/step
# Epoch 12/10000
# 14/14 - 0s - loss: 0.6890 - accuracy: 0.5352 - val_loss: 0.6944 - val_accuracy: 0.5262 - 36ms/epoch - 3ms/step
# Epoch 13/10000
# 14/14 - 0s - loss: 0.6889 - accuracy: 0.5414 - val_loss: 0.6947 - val_accuracy: 0.5233 - 32ms/epoch - 2ms/step
# Epoch 14/10000
# 14/14 - 0s - loss: 0.6857 - accuracy: 0.5483 - val_loss: 0.6945 - val_accuracy: 0.5247 - 29ms/epoch - 2ms/step
# Epoch 15/10000
# 14/14 - 0s - loss: 0.6878 - accuracy: 0.5472 - val_loss: 0.6944 - val_accuracy: 0.5291 - 29ms/epoch - 2ms/step
# Epoch 16/10000
# 14/14 - 0s - loss: 0.6874 - accuracy: 0.5414 - val_loss: 0.6944 - val_accuracy: 0.5247 - 30ms/epoch - 2ms/step
# Epoch 17/10000
# 14/14 - 0s - loss: 0.6886 - accuracy: 0.5512 - val_loss: 0.6946 - val_accuracy: 0.5247 - 30ms/epoch - 2ms/step
# Epoch 18/10000
# 14/14 - 0s - loss: 0.6846 - accuracy: 0.5574 - val_loss: 0.6945 - val_accuracy: 0.5276 - 29ms/epoch - 2ms/step
# Epoch 19/10000
# 14/14 - 0s - loss: 0.6861 - accuracy: 0.5538 - val_loss: 0.6945 - val_accuracy: 0.5262 - 29ms/epoch - 2ms/step
# Epoch 20/10000
# 14/14 - 0s - loss: 0.6857 - accuracy: 0.5487 - val_loss: 0.6946 - val_accuracy: 0.5276 - 29ms/epoch - 2ms/step
# Epoch 21/10000
# 14/14 - 0s - loss: 0.6873 - accuracy: 0.5469 - val_loss: 0.6949 - val_accuracy: 0.5247 - 29ms/epoch - 2ms/step
# Epoch 22/10000
# 14/14 - 0s - loss: 0.6857 - accuracy: 0.5509 - val_loss: 0.6951 - val_accuracy: 0.5262 - 29ms/epoch - 2ms/step
# Epoch 23/10000
# 14/14 - 0s - loss: 0.6870 - accuracy: 0.5472 - val_loss: 0.6951 - val_accuracy: 0.5218 - 29ms/epoch - 2ms/step
# Epoch 24/10000
# 14/14 - 0s - loss: 0.6842 - accuracy: 0.5592 - val_loss: 0.6952 - val_accuracy: 0.5233 - 29ms/epoch - 2ms/step
# Epoch 25/10000
# 14/14 - 0s - loss: 0.6859 - accuracy: 0.5472 - val_loss: 0.6953 - val_accuracy: 0.5247 - 29ms/epoch - 2ms/step
# Epoch 26/10000
# 14/14 - 0s - loss: 0.6832 - accuracy: 0.5614 - val_loss: 0.6953 - val_accuracy: 0.5262 - 29ms/epoch - 2ms/step
# Epoch 27/10000
# 14/14 - 0s - loss: 0.6856 - accuracy: 0.5523 - val_loss: 0.6954 - val_accuracy: 0.5262 - 28ms/epoch - 2ms/step
# Epoch 28/10000
# 14/14 - 0s - loss: 0.6877 - accuracy: 0.5454 - val_loss: 0.6955 - val_accuracy: 0.5233 - 29ms/epoch - 2ms/step
# Epoch 29/10000
# 14/14 - 0s - loss: 0.6855 - accuracy: 0.5447 - val_loss: 0.6955 - val_accuracy: 0.5203 - 29ms/epoch - 2ms/step
# Epoch 30/10000
# 14/14 - 0s - loss: 0.6851 - accuracy: 0.5494 - val_loss: 0.6956 - val_accuracy: 0.5218 - 29ms/epoch - 2ms/step
# Epoch 31/10000
# 14/14 - 0s - loss: 0.6853 - accuracy: 0.5494 - val_loss: 0.6955 - val_accuracy: 0.5247 - 29ms/epoch - 2ms/step
# Epoch 32/10000
# 14/14 - 0s - loss: 0.6843 - accuracy: 0.5520 - val_loss: 0.6957 - val_accuracy: 0.5247 - 29ms/epoch - 2ms/step
# Epoch 33/10000
# 14/14 - 0s - loss: 0.6861 - accuracy: 0.5403 - val_loss: 0.6958 - val_accuracy: 0.5203 - 29ms/epoch - 2ms/step
# Epoch 34/10000
# 14/14 - 0s - loss: 0.6848 - accuracy: 0.5516 - val_loss: 0.6957 - val_accuracy: 0.5233 - 40ms/epoch - 3ms/step
# Epoch 35/10000
# 14/14 - 0s - loss: 0.6852 - accuracy: 0.5509 - val_loss: 0.6958 - val_accuracy: 0.5174 - 29ms/epoch - 2ms/step
# Epoch 36/10000
# 14/14 - 0s - loss: 0.6853 - accuracy: 0.5527 - val_loss: 0.6958 - val_accuracy: 0.5160 - 29ms/epoch - 2ms/step
# Epoch 37/10000
# 14/14 - 0s - loss: 0.6853 - accuracy: 0.5491 - val_loss: 0.6957 - val_accuracy: 0.5262 - 30ms/epoch - 2ms/step
# Epoch 38/10000
# 14/14 - 0s - loss: 0.6837 - accuracy: 0.5592 - val_loss: 0.6959 - val_accuracy: 0.5203 - 29ms/epoch - 2ms/step
# Epoch 39/10000
# 14/14 - 0s - loss: 0.6848 - accuracy: 0.5494 - val_loss: 0.6960 - val_accuracy: 0.5218 - 31ms/epoch - 2ms/step
# Epoch 40/10000
# 14/14 - 0s - loss: 0.6852 - accuracy: 0.5538 - val_loss: 0.6960 - val_accuracy: 0.5203 - 29ms/epoch - 2ms/step
# Epoch 41/10000
# 14/14 - 0s - loss: 0.6861 - accuracy: 0.5516 - val_loss: 0.6961 - val_accuracy: 0.5174 - 29ms/epoch - 2ms/step
# Epoch 42/10000
# 14/14 - 0s - loss: 0.6847 - accuracy: 0.5560 - val_loss: 0.6960 - val_accuracy: 0.5203 - 29ms/epoch - 2ms/step
# Epoch 43/10000
# 14/14 - 0s - loss: 0.6861 - accuracy: 0.5418 - val_loss: 0.6961 - val_accuracy: 0.5189 - 27ms/epoch - 2ms/step
# Epoch 44/10000
# 14/14 - 0s - loss: 0.6858 - accuracy: 0.5505 - val_loss: 0.6960 - val_accuracy: 0.5160 - 29ms/epoch - 2ms/step
# Epoch 45/10000
# 14/14 - 0s - loss: 0.6838 - accuracy: 0.5589 - val_loss: 0.6961 - val_accuracy: 0.5174 - 30ms/epoch - 2ms/step
# Epoch 46/10000
# 14/14 - 0s - loss: 0.6844 - accuracy: 0.5541 - val_loss: 0.6959 - val_accuracy: 0.5203 - 29ms/epoch - 2ms/step
# Epoch 47/10000
# 14/14 - 0s - loss: 0.6844 - accuracy: 0.5600 - val_loss: 0.6959 - val_accuracy: 0.5160 - 29ms/epoch - 2ms/step
# Epoch 48/10000
# 14/14 - 0s - loss: 0.6840 - accuracy: 0.5596 - val_loss: 0.6962 - val_accuracy: 0.5203 - 29ms/epoch - 2ms/step
# Epoch 49/10000
# 14/14 - 0s - loss: 0.6841 - accuracy: 0.5629 - val_loss: 0.6961 - val_accuracy: 0.5218 - 28ms/epoch - 2ms/step
# Epoch 50/10000
# 14/14 - 0s - loss: 0.6838 - accuracy: 0.5498 - val_loss: 0.6962 - val_accuracy: 0.5174 - 29ms/epoch - 2ms/step
# Epoch 51/10000
# 14/14 - 0s - loss: 0.6849 - accuracy: 0.5472 - val_loss: 0.6962 - val_accuracy: 0.5131 - 29ms/epoch - 2ms/step
# 27/27 [==============================] - 0s 396us/step
# train_X Shape: (3440, 15, 2)
# train_y Shape: (3440, 2)
# test_X Shape: (861, 15, 2)
# test_y Shape: (861,)
# Epoch 1/10000
# 14/14 - 0s - loss: 0.7302 - accuracy: 0.4989 - val_loss: 0.7137 - val_accuracy: 0.5000 - 196ms/epoch - 14ms/step
# Epoch 2/10000
# 14/14 - 0s - loss: 0.7071 - accuracy: 0.5127 - val_loss: 0.7002 - val_accuracy: 0.4840 - 28ms/epoch - 2ms/step
# Epoch 3/10000
# 14/14 - 0s - loss: 0.6990 - accuracy: 0.5174 - val_loss: 0.6989 - val_accuracy: 0.4942 - 28ms/epoch - 2ms/step
# Epoch 4/10000
# 14/14 - 0s - loss: 0.6999 - accuracy: 0.5200 - val_loss: 0.6976 - val_accuracy: 0.4927 - 29ms/epoch - 2ms/step
# Epoch 5/10000
# 14/14 - 0s - loss: 0.6915 - accuracy: 0.5342 - val_loss: 0.6970 - val_accuracy: 0.5073 - 29ms/epoch - 2ms/step
# Epoch 6/10000
# 14/14 - 0s - loss: 0.6942 - accuracy: 0.5291 - val_loss: 0.6966 - val_accuracy: 0.5174 - 29ms/epoch - 2ms/step
# Epoch 7/10000
# 14/14 - 0s - loss: 0.6963 - accuracy: 0.5265 - val_loss: 0.6959 - val_accuracy: 0.5203 - 29ms/epoch - 2ms/step
# Epoch 8/10000
# 14/14 - 0s - loss: 0.6953 - accuracy: 0.5153 - val_loss: 0.6953 - val_accuracy: 0.5087 - 30ms/epoch - 2ms/step
# Epoch 9/10000
# 14/14 - 0s - loss: 0.6994 - accuracy: 0.5167 - val_loss: 0.6950 - val_accuracy: 0.5174 - 29ms/epoch - 2ms/step
# Epoch 10/10000
# 14/14 - 0s - loss: 0.6916 - accuracy: 0.5494 - val_loss: 0.6947 - val_accuracy: 0.5131 - 30ms/epoch - 2ms/step
# Epoch 11/10000
# 14/14 - 0s - loss: 0.6904 - accuracy: 0.5400 - val_loss: 0.6946 - val_accuracy: 0.5145 - 29ms/epoch - 2ms/step
# Epoch 12/10000
# 14/14 - 0s - loss: 0.6950 - accuracy: 0.5287 - val_loss: 0.6944 - val_accuracy: 0.5131 - 30ms/epoch - 2ms/step
# Epoch 13/10000
# 14/14 - 0s - loss: 0.6906 - accuracy: 0.5374 - val_loss: 0.6946 - val_accuracy: 0.5044 - 30ms/epoch - 2ms/step
# Epoch 14/10000
# 14/14 - 0s - loss: 0.6906 - accuracy: 0.5349 - val_loss: 0.6944 - val_accuracy: 0.5160 - 29ms/epoch - 2ms/step
# Epoch 15/10000
# 14/14 - 0s - loss: 0.6937 - accuracy: 0.5360 - val_loss: 0.6944 - val_accuracy: 0.5073 - 29ms/epoch - 2ms/step
# Epoch 16/10000
# 14/14 - 0s - loss: 0.6911 - accuracy: 0.5487 - val_loss: 0.6944 - val_accuracy: 0.5087 - 29ms/epoch - 2ms/step
# Epoch 17/10000
# 14/14 - 0s - loss: 0.6882 - accuracy: 0.5414 - val_loss: 0.6945 - val_accuracy: 0.5073 - 29ms/epoch - 2ms/step
# Epoch 18/10000
# 14/14 - 0s - loss: 0.6890 - accuracy: 0.5454 - val_loss: 0.6947 - val_accuracy: 0.5087 - 28ms/epoch - 2ms/step
# Epoch 19/10000
# 14/14 - 0s - loss: 0.6889 - accuracy: 0.5483 - val_loss: 0.6948 - val_accuracy: 0.5203 - 28ms/epoch - 2ms/step
# Epoch 20/10000
# 14/14 - 0s - loss: 0.6875 - accuracy: 0.5472 - val_loss: 0.6949 - val_accuracy: 0.5116 - 29ms/epoch - 2ms/step
# Epoch 21/10000
# 14/14 - 0s - loss: 0.6875 - accuracy: 0.5440 - val_loss: 0.6946 - val_accuracy: 0.5218 - 30ms/epoch - 2ms/step
# Epoch 22/10000
# 14/14 - 0s - loss: 0.6855 - accuracy: 0.5509 - val_loss: 0.6947 - val_accuracy: 0.5160 - 30ms/epoch - 2ms/step
# Epoch 23/10000
# 14/14 - 0s - loss: 0.6873 - accuracy: 0.5534 - val_loss: 0.6948 - val_accuracy: 0.5203 - 29ms/epoch - 2ms/step
# Epoch 24/10000
# 14/14 - 0s - loss: 0.6865 - accuracy: 0.5491 - val_loss: 0.6952 - val_accuracy: 0.5131 - 30ms/epoch - 2ms/step
# Epoch 25/10000
# 14/14 - 0s - loss: 0.6881 - accuracy: 0.5469 - val_loss: 0.6953 - val_accuracy: 0.5116 - 30ms/epoch - 2ms/step
# Epoch 26/10000
# 14/14 - 0s - loss: 0.6866 - accuracy: 0.5509 - val_loss: 0.6954 - val_accuracy: 0.5203 - 30ms/epoch - 2ms/step
# Epoch 27/10000
# 14/14 - 0s - loss: 0.6849 - accuracy: 0.5549 - val_loss: 0.6955 - val_accuracy: 0.5102 - 30ms/epoch - 2ms/step
# Epoch 28/10000
# 14/14 - 0s - loss: 0.6858 - accuracy: 0.5505 - val_loss: 0.6953 - val_accuracy: 0.5305 - 29ms/epoch - 2ms/step
# Epoch 29/10000
# 14/14 - 0s - loss: 0.6857 - accuracy: 0.5549 - val_loss: 0.6954 - val_accuracy: 0.5174 - 30ms/epoch - 2ms/step
# Epoch 30/10000
# 14/14 - 0s - loss: 0.6845 - accuracy: 0.5589 - val_loss: 0.6954 - val_accuracy: 0.5247 - 30ms/epoch - 2ms/step
# Epoch 31/10000
# 14/14 - 0s - loss: 0.6859 - accuracy: 0.5512 - val_loss: 0.6957 - val_accuracy: 0.5189 - 29ms/epoch - 2ms/step
# Epoch 32/10000
# 14/14 - 0s - loss: 0.6845 - accuracy: 0.5512 - val_loss: 0.6957 - val_accuracy: 0.5233 - 29ms/epoch - 2ms/step
# Epoch 33/10000
# 14/14 - 0s - loss: 0.6880 - accuracy: 0.5509 - val_loss: 0.6958 - val_accuracy: 0.5203 - 29ms/epoch - 2ms/step
# Epoch 34/10000
# 14/14 - 0s - loss: 0.6852 - accuracy: 0.5549 - val_loss: 0.6958 - val_accuracy: 0.5203 - 29ms/epoch - 2ms/step
# Epoch 35/10000
# 14/14 - 0s - loss: 0.6859 - accuracy: 0.5610 - val_loss: 0.6959 - val_accuracy: 0.5189 - 29ms/epoch - 2ms/step
# Epoch 36/10000
# 14/14 - 0s - loss: 0.6853 - accuracy: 0.5531 - val_loss: 0.6960 - val_accuracy: 0.5203 - 30ms/epoch - 2ms/step
# Epoch 37/10000
# 14/14 - 0s - loss: 0.6849 - accuracy: 0.5552 - val_loss: 0.6963 - val_accuracy: 0.5160 - 29ms/epoch - 2ms/step
# Epoch 38/10000
# 14/14 - 0s - loss: 0.6847 - accuracy: 0.5570 - val_loss: 0.6963 - val_accuracy: 0.5174 - 28ms/epoch - 2ms/step
# Epoch 39/10000
# 14/14 - 0s - loss: 0.6850 - accuracy: 0.5545 - val_loss: 0.6963 - val_accuracy: 0.5189 - 28ms/epoch - 2ms/step
# Epoch 40/10000
# 14/14 - 0s - loss: 0.6855 - accuracy: 0.5538 - val_loss: 0.6962 - val_accuracy: 0.5160 - 29ms/epoch - 2ms/step
# Epoch 41/10000
# 14/14 - 0s - loss: 0.6864 - accuracy: 0.5589 - val_loss: 0.6961 - val_accuracy: 0.5160 - 28ms/epoch - 2ms/step
# Epoch 42/10000
# 14/14 - 0s - loss: 0.6851 - accuracy: 0.5531 - val_loss: 0.6961 - val_accuracy: 0.5160 - 28ms/epoch - 2ms/step
# Epoch 43/10000
# 14/14 - 0s - loss: 0.6854 - accuracy: 0.5545 - val_loss: 0.6963 - val_accuracy: 0.5160 - 29ms/epoch - 2ms/step
# Epoch 44/10000
# 14/14 - 0s - loss: 0.6865 - accuracy: 0.5549 - val_loss: 0.6961 - val_accuracy: 0.5189 - 29ms/epoch - 2ms/step
# Epoch 45/10000
# 14/14 - 0s - loss: 0.6848 - accuracy: 0.5523 - val_loss: 0.6963 - val_accuracy: 0.5174 - 30ms/epoch - 2ms/step
# Epoch 46/10000
# 14/14 - 0s - loss: 0.6846 - accuracy: 0.5501 - val_loss: 0.6962 - val_accuracy: 0.5218 - 29ms/epoch - 2ms/step
# Epoch 47/10000
# 14/14 - 0s - loss: 0.6854 - accuracy: 0.5429 - val_loss: 0.6960 - val_accuracy: 0.5218 - 29ms/epoch - 2ms/step
# Epoch 48/10000
# 14/14 - 0s - loss: 0.6817 - accuracy: 0.5607 - val_loss: 0.6962 - val_accuracy: 0.5174 - 30ms/epoch - 2ms/step
# Epoch 49/10000
# 14/14 - 0s - loss: 0.6865 - accuracy: 0.5414 - val_loss: 0.6961 - val_accuracy: 0.5189 - 29ms/epoch - 2ms/step
# Epoch 50/10000
# 14/14 - 0s - loss: 0.6865 - accuracy: 0.5447 - val_loss: 0.6960 - val_accuracy: 0.5189 - 29ms/epoch - 2ms/step
# Epoch 51/10000
# 14/14 - 0s - loss: 0.6842 - accuracy: 0.5600 - val_loss: 0.6959 - val_accuracy: 0.5174 - 29ms/epoch - 2ms/step
# Epoch 52/10000
# 14/14 - 0s - loss: 0.6854 - accuracy: 0.5541 - val_loss: 0.6958 - val_accuracy: 0.5160 - 29ms/epoch - 2ms/step
# Epoch 53/10000
# 14/14 - 0s - loss: 0.6845 - accuracy: 0.5578 - val_loss: 0.6959 - val_accuracy: 0.5174 - 29ms/epoch - 2ms/step
# Epoch 54/10000
# 14/14 - 0s - loss: 0.6832 - accuracy: 0.5632 - val_loss: 0.6959 - val_accuracy: 0.5174 - 30ms/epoch - 2ms/step
# Epoch 55/10000
# 14/14 - 0s - loss: 0.6843 - accuracy: 0.5607 - val_loss: 0.6960 - val_accuracy: 0.5131 - 29ms/epoch - 2ms/step
# Epoch 56/10000
# 14/14 - 0s - loss: 0.6859 - accuracy: 0.5440 - val_loss: 0.6961 - val_accuracy: 0.5203 - 30ms/epoch - 2ms/step
# Epoch 57/10000
# 14/14 - 0s - loss: 0.6850 - accuracy: 0.5640 - val_loss: 0.6961 - val_accuracy: 0.5174 - 30ms/epoch - 2ms/step
# Epoch 58/10000
# 14/14 - 0s - loss: 0.6839 - accuracy: 0.5567 - val_loss: 0.6961 - val_accuracy: 0.5203 - 31ms/epoch - 2ms/step
# Epoch 59/10000
# 14/14 - 0s - loss: 0.6817 - accuracy: 0.5570 - val_loss: 0.6960 - val_accuracy: 0.5174 - 29ms/epoch - 2ms/step
# Epoch 60/10000
# 14/14 - 0s - loss: 0.6839 - accuracy: 0.5640 - val_loss: 0.6960 - val_accuracy: 0.5174 - 29ms/epoch - 2ms/step
# Epoch 61/10000
# 14/14 - 0s - loss: 0.6860 - accuracy: 0.5483 - val_loss: 0.6959 - val_accuracy: 0.5160 - 30ms/epoch - 2ms/step
# Epoch 62/10000
# 14/14 - 0s - loss: 0.6837 - accuracy: 0.5589 - val_loss: 0.6957 - val_accuracy: 0.5145 - 30ms/epoch - 2ms/step
# Epoch 63/10000
# 14/14 - 0s - loss: 0.6841 - accuracy: 0.5556 - val_loss: 0.6960 - val_accuracy: 0.5174 - 30ms/epoch - 2ms/step
# Epoch 64/10000
# 14/14 - 0s - loss: 0.6861 - accuracy: 0.5487 - val_loss: 0.6961 - val_accuracy: 0.5174 - 30ms/epoch - 2ms/step
# Epoch 65/10000
# 14/14 - 0s - loss: 0.6841 - accuracy: 0.5560 - val_loss: 0.6961 - val_accuracy: 0.5145 - 29ms/epoch - 2ms/step
# Epoch 66/10000
# 14/14 - 0s - loss: 0.6845 - accuracy: 0.5531 - val_loss: 0.6960 - val_accuracy: 0.5131 - 28ms/epoch - 2ms/step
# 27/27 [==============================] - 0s 384us/step
# /var/folders/vp/8_rd4_c56g3dpqb1167z6tqr0000gn/T/ipykernel_29133/3454146048.py:66: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append({"timestep": step,"features": data.columns.values,"google_trends_lag":g,"tweet_volume_lag": tv,"tweet_polarity_score_lag": tw_lag, "batch_size":b, "neurons":n, "layers":l, "mean_down_f1_score":mean_down_f1_score,"mean_up_f1_score":mean_up_f1_score, "mean_acc": mean_acc,"min_acc":min_acc, "max_acc":max_acc, "diff_acc": diff_acc,'optimizer':my_optimizer}, ignore_index=True)

# %%
results.to_csv(filepath_out, index=False)
